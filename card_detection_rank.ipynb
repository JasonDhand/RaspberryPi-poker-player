# %%
import tensorflow as tf
from PIL import Image
import numpy as np

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# Create the CNN model
model = Sequential()

# Add the first convolutional layer
model.add(Conv2D(64, (5, 5), activation='relu', input_shape=(224, 224, 3)))
model.add(BatchNormalization())
model.add(MaxPooling2D((3, 3)))

# Add the second convolutional layer
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((3, 3)))

# Add the third convolutional layer
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D((2, 2)))

# Flatten the output
model.add(Flatten())

# Add the first dense layer
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))

# Add the output layer
model.add(Dense(13, activation='softmax'))

# %%
####rank detection datasets defined
train_path = "cards_dataset_by_rank\\train"
valid_path = "cards_dataset_by_rank\\valid"
test_path = "cards_dataset_by_rank\\test"

batch_size = 32
img_height = 224
img_width = 224
num_classes = 13  # Number of classes in your dataset

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_path,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='categorical'  # Use one-hot encoded labels
)

# Load validation dataset with integer-encoded labels
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    valid_path,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='categorical' 
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_path,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='categorical',  # Assuming integer-encoded labels for testing dataset
    shuffle=False  # Ensure dataset is not shuffled
)
# Out:
# Found 22527 files belonging to 13 classes.
# Found 520 files belonging to 13 classes.
# Found 520 files belonging to 13 classes.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
hist = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)
# Out:
# Epoch 1/10
# 704/704 [==============================] - 834s 1s/step - loss: 1.1954 - accuracy: 0.6442 - val_loss: 0.8200 - val_accuracy: 0.8577
# Epoch 2/10
# 704/704 [==============================] - 765s 1s/step - loss: 0.5258 - accuracy: 0.8409 - val_loss: 0.4061 - val_accuracy: 0.9019
# Epoch 3/10
# 704/704 [==============================] - 702s 998ms/step - loss: 0.2106 - accuracy: 0.9397 - val_loss: 0.2467 - val_accuracy: 0.9250
# Epoch 4/10
# 704/704 [==============================] - 718s 1s/step - loss: 0.0985 - accuracy: 0.9718 - val_loss: 0.2681 - val_accuracy: 0.9250
# Epoch 5/10
# 704/704 [==============================] - 894s 1s/step - loss: 0.0613 - accuracy: 0.9831 - val_loss: 0.1867 - val_accuracy: 0.9385
# Epoch 6/10
# 704/704 [==============================] - 752s 1s/step - loss: 0.0600 - accuracy: 0.9822 - val_loss: 1.1873 - val_accuracy: 0.7154
# Epoch 7/10
# 704/704 [==============================] - 905s 1s/step - loss: 0.0439 - accuracy: 0.9871 - val_loss: 0.1650 - val_accuracy: 0.9519
# Epoch 8/10
# 704/704 [==============================] - 828s 1s/step - loss: 0.0461 - accuracy: 0.9868 - val_loss: 0.1553 - val_accuracy: 0.9615
# Epoch 9/10
# 704/704 [==============================] - 861s 1s/step - loss: 0.0410 - accuracy: 0.9876 - val_loss: 0.1703 - val_accuracy: 0.9558
# Epoch 10/10
# 704/704 [==============================] - 923s 1s/step - loss: 0.0414 - accuracy: 0.9863 - val_loss: 0.1501 - val_accuracy: 0.9442

# %%
model.save('rank_classification')
model.save_weights('rank_classification.h5')
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 3 of 3). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: rank_classification\assets
# INFO:tensorflow:Assets written to: rank_classification\assets

# %%
rank_model = tf.keras.models.load_model('rank_classification')

# %%
test_loss, test_accuracy = rank_model.evaluate(test_ds)

print(f'Test accuracy: {test_accuracy}')
# Out:
# 17/17 [==============================] - 4s 211ms/step - loss: 0.2143 - accuracy: 0.9462
# Test accuracy: 0.9461538195610046

# %%
def preprocess_image(image_path, desired_size=(224, 224)):
    # Open the image
    image = Image.open(image_path)
    
    # Resize the image using the ANTIALIAS (high-quality) interpolation method
    # resized_image = image.resize(desired_size, Image.ANTIALIAS)
    
    # Return the resized image
    return image
    # return resized_image

# %%
my_rank = []


from PIL import Image
import tensorflow as tf
classes = ["ace", "eight", "five", "four", "jack", "king", "nine", "queen", "seven", "six", "ten", "three", "two"]

# File path to the image
# image_path = "C:\\Users\\jason\\ECE_479\\final_project_3\\PiCam images\\2d.png"
image_path = "cropped_image.jpg"
# Load and preprocess the image using TensorFlow
image = tf.keras.preprocessing.image.load_img(image_path, target_size=(img_height, img_width))
image_array = tf.keras.preprocessing.image.img_to_array(image)
image_array = tf.expand_dims(image_array, axis=0)  # Add batch dimension

# Make prediction
predictions = rank_model.predict(image_array)
predicted_class = np.argmax(predictions, axis=1)
print("Predicted class:", classes[int(predicted_class)])
my_rank.append(classes[int(predicted_class)])
# Out:
# 1/1 [==============================] - 0s 49ms/step
# Predicted class: two

# %%
classes = ["ace", "eight", "five", "four", "jack", "king", "nine", "queen", "seven", "six", "ten", "three", "two"]

# File path to the image
# image_path = "C:\\Users\\jason\\ECE_479\\final_project_3\\PiCam images\\2d.png"
image_path = "cropped_image.jpg"
# Load and preprocess the image using TensorFlow
image = tf.keras.preprocessing.image.load_img(image_path, target_size=(img_height, img_width))
image_array = tf.keras.preprocessing.image.img_to_array(image)
image_array = tf.expand_dims(image_array, axis=0)  # Add batch dimension

# Make prediction
predictions = rank_model.predict(image_array)
predicted_class = np.argmax(predictions, axis=1)
print("Predicted class:", classes[int(predicted_class)])
my_rank.append(classes[int(predicted_class)])
# Out:
# 1/1 [==============================] - 0s 111ms/step
# Predicted class: three

# %%
print(my_rank)
# Out:
# ['two', 'three']

# %%
# import random

# def find_high_card(cards):
#     sorted_cards = sorted(cards, key=lambda x: '23456789TJQKA'.index(x[0]))
#     return sorted_cards[-1]

# def generate_random_cards(num_cards):
#     ranks = '23456789TJQKA'
#     suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
#     deck = [(rank, suit) for rank in ranks for suit in suits]
#     return random.sample(deck, num_cards)

# def print_combination(hand_type, winning_cards, winning_combination, high_card):
#     if hand_type == "Pair":
#         print("Combination: Pair of", winning_cards[0][0] + "s")
#     elif hand_type == "Two pair":
#         pair1_rank = winning_cards[0][0]
#         pair2_rank = winning_cards[2][0]
#         print("Combination: Two Pair")
#     elif hand_type == "Three of a kind":
#         print("Combination: Three of a Kind of", winning_cards[0][0] + "s")
#     elif hand_type == "Straight":
#         print("Combination: Straight")
#     elif hand_type == "Flush":
#         print("Combination: Flush")
#     elif hand_type == "Full house":
#         print("Combination: Full House")
#     elif hand_type == "Four of a kind":
#         print("Combination: Four of a Kind")
#     elif hand_type == "Straight flush":
#         print("Combination: Straight Flush")
#     elif hand_type == "Royal flush":
#         print("Combination: Royal Flush")
#     else:
#         print("Combination:", winning_combination)

# def predict_poker_hand(hand, table_cards):
#     all_cards = hand + table_cards
#     sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

#     suits = [card[1] for card in all_cards]
#     ranks = [card[0] for card in all_cards]

#     for suit in set(suits):
#         if suits.count(suit) >= 5:
#             flush_cards = [card for card in all_cards if card[1] == suit]
#             flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
#             if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
#                 if flush_sorted[-1][0] == 'A':
#                     return "Royal flush", None, "Royal Flush"
#                 else:
#                     return "Straight flush", None, "Straight Flush"

#     # Check for Straight
#     unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
#     straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
#     for i in range(len(unique_ranks) - 4):
#         if ''.join(unique_ranks[i:i+5]) in straight_ranks:
#             return "Straight", None, "Straight"

#     counts = [ranks.count(rank) for rank in set(ranks)]

#     if 4 in counts:  # Four of a kind
#         return "Four of a kind", None, "Four of a Kind"

#     if 3 in counts and 2 in counts:  # Full house
#         return "Full house", None, "Full House"

#     if 3 in counts:  # Three of a kind
#         three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
#         three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
#         return "Three of a kind", three_kind_cards, "Three of a Kind", find_high_card(three_kind_cards)

#     if counts.count(2) == 2:  # Two pair
#         two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
#         two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
#         return "Two pair", two_pair_cards, "Two Pair", find_high_card(two_pair_cards)

#     if counts.count(2) == 1:  # Pair
#         pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
#         pair_cards = [card for card in all_cards if card[0] in pair_rank]
#         return "Pair", pair_cards, "Pair", find_high_card(pair_cards)

#     high_card = find_high_card(all_cards)
#     return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

# hand = [('J', 'Spades'), ('8', 'Spades')]
# table_cards = [('4', 'Diamonds'), ('J', 'Clubs'), ('T', 'Hearts'), ('8', 'Clubs'), ('2', 'Spades')]

# result = predict_poker_hand(hand, table_cards)
# hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

# print_combination(hand_type, winning_cards, winning_combination, high_card)
# Out:
# Combination: Two Pair

# %%
# import random
# import itertools

# def generate_remaining_cards(initial_hand, table_cards):
#     ranks = '23456789TJQKA'
#     suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
#     deck = [(rank, suit) for rank in ranks for suit in suits]
    
#     remaining_cards = [card for card in deck if card not in initial_hand and card not in table_cards]
    
#     return remaining_cards

# def generate_hand_combinations(initial_hand, remaining_cards):
#     return itertools.combinations(remaining_cards, 2)

# def evaluate_hand_combinations(hand_combinations, table_cards):
#     evaluated_hands = []
#     for hand_combination in hand_combinations:
#         hand = list(hand_combination)
#         result = predict_poker_hand(hand, table_cards)
#         hand_type = result[0]
#         evaluated_hands.append((hand, hand_type))
    
#     # Sort hands based on their ranks
#     evaluated_hands.sort(key=lambda x: hand_ranking.index(x[1]))
    
#     return evaluated_hands

# hand_ranking = [
#     "Royal flush",
#     "Straight flush",
#     "Four of a kind",
#     "Full house",
#     "Flush",
#     "Straight",
#     "Three of a kind",
#     "Two pair",
#     "Pair",
#     "High card"
# ]

# # Function to print the combination
# def print_combination(hand_type, winning_cards, winning_combination, high_card):
#     if hand_type == "Pair":
#         print("Combination: Pair of", winning_cards[0][0] + "s")
#     elif hand_type == "Two pair":
#         pair1_rank = winning_cards[0][0]
#         pair2_rank = winning_cards[2][0]
#         print("Combination: Two Pair")
#     # Add more elif blocks for other combinations
#     else:
#         print("Combination:", winning_combination)

# def predict_poker_hand(hand, table_cards):
#     all_cards = hand + table_cards
#     sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

#     suits = [card[1] for card in all_cards]
#     ranks = [card[0] for card in all_cards]

#     for suit in set(suits):
#         if suits.count(suit) >= 5:
#             flush_cards = [card for card in all_cards if card[1] == suit]
#             flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
#             if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
#                 if flush_sorted[-1][0] == 'A':
#                     return "Royal flush", None, "Royal Flush"
#                 else:
#                     return "Straight flush", None, "Straight Flush"

#     # Check for Straight
#     unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
#     straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
#     for i in range(len(unique_ranks) - 4):
#         if ''.join(unique_ranks[i:i+5]) in straight_ranks:
#             return "Straight", None, "Straight"

#     # Rest
#     counts = [ranks.count(rank) for rank in set(ranks)]

#     if 4 in counts: 
#         return "Four of a kind", None, "Four of a Kind"

#     if 3 in counts and 2 in counts:
#         return "Full house", None, "Full House"

#     if 3 in counts:  
#         three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
#         three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
#         return "Three of a kind", three_kind_cards, "Three of a Kind"

#     if counts.count(2) == 2: 
#         two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
#         two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
#         return "Two pair", two_pair_cards, "Two Pair"

#     if counts.count(2) == 1:  
#         pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
#         pair_cards = [card for card in all_cards if card[0] in pair_rank]
#         return "Pair", pair_cards, "Pair"

#     high_card = find_high_card(all_cards)
#     return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

# # Previous hand and table cards
# hand = [('J', 'Spades'), ('8', 'Spades')]
# table_cards = [('4', 'Diamonds'), ('J', 'Clubs'), ('T', 'Hearts'), ('8', 'Clubs'), ('2', 'Spades')]

# result = predict_poker_hand(hand, table_cards)
# hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

# print_combination(hand_type, winning_cards, winning_combination, high_card)

# # Generate remaining cards and hand combinations
# remaining_cards = generate_remaining_cards(hand, table_cards)
# hand_combinations = generate_hand_combinations(hand, remaining_cards)
# evaluated_hands = evaluate_hand_combinations(hand_combinations, table_cards)

# print("Ranking of other hand combinations:")
# for i, (hand, hand_type) in enumerate(evaluated_hands, 1):
#     print(i, ":", hand_type, "-", hand)
# Out:
# Combination: Two Pair
# Ranking of other hand combinations:
# 1 : Straight - [('7', 'Spades'), ('9', 'Spades')]
# 2 : Straight - [('7', 'Spades'), ('9', 'Hearts')]
# 3 : Straight - [('7', 'Spades'), ('9', 'Diamonds')]
# 4 : Straight - [('7', 'Spades'), ('9', 'Clubs')]
# 5 : Straight - [('7', 'Hearts'), ('9', 'Spades')]
# 6 : Straight - [('7', 'Hearts'), ('9', 'Hearts')]
# 7 : Straight - [('7', 'Hearts'), ('9', 'Diamonds')]
# 8 : Straight - [('7', 'Hearts'), ('9', 'Clubs')]
# 9 : Straight - [('7', 'Diamonds'), ('9', 'Spades')]
# 10 : Straight - [('7', 'Diamonds'), ('9', 'Hearts')]
# 11 : Straight - [('7', 'Diamonds'), ('9', 'Diamonds')]
# 12 : Straight - [('7', 'Diamonds'), ('9', 'Clubs')]
# 13 : Straight - [('7', 'Clubs'), ('9', 'Spades')]
# 14 : Straight - [('7', 'Clubs'), ('9', 'Hearts')]
# 15 : Straight - [('7', 'Clubs'), ('9', 'Diamonds')]
# 16 : Straight - [('7', 'Clubs'), ('9', 'Clubs')]
# 17 : Straight - [('9', 'Spades'), ('Q', 'Spades')]
# 18 : Straight - [('9', 'Spades'), ('Q', 'Hearts')]
# 19 : Straight - [('9', 'Spades'), ('Q', 'Diamonds')]
# 20 : Straight - [('9', 'Spades'), ('Q', 'Clubs')]
# 21 : Straight - [('9', 'Hearts'), ('Q', 'Spades')]
# 22 : Straight - [('9', 'Hearts'), ('Q', 'Hearts')]
# 23 : Straight - [('9', 'Hearts'), ('Q', 'Diamonds')]
# 24 : Straight - [('9', 'Hearts'), ('Q', 'Clubs')]
# 25 : Straight - [('9', 'Diamonds'), ('Q', 'Spades')]
# 26 : Straight - [('9', 'Diamonds'), ('Q', 'Hearts')]
# 27 : Straight - [('9', 'Diamonds'), ('Q', 'Diamonds')]
# 28 : Straight - [('9', 'Diamonds'), ('Q', 'Clubs')]
# 29 : Straight - [('9', 'Clubs'), ('Q', 'Spades')]
# 30 : Straight - [('9', 'Clubs'), ('Q', 'Hearts')]
# 31 : Straight - [('9', 'Clubs'), ('Q', 'Diamonds')]
# 32 : Straight - [('9', 'Clubs'), ('Q', 'Clubs')]
# 33 : Three of a kind - [('2', 'Hearts'), ('2', 'Diamonds')]
# 34 : Three of a kind - [('2', 'Hearts'), ('2', 'Clubs')]
# 35 : Three of a kind - [('2', 'Diamonds'), ('2', 'Clubs')]
# 36 : Three of a kind - [('4', 'Spades'), ('4', 'Hearts')]
# 37 : Three of a kind - [('4', 'Spades'), ('4', 'Clubs')]
# 38 : Three of a kind - [('4', 'Hearts'), ('4', 'Clubs')]
# 39 : Three of a kind - [('8', 'Hearts'), ('8', 'Diamonds')]
# 40 : Three of a kind - [('T', 'Spades'), ('T', 'Diamonds')]
# 41 : Three of a kind - [('T', 'Spades'), ('T', 'Clubs')]
# 42 : Three of a kind - [('T', 'Diamonds'), ('T', 'Clubs')]
# 43 : Three of a kind - [('J', 'Hearts'), ('J', 'Diamonds')]
# 44 : Two pair - [('2', 'Hearts'), ('4', 'Spades')]
# 45 : Two pair - [('2', 'Hearts'), ('4', 'Hearts')]
# 46 : Two pair - [('2', 'Hearts'), ('4', 'Clubs')]
# 47 : Two pair - [('2', 'Hearts'), ('8', 'Hearts')]
# 48 : Two pair - [('2', 'Hearts'), ('8', 'Diamonds')]
# 49 : Two pair - [('2', 'Hearts'), ('T', 'Spades')]
# 50 : Two pair - [('2', 'Hearts'), ('T', 'Diamonds')]
# 51 : Two pair - [('2', 'Hearts'), ('T', 'Clubs')]
# 52 : Two pair - [('2', 'Hearts'), ('J', 'Hearts')]
# 53 : Two pair - [('2', 'Hearts'), ('J', 'Diamonds')]
# 54 : Two pair - [('2', 'Diamonds'), ('4', 'Spades')]
# 55 : Two pair - [('2', 'Diamonds'), ('4', 'Hearts')]
# 56 : Two pair - [('2', 'Diamonds'), ('4', 'Clubs')]
# 57 : Two pair - [('2', 'Diamonds'), ('8', 'Hearts')]
# 58 : Two pair - [('2', 'Diamonds'), ('8', 'Diamonds')]
# 59 : Two pair - [('2', 'Diamonds'), ('T', 'Spades')]
# 60 : Two pair - [('2', 'Diamonds'), ('T', 'Diamonds')]
# 61 : Two pair - [('2', 'Diamonds'), ('T', 'Clubs')]
# 62 : Two pair - [('2', 'Diamonds'), ('J', 'Hearts')]
# 63 : Two pair - [('2', 'Diamonds'), ('J', 'Diamonds')]
# 64 : Two pair - [('2', 'Clubs'), ('4', 'Spades')]
# 65 : Two pair - [('2', 'Clubs'), ('4', 'Hearts')]
# 66 : Two pair - [('2', 'Clubs'), ('4', 'Clubs')]
# 67 : Two pair - [('2', 'Clubs'), ('8', 'Hearts')]
# 68 : Two pair - [('2', 'Clubs'), ('8', 'Diamonds')]
# 69 : Two pair - [('2', 'Clubs'), ('T', 'Spades')]
# 70 : Two pair - [('2', 'Clubs'), ('T', 'Diamonds')]
# 71 : Two pair - [('2', 'Clubs'), ('T', 'Clubs')]
# 72 : Two pair - [('2', 'Clubs'), ('J', 'Hearts')]
# 73 : Two pair - [('2', 'Clubs'), ('J', 'Diamonds')]
# 74 : Two pair - [('4', 'Spades'), ('8', 'Hearts')]
# 75 : Two pair - [('4', 'Spades'), ('8', 'Diamonds')]
# 76 : Two pair - [('4', 'Spades'), ('T', 'Spades')]
# 77 : Two pair - [('4', 'Spades'), ('T', 'Diamonds')]
# 78 : Two pair - [('4', 'Spades'), ('T', 'Clubs')]
# 79 : Two pair - [('4', 'Spades'), ('J', 'Hearts')]
# 80 : Two pair - [('4', 'Spades'), ('J', 'Diamonds')]
# 81 : Two pair - [('4', 'Hearts'), ('8', 'Hearts')]
# 82 : Two pair - [('4', 'Hearts'), ('8', 'Diamonds')]
# 83 : Two pair - [('4', 'Hearts'), ('T', 'Spades')]
# 84 : Two pair - [('4', 'Hearts'), ('T', 'Diamonds')]
# 85 : Two pair - [('4', 'Hearts'), ('T', 'Clubs')]
# 86 : Two pair - [('4', 'Hearts'), ('J', 'Hearts')]
# 87 : Two pair - [('4', 'Hearts'), ('J', 'Diamonds')]
# 88 : Two pair - [('4', 'Clubs'), ('8', 'Hearts')]
# 89 : Two pair - [('4', 'Clubs'), ('8', 'Diamonds')]
# 90 : Two pair - [('4', 'Clubs'), ('T', 'Spades')]
# 91 : Two pair - [('4', 'Clubs'), ('T', 'Diamonds')]
# 92 : Two pair - [('4', 'Clubs'), ('T', 'Clubs')]
# 93 : Two pair - [('4', 'Clubs'), ('J', 'Hearts')]
# 94 : Two pair - [('4', 'Clubs'), ('J', 'Diamonds')]
# 95 : Two pair - [('8', 'Hearts'), ('T', 'Spades')]
# 96 : Two pair - [('8', 'Hearts'), ('T', 'Diamonds')]
# 97 : Two pair - [('8', 'Hearts'), ('T', 'Clubs')]
# 98 : Two pair - [('8', 'Hearts'), ('J', 'Hearts')]
# 99 : Two pair - [('8', 'Hearts'), ('J', 'Diamonds')]
# 100 : Two pair - [('8', 'Diamonds'), ('T', 'Spades')]
# 101 : Two pair - [('8', 'Diamonds'), ('T', 'Diamonds')]
# 102 : Two pair - [('8', 'Diamonds'), ('T', 'Clubs')]
# 103 : Two pair - [('8', 'Diamonds'), ('J', 'Hearts')]
# 104 : Two pair - [('8', 'Diamonds'), ('J', 'Diamonds')]
# 105 : Two pair - [('T', 'Spades'), ('J', 'Hearts')]
# 106 : Two pair - [('T', 'Spades'), ('J', 'Diamonds')]
# 107 : Two pair - [('T', 'Diamonds'), ('J', 'Hearts')]
# 108 : Two pair - [('T', 'Diamonds'), ('J', 'Diamonds')]
# 109 : Two pair - [('T', 'Clubs'), ('J', 'Hearts')]
# 110 : Two pair - [('T', 'Clubs'), ('J', 'Diamonds')]
# 111 : Pair - [('2', 'Hearts'), ('3', 'Spades')]
# 112 : Pair - [('2', 'Hearts'), ('3', 'Hearts')]
# 113 : Pair - [('2', 'Hearts'), ('3', 'Diamonds')]
# 114 : Pair - [('2', 'Hearts'), ('3', 'Clubs')]
# 115 : Pair - [('2', 'Hearts'), ('5', 'Spades')]
# 116 : Pair - [('2', 'Hearts'), ('5', 'Hearts')]
# 117 : Pair - [('2', 'Hearts'), ('5', 'Diamonds')]
# 118 : Pair - [('2', 'Hearts'), ('5', 'Clubs')]
# 119 : Pair - [('2', 'Hearts'), ('6', 'Spades')]
# 120 : Pair - [('2', 'Hearts'), ('6', 'Hearts')]
# 121 : Pair - [('2', 'Hearts'), ('6', 'Diamonds')]
# 122 : Pair - [('2', 'Hearts'), ('6', 'Clubs')]
# 123 : Pair - [('2', 'Hearts'), ('7', 'Spades')]
# 124 : Pair - [('2', 'Hearts'), ('7', 'Hearts')]
# 125 : Pair - [('2', 'Hearts'), ('7', 'Diamonds')]
# 126 : Pair - [('2', 'Hearts'), ('7', 'Clubs')]
# 127 : Pair - [('2', 'Hearts'), ('9', 'Spades')]
# 128 : Pair - [('2', 'Hearts'), ('9', 'Hearts')]
# 129 : Pair - [('2', 'Hearts'), ('9', 'Diamonds')]
# 130 : Pair - [('2', 'Hearts'), ('9', 'Clubs')]
# 131 : Pair - [('2', 'Hearts'), ('Q', 'Spades')]
# 132 : Pair - [('2', 'Hearts'), ('Q', 'Hearts')]
# 133 : Pair - [('2', 'Hearts'), ('Q', 'Diamonds')]
# 134 : Pair - [('2', 'Hearts'), ('Q', 'Clubs')]
# 135 : Pair - [('2', 'Hearts'), ('K', 'Spades')]
# 136 : Pair - [('2', 'Hearts'), ('K', 'Hearts')]
# 137 : Pair - [('2', 'Hearts'), ('K', 'Diamonds')]
# 138 : Pair - [('2', 'Hearts'), ('K', 'Clubs')]
# 139 : Pair - [('2', 'Hearts'), ('A', 'Spades')]
# 140 : Pair - [('2', 'Hearts'), ('A', 'Hearts')]
# 141 : Pair - [('2', 'Hearts'), ('A', 'Diamonds')]
# 142 : Pair - [('2', 'Hearts'), ('A', 'Clubs')]
# 143 : Pair - [('2', 'Diamonds'), ('3', 'Spades')]
# 144 : Pair - [('2', 'Diamonds'), ('3', 'Hearts')]
# 145 : Pair - [('2', 'Diamonds'), ('3', 'Diamonds')]
# 146 : Pair - [('2', 'Diamonds'), ('3', 'Clubs')]
# 147 : Pair - [('2', 'Diamonds'), ('5', 'Spades')]
# 148 : Pair - [('2', 'Diamonds'), ('5', 'Hearts')]
# 149 : Pair - [('2', 'Diamonds'), ('5', 'Diamonds')]
# 150 : Pair - [('2', 'Diamonds'), ('5', 'Clubs')]
# 151 : Pair - [('2', 'Diamonds'), ('6', 'Spades')]
# 152 : Pair - [('2', 'Diamonds'), ('6', 'Hearts')]
# 153 : Pair - [('2', 'Diamonds'), ('6', 'Diamonds')]
# 154 : Pair - [('2', 'Diamonds'), ('6', 'Clubs')]
# 155 : Pair - [('2', 'Diamonds'), ('7', 'Spades')]
# 156 : Pair - [('2', 'Diamonds'), ('7', 'Hearts')]
# 157 : Pair - [('2', 'Diamonds'), ('7', 'Diamonds')]
# 158 : Pair - [('2', 'Diamonds'), ('7', 'Clubs')]
# 159 : Pair - [('2', 'Diamonds'), ('9', 'Spades')]
# 160 : Pair - [('2', 'Diamonds'), ('9', 'Hearts')]
# 161 : Pair - [('2', 'Diamonds'), ('9', 'Diamonds')]
# 162 : Pair - [('2', 'Diamonds'), ('9', 'Clubs')]
# 163 : Pair - [('2', 'Diamonds'), ('Q', 'Spades')]
# 164 : Pair - [('2', 'Diamonds'), ('Q', 'Hearts')]
# 165 : Pair - [('2', 'Diamonds'), ('Q', 'Diamonds')]
# 166 : Pair - [('2', 'Diamonds'), ('Q', 'Clubs')]
# 167 : Pair - [('2', 'Diamonds'), ('K', 'Spades')]
# 168 : Pair - [('2', 'Diamonds'), ('K', 'Hearts')]
# 169 : Pair - [('2', 'Diamonds'), ('K', 'Diamonds')]
# 170 : Pair - [('2', 'Diamonds'), ('K', 'Clubs')]
# 171 : Pair - [('2', 'Diamonds'), ('A', 'Spades')]
# 172 : Pair - [('2', 'Diamonds'), ('A', 'Hearts')]
# 173 : Pair - [('2', 'Diamonds'), ('A', 'Diamonds')]
# 174 : Pair - [('2', 'Diamonds'), ('A', 'Clubs')]
# 175 : Pair - [('2', 'Clubs'), ('3', 'Spades')]
# 176 : Pair - [('2', 'Clubs'), ('3', 'Hearts')]
# 177 : Pair - [('2', 'Clubs'), ('3', 'Diamonds')]
# 178 : Pair - [('2', 'Clubs'), ('3', 'Clubs')]
# 179 : Pair - [('2', 'Clubs'), ('5', 'Spades')]
# 180 : Pair - [('2', 'Clubs'), ('5', 'Hearts')]
# 181 : Pair - [('2', 'Clubs'), ('5', 'Diamonds')]
# 182 : Pair - [('2', 'Clubs'), ('5', 'Clubs')]
# 183 : Pair - [('2', 'Clubs'), ('6', 'Spades')]
# 184 : Pair - [('2', 'Clubs'), ('6', 'Hearts')]
# 185 : Pair - [('2', 'Clubs'), ('6', 'Diamonds')]
# 186 : Pair - [('2', 'Clubs'), ('6', 'Clubs')]
# 187 : Pair - [('2', 'Clubs'), ('7', 'Spades')]
# 188 : Pair - [('2', 'Clubs'), ('7', 'Hearts')]
# 189 : Pair - [('2', 'Clubs'), ('7', 'Diamonds')]
# 190 : Pair - [('2', 'Clubs'), ('7', 'Clubs')]
# 191 : Pair - [('2', 'Clubs'), ('9', 'Spades')]
# 192 : Pair - [('2', 'Clubs'), ('9', 'Hearts')]
# 193 : Pair - [('2', 'Clubs'), ('9', 'Diamonds')]
# 194 : Pair - [('2', 'Clubs'), ('9', 'Clubs')]
# 195 : Pair - [('2', 'Clubs'), ('Q', 'Spades')]
# 196 : Pair - [('2', 'Clubs'), ('Q', 'Hearts')]
# 197 : Pair - [('2', 'Clubs'), ('Q', 'Diamonds')]
# 198 : Pair - [('2', 'Clubs'), ('Q', 'Clubs')]
# 199 : Pair - [('2', 'Clubs'), ('K', 'Spades')]
# 200 : Pair - [('2', 'Clubs'), ('K', 'Hearts')]
# 201 : Pair - [('2', 'Clubs'), ('K', 'Diamonds')]
# 202 : Pair - [('2', 'Clubs'), ('K', 'Clubs')]
# 203 : Pair - [('2', 'Clubs'), ('A', 'Spades')]
# 204 : Pair - [('2', 'Clubs'), ('A', 'Hearts')]
# 205 : Pair - [('2', 'Clubs'), ('A', 'Diamonds')]
# 206 : Pair - [('2', 'Clubs'), ('A', 'Clubs')]
# 207 : Pair - [('3', 'Spades'), ('3', 'Hearts')]
# 208 : Pair - [('3', 'Spades'), ('3', 'Diamonds')]
# 209 : Pair - [('3', 'Spades'), ('3', 'Clubs')]
# 210 : Pair - [('3', 'Spades'), ('4', 'Spades')]
# 211 : Pair - [('3', 'Spades'), ('4', 'Hearts')]
# 212 : Pair - [('3', 'Spades'), ('4', 'Clubs')]
# 213 : Pair - [('3', 'Spades'), ('8', 'Hearts')]
# 214 : Pair - [('3', 'Spades'), ('8', 'Diamonds')]
# 215 : Pair - [('3', 'Spades'), ('T', 'Spades')]
# 216 : Pair - [('3', 'Spades'), ('T', 'Diamonds')]
# 217 : Pair - [('3', 'Spades'), ('T', 'Clubs')]
# 218 : Pair - [('3', 'Spades'), ('J', 'Hearts')]
# 219 : Pair - [('3', 'Spades'), ('J', 'Diamonds')]
# 220 : Pair - [('3', 'Hearts'), ('3', 'Diamonds')]
# 221 : Pair - [('3', 'Hearts'), ('3', 'Clubs')]
# 222 : Pair - [('3', 'Hearts'), ('4', 'Spades')]
# 223 : Pair - [('3', 'Hearts'), ('4', 'Hearts')]
# 224 : Pair - [('3', 'Hearts'), ('4', 'Clubs')]
# 225 : Pair - [('3', 'Hearts'), ('8', 'Hearts')]
# 226 : Pair - [('3', 'Hearts'), ('8', 'Diamonds')]
# 227 : Pair - [('3', 'Hearts'), ('T', 'Spades')]
# 228 : Pair - [('3', 'Hearts'), ('T', 'Diamonds')]
# 229 : Pair - [('3', 'Hearts'), ('T', 'Clubs')]
# 230 : Pair - [('3', 'Hearts'), ('J', 'Hearts')]
# 231 : Pair - [('3', 'Hearts'), ('J', 'Diamonds')]
# 232 : Pair - [('3', 'Diamonds'), ('3', 'Clubs')]
# 233 : Pair - [('3', 'Diamonds'), ('4', 'Spades')]
# 234 : Pair - [('3', 'Diamonds'), ('4', 'Hearts')]
# 235 : Pair - [('3', 'Diamonds'), ('4', 'Clubs')]
# 236 : Pair - [('3', 'Diamonds'), ('8', 'Hearts')]
# 237 : Pair - [('3', 'Diamonds'), ('8', 'Diamonds')]
# 238 : Pair - [('3', 'Diamonds'), ('T', 'Spades')]
# 239 : Pair - [('3', 'Diamonds'), ('T', 'Diamonds')]
# 240 : Pair - [('3', 'Diamonds'), ('T', 'Clubs')]
# 241 : Pair - [('3', 'Diamonds'), ('J', 'Hearts')]
# 242 : Pair - [('3', 'Diamonds'), ('J', 'Diamonds')]
# 243 : Pair - [('3', 'Clubs'), ('4', 'Spades')]
# 244 : Pair - [('3', 'Clubs'), ('4', 'Hearts')]
# 245 : Pair - [('3', 'Clubs'), ('4', 'Clubs')]
# 246 : Pair - [('3', 'Clubs'), ('8', 'Hearts')]
# 247 : Pair - [('3', 'Clubs'), ('8', 'Diamonds')]
# 248 : Pair - [('3', 'Clubs'), ('T', 'Spades')]
# 249 : Pair - [('3', 'Clubs'), ('T', 'Diamonds')]
# 250 : Pair - [('3', 'Clubs'), ('T', 'Clubs')]
# 251 : Pair - [('3', 'Clubs'), ('J', 'Hearts')]
# 252 : Pair - [('3', 'Clubs'), ('J', 'Diamonds')]
# 253 : Pair - [('4', 'Spades'), ('5', 'Spades')]
# 254 : Pair - [('4', 'Spades'), ('5', 'Hearts')]
# 255 : Pair - [('4', 'Spades'), ('5', 'Diamonds')]
# 256 : Pair - [('4', 'Spades'), ('5', 'Clubs')]
# 257 : Pair - [('4', 'Spades'), ('6', 'Spades')]
# 258 : Pair - [('4', 'Spades'), ('6', 'Hearts')]
# 259 : Pair - [('4', 'Spades'), ('6', 'Diamonds')]
# 260 : Pair - [('4', 'Spades'), ('6', 'Clubs')]
# 261 : Pair - [('4', 'Spades'), ('7', 'Spades')]
# 262 : Pair - [('4', 'Spades'), ('7', 'Hearts')]
# 263 : Pair - [('4', 'Spades'), ('7', 'Diamonds')]
# 264 : Pair - [('4', 'Spades'), ('7', 'Clubs')]
# 265 : Pair - [('4', 'Spades'), ('9', 'Spades')]
# 266 : Pair - [('4', 'Spades'), ('9', 'Hearts')]
# 267 : Pair - [('4', 'Spades'), ('9', 'Diamonds')]
# 268 : Pair - [('4', 'Spades'), ('9', 'Clubs')]
# 269 : Pair - [('4', 'Spades'), ('Q', 'Spades')]
# 270 : Pair - [('4', 'Spades'), ('Q', 'Hearts')]
# 271 : Pair - [('4', 'Spades'), ('Q', 'Diamonds')]
# 272 : Pair - [('4', 'Spades'), ('Q', 'Clubs')]
# 273 : Pair - [('4', 'Spades'), ('K', 'Spades')]
# 274 : Pair - [('4', 'Spades'), ('K', 'Hearts')]
# 275 : Pair - [('4', 'Spades'), ('K', 'Diamonds')]
# 276 : Pair - [('4', 'Spades'), ('K', 'Clubs')]
# 277 : Pair - [('4', 'Spades'), ('A', 'Spades')]
# 278 : Pair - [('4', 'Spades'), ('A', 'Hearts')]
# 279 : Pair - [('4', 'Spades'), ('A', 'Diamonds')]
# 280 : Pair - [('4', 'Spades'), ('A', 'Clubs')]
# 281 : Pair - [('4', 'Hearts'), ('5', 'Spades')]
# 282 : Pair - [('4', 'Hearts'), ('5', 'Hearts')]
# 283 : Pair - [('4', 'Hearts'), ('5', 'Diamonds')]
# 284 : Pair - [('4', 'Hearts'), ('5', 'Clubs')]
# 285 : Pair - [('4', 'Hearts'), ('6', 'Spades')]
# 286 : Pair - [('4', 'Hearts'), ('6', 'Hearts')]
# 287 : Pair - [('4', 'Hearts'), ('6', 'Diamonds')]
# 288 : Pair - [('4', 'Hearts'), ('6', 'Clubs')]
# 289 : Pair - [('4', 'Hearts'), ('7', 'Spades')]
# 290 : Pair - [('4', 'Hearts'), ('7', 'Hearts')]
# 291 : Pair - [('4', 'Hearts'), ('7', 'Diamonds')]
# 292 : Pair - [('4', 'Hearts'), ('7', 'Clubs')]
# 293 : Pair - [('4', 'Hearts'), ('9', 'Spades')]
# 294 : Pair - [('4', 'Hearts'), ('9', 'Hearts')]
# 295 : Pair - [('4', 'Hearts'), ('9', 'Diamonds')]
# 296 : Pair - [('4', 'Hearts'), ('9', 'Clubs')]
# 297 : Pair - [('4', 'Hearts'), ('Q', 'Spades')]
# 298 : Pair - [('4', 'Hearts'), ('Q', 'Hearts')]
# 299 : Pair - [('4', 'Hearts'), ('Q', 'Diamonds')]
# 300 : Pair - [('4', 'Hearts'), ('Q', 'Clubs')]
# 301 : Pair - [('4', 'Hearts'), ('K', 'Spades')]
# 302 : Pair - [('4', 'Hearts'), ('K', 'Hearts')]
# 303 : Pair - [('4', 'Hearts'), ('K', 'Diamonds')]
# 304 : Pair - [('4', 'Hearts'), ('K', 'Clubs')]
# 305 : Pair - [('4', 'Hearts'), ('A', 'Spades')]
# 306 : Pair - [('4', 'Hearts'), ('A', 'Hearts')]
# 307 : Pair - [('4', 'Hearts'), ('A', 'Diamonds')]
# 308 : Pair - [('4', 'Hearts'), ('A', 'Clubs')]
# 309 : Pair - [('4', 'Clubs'), ('5', 'Spades')]
# 310 : Pair - [('4', 'Clubs'), ('5', 'Hearts')]
# 311 : Pair - [('4', 'Clubs'), ('5', 'Diamonds')]
# 312 : Pair - [('4', 'Clubs'), ('5', 'Clubs')]
# 313 : Pair - [('4', 'Clubs'), ('6', 'Spades')]
# 314 : Pair - [('4', 'Clubs'), ('6', 'Hearts')]
# 315 : Pair - [('4', 'Clubs'), ('6', 'Diamonds')]
# 316 : Pair - [('4', 'Clubs'), ('6', 'Clubs')]
# 317 : Pair - [('4', 'Clubs'), ('7', 'Spades')]
# 318 : Pair - [('4', 'Clubs'), ('7', 'Hearts')]
# 319 : Pair - [('4', 'Clubs'), ('7', 'Diamonds')]
# 320 : Pair - [('4', 'Clubs'), ('7', 'Clubs')]
# 321 : Pair - [('4', 'Clubs'), ('9', 'Spades')]
# 322 : Pair - [('4', 'Clubs'), ('9', 'Hearts')]
# 323 : Pair - [('4', 'Clubs'), ('9', 'Diamonds')]
# 324 : Pair - [('4', 'Clubs'), ('9', 'Clubs')]
# 325 : Pair - [('4', 'Clubs'), ('Q', 'Spades')]
# 326 : Pair - [('4', 'Clubs'), ('Q', 'Hearts')]
# 327 : Pair - [('4', 'Clubs'), ('Q', 'Diamonds')]
# 328 : Pair - [('4', 'Clubs'), ('Q', 'Clubs')]
# 329 : Pair - [('4', 'Clubs'), ('K', 'Spades')]
# 330 : Pair - [('4', 'Clubs'), ('K', 'Hearts')]
# 331 : Pair - [('4', 'Clubs'), ('K', 'Diamonds')]
# 332 : Pair - [('4', 'Clubs'), ('K', 'Clubs')]
# 333 : Pair - [('4', 'Clubs'), ('A', 'Spades')]
# 334 : Pair - [('4', 'Clubs'), ('A', 'Hearts')]
# 335 : Pair - [('4', 'Clubs'), ('A', 'Diamonds')]
# 336 : Pair - [('4', 'Clubs'), ('A', 'Clubs')]
# 337 : Pair - [('5', 'Spades'), ('5', 'Hearts')]
# 338 : Pair - [('5', 'Spades'), ('5', 'Diamonds')]
# 339 : Pair - [('5', 'Spades'), ('5', 'Clubs')]
# 340 : Pair - [('5', 'Spades'), ('8', 'Hearts')]
# 341 : Pair - [('5', 'Spades'), ('8', 'Diamonds')]
# 342 : Pair - [('5', 'Spades'), ('T', 'Spades')]
# 343 : Pair - [('5', 'Spades'), ('T', 'Diamonds')]
# 344 : Pair - [('5', 'Spades'), ('T', 'Clubs')]
# 345 : Pair - [('5', 'Spades'), ('J', 'Hearts')]
# 346 : Pair - [('5', 'Spades'), ('J', 'Diamonds')]
# 347 : Pair - [('5', 'Hearts'), ('5', 'Diamonds')]
# 348 : Pair - [('5', 'Hearts'), ('5', 'Clubs')]
# 349 : Pair - [('5', 'Hearts'), ('8', 'Hearts')]
# 350 : Pair - [('5', 'Hearts'), ('8', 'Diamonds')]
# 351 : Pair - [('5', 'Hearts'), ('T', 'Spades')]
# 352 : Pair - [('5', 'Hearts'), ('T', 'Diamonds')]
# 353 : Pair - [('5', 'Hearts'), ('T', 'Clubs')]
# 354 : Pair - [('5', 'Hearts'), ('J', 'Hearts')]
# 355 : Pair - [('5', 'Hearts'), ('J', 'Diamonds')]
# 356 : Pair - [('5', 'Diamonds'), ('5', 'Clubs')]
# 357 : Pair - [('5', 'Diamonds'), ('8', 'Hearts')]
# 358 : Pair - [('5', 'Diamonds'), ('8', 'Diamonds')]
# 359 : Pair - [('5', 'Diamonds'), ('T', 'Spades')]
# 360 : Pair - [('5', 'Diamonds'), ('T', 'Diamonds')]
# 361 : Pair - [('5', 'Diamonds'), ('T', 'Clubs')]
# 362 : Pair - [('5', 'Diamonds'), ('J', 'Hearts')]
# 363 : Pair - [('5', 'Diamonds'), ('J', 'Diamonds')]
# 364 : Pair - [('5', 'Clubs'), ('8', 'Hearts')]
# 365 : Pair - [('5', 'Clubs'), ('8', 'Diamonds')]
# 366 : Pair - [('5', 'Clubs'), ('T', 'Spades')]
# 367 : Pair - [('5', 'Clubs'), ('T', 'Diamonds')]
# 368 : Pair - [('5', 'Clubs'), ('T', 'Clubs')]
# 369 : Pair - [('5', 'Clubs'), ('J', 'Hearts')]
# 370 : Pair - [('5', 'Clubs'), ('J', 'Diamonds')]
# 371 : Pair - [('6', 'Spades'), ('6', 'Hearts')]
# 372 : Pair - [('6', 'Spades'), ('6', 'Diamonds')]
# 373 : Pair - [('6', 'Spades'), ('6', 'Clubs')]
# 374 : Pair - [('6', 'Spades'), ('8', 'Hearts')]
# 375 : Pair - [('6', 'Spades'), ('8', 'Diamonds')]
# 376 : Pair - [('6', 'Spades'), ('T', 'Spades')]
# 377 : Pair - [('6', 'Spades'), ('T', 'Diamonds')]
# 378 : Pair - [('6', 'Spades'), ('T', 'Clubs')]
# 379 : Pair - [('6', 'Spades'), ('J', 'Hearts')]
# 380 : Pair - [('6', 'Spades'), ('J', 'Diamonds')]
# 381 : Pair - [('6', 'Hearts'), ('6', 'Diamonds')]
# 382 : Pair - [('6', 'Hearts'), ('6', 'Clubs')]
# 383 : Pair - [('6', 'Hearts'), ('8', 'Hearts')]
# 384 : Pair - [('6', 'Hearts'), ('8', 'Diamonds')]
# 385 : Pair - [('6', 'Hearts'), ('T', 'Spades')]
# 386 : Pair - [('6', 'Hearts'), ('T', 'Diamonds')]
# 387 : Pair - [('6', 'Hearts'), ('T', 'Clubs')]
# 388 : Pair - [('6', 'Hearts'), ('J', 'Hearts')]
# 389 : Pair - [('6', 'Hearts'), ('J', 'Diamonds')]
# 390 : Pair - [('6', 'Diamonds'), ('6', 'Clubs')]
# 391 : Pair - [('6', 'Diamonds'), ('8', 'Hearts')]
# 392 : Pair - [('6', 'Diamonds'), ('8', 'Diamonds')]
# 393 : Pair - [('6', 'Diamonds'), ('T', 'Spades')]
# 394 : Pair - [('6', 'Diamonds'), ('T', 'Diamonds')]
# 395 : Pair - [('6', 'Diamonds'), ('T', 'Clubs')]
# 396 : Pair - [('6', 'Diamonds'), ('J', 'Hearts')]
# 397 : Pair - [('6', 'Diamonds'), ('J', 'Diamonds')]
# 398 : Pair - [('6', 'Clubs'), ('8', 'Hearts')]
# 399 : Pair - [('6', 'Clubs'), ('8', 'Diamonds')]
# 400 : Pair - [('6', 'Clubs'), ('T', 'Spades')]
# 401 : Pair - [('6', 'Clubs'), ('T', 'Diamonds')]
# 402 : Pair - [('6', 'Clubs'), ('T', 'Clubs')]
# 403 : Pair - [('6', 'Clubs'), ('J', 'Hearts')]
# 404 : Pair - [('6', 'Clubs'), ('J', 'Diamonds')]
# 405 : Pair - [('7', 'Spades'), ('7', 'Hearts')]
# 406 : Pair - [('7', 'Spades'), ('7', 'Diamonds')]
# 407 : Pair - [('7', 'Spades'), ('7', 'Clubs')]
# 408 : Pair - [('7', 'Spades'), ('8', 'Hearts')]
# 409 : Pair - [('7', 'Spades'), ('8', 'Diamonds')]
# 410 : Pair - [('7', 'Spades'), ('T', 'Spades')]
# 411 : Pair - [('7', 'Spades'), ('T', 'Diamonds')]
# 412 : Pair - [('7', 'Spades'), ('T', 'Clubs')]
# 413 : Pair - [('7', 'Spades'), ('J', 'Hearts')]
# 414 : Pair - [('7', 'Spades'), ('J', 'Diamonds')]
# 415 : Pair - [('7', 'Hearts'), ('7', 'Diamonds')]
# 416 : Pair - [('7', 'Hearts'), ('7', 'Clubs')]
# 417 : Pair - [('7', 'Hearts'), ('8', 'Hearts')]
# 418 : Pair - [('7', 'Hearts'), ('8', 'Diamonds')]
# 419 : Pair - [('7', 'Hearts'), ('T', 'Spades')]
# 420 : Pair - [('7', 'Hearts'), ('T', 'Diamonds')]
# 421 : Pair - [('7', 'Hearts'), ('T', 'Clubs')]
# 422 : Pair - [('7', 'Hearts'), ('J', 'Hearts')]
# 423 : Pair - [('7', 'Hearts'), ('J', 'Diamonds')]
# 424 : Pair - [('7', 'Diamonds'), ('7', 'Clubs')]
# 425 : Pair - [('7', 'Diamonds'), ('8', 'Hearts')]
# 426 : Pair - [('7', 'Diamonds'), ('8', 'Diamonds')]
# 427 : Pair - [('7', 'Diamonds'), ('T', 'Spades')]
# 428 : Pair - [('7', 'Diamonds'), ('T', 'Diamonds')]
# 429 : Pair - [('7', 'Diamonds'), ('T', 'Clubs')]
# 430 : Pair - [('7', 'Diamonds'), ('J', 'Hearts')]
# 431 : Pair - [('7', 'Diamonds'), ('J', 'Diamonds')]
# 432 : Pair - [('7', 'Clubs'), ('8', 'Hearts')]
# 433 : Pair - [('7', 'Clubs'), ('8', 'Diamonds')]
# 434 : Pair - [('7', 'Clubs'), ('T', 'Spades')]
# 435 : Pair - [('7', 'Clubs'), ('T', 'Diamonds')]
# 436 : Pair - [('7', 'Clubs'), ('T', 'Clubs')]
# 437 : Pair - [('7', 'Clubs'), ('J', 'Hearts')]
# 438 : Pair - [('7', 'Clubs'), ('J', 'Diamonds')]
# 439 : Pair - [('8', 'Hearts'), ('9', 'Spades')]
# 440 : Pair - [('8', 'Hearts'), ('9', 'Hearts')]
# 441 : Pair - [('8', 'Hearts'), ('9', 'Diamonds')]
# 442 : Pair - [('8', 'Hearts'), ('9', 'Clubs')]
# 443 : Pair - [('8', 'Hearts'), ('Q', 'Spades')]
# 444 : Pair - [('8', 'Hearts'), ('Q', 'Hearts')]
# 445 : Pair - [('8', 'Hearts'), ('Q', 'Diamonds')]
# 446 : Pair - [('8', 'Hearts'), ('Q', 'Clubs')]
# 447 : Pair - [('8', 'Hearts'), ('K', 'Spades')]
# 448 : Pair - [('8', 'Hearts'), ('K', 'Hearts')]
# 449 : Pair - [('8', 'Hearts'), ('K', 'Diamonds')]
# 450 : Pair - [('8', 'Hearts'), ('K', 'Clubs')]
# 451 : Pair - [('8', 'Hearts'), ('A', 'Spades')]
# 452 : Pair - [('8', 'Hearts'), ('A', 'Hearts')]
# 453 : Pair - [('8', 'Hearts'), ('A', 'Diamonds')]
# 454 : Pair - [('8', 'Hearts'), ('A', 'Clubs')]
# 455 : Pair - [('8', 'Diamonds'), ('9', 'Spades')]
# 456 : Pair - [('8', 'Diamonds'), ('9', 'Hearts')]
# 457 : Pair - [('8', 'Diamonds'), ('9', 'Diamonds')]
# 458 : Pair - [('8', 'Diamonds'), ('9', 'Clubs')]
# 459 : Pair - [('8', 'Diamonds'), ('Q', 'Spades')]
# 460 : Pair - [('8', 'Diamonds'), ('Q', 'Hearts')]
# 461 : Pair - [('8', 'Diamonds'), ('Q', 'Diamonds')]
# 462 : Pair - [('8', 'Diamonds'), ('Q', 'Clubs')]
# 463 : Pair - [('8', 'Diamonds'), ('K', 'Spades')]
# 464 : Pair - [('8', 'Diamonds'), ('K', 'Hearts')]
# 465 : Pair - [('8', 'Diamonds'), ('K', 'Diamonds')]
# 466 : Pair - [('8', 'Diamonds'), ('K', 'Clubs')]
# 467 : Pair - [('8', 'Diamonds'), ('A', 'Spades')]
# 468 : Pair - [('8', 'Diamonds'), ('A', 'Hearts')]
# 469 : Pair - [('8', 'Diamonds'), ('A', 'Diamonds')]
# 470 : Pair - [('8', 'Diamonds'), ('A', 'Clubs')]
# 471 : Pair - [('9', 'Spades'), ('9', 'Hearts')]
# 472 : Pair - [('9', 'Spades'), ('9', 'Diamonds')]
# 473 : Pair - [('9', 'Spades'), ('9', 'Clubs')]
# 474 : Pair - [('9', 'Spades'), ('T', 'Spades')]
# 475 : Pair - [('9', 'Spades'), ('T', 'Diamonds')]
# 476 : Pair - [('9', 'Spades'), ('T', 'Clubs')]
# 477 : Pair - [('9', 'Spades'), ('J', 'Hearts')]
# 478 : Pair - [('9', 'Spades'), ('J', 'Diamonds')]
# 479 : Pair - [('9', 'Hearts'), ('9', 'Diamonds')]
# 480 : Pair - [('9', 'Hearts'), ('9', 'Clubs')]
# 481 : Pair - [('9', 'Hearts'), ('T', 'Spades')]
# 482 : Pair - [('9', 'Hearts'), ('T', 'Diamonds')]
# 483 : Pair - [('9', 'Hearts'), ('T', 'Clubs')]
# 484 : Pair - [('9', 'Hearts'), ('J', 'Hearts')]
# 485 : Pair - [('9', 'Hearts'), ('J', 'Diamonds')]
# 486 : Pair - [('9', 'Diamonds'), ('9', 'Clubs')]
# 487 : Pair - [('9', 'Diamonds'), ('T', 'Spades')]
# 488 : Pair - [('9', 'Diamonds'), ('T', 'Diamonds')]
# 489 : Pair - [('9', 'Diamonds'), ('T', 'Clubs')]
# 490 : Pair - [('9', 'Diamonds'), ('J', 'Hearts')]
# 491 : Pair - [('9', 'Diamonds'), ('J', 'Diamonds')]
# 492 : Pair - [('9', 'Clubs'), ('T', 'Spades')]
# 493 : Pair - [('9', 'Clubs'), ('T', 'Diamonds')]
# 494 : Pair - [('9', 'Clubs'), ('T', 'Clubs')]
# 495 : Pair - [('9', 'Clubs'), ('J', 'Hearts')]
# 496 : Pair - [('9', 'Clubs'), ('J', 'Diamonds')]
# 497 : Pair - [('T', 'Spades'), ('Q', 'Spades')]
# 498 : Pair - [('T', 'Spades'), ('Q', 'Hearts')]
# 499 : Pair - [('T', 'Spades'), ('Q', 'Diamonds')]
# 500 : Pair - [('T', 'Spades'), ('Q', 'Clubs')]
# 501 : Pair - [('T', 'Spades'), ('K', 'Spades')]
# 502 : Pair - [('T', 'Spades'), ('K', 'Hearts')]
# 503 : Pair - [('T', 'Spades'), ('K', 'Diamonds')]
# 504 : Pair - [('T', 'Spades'), ('K', 'Clubs')]
# 505 : Pair - [('T', 'Spades'), ('A', 'Spades')]
# 506 : Pair - [('T', 'Spades'), ('A', 'Hearts')]
# 507 : Pair - [('T', 'Spades'), ('A', 'Diamonds')]
# 508 : Pair - [('T', 'Spades'), ('A', 'Clubs')]
# 509 : Pair - [('T', 'Diamonds'), ('Q', 'Spades')]
# 510 : Pair - [('T', 'Diamonds'), ('Q', 'Hearts')]
# 511 : Pair - [('T', 'Diamonds'), ('Q', 'Diamonds')]
# 512 : Pair - [('T', 'Diamonds'), ('Q', 'Clubs')]
# 513 : Pair - [('T', 'Diamonds'), ('K', 'Spades')]
# 514 : Pair - [('T', 'Diamonds'), ('K', 'Hearts')]
# 515 : Pair - [('T', 'Diamonds'), ('K', 'Diamonds')]
# 516 : Pair - [('T', 'Diamonds'), ('K', 'Clubs')]
# 517 : Pair - [('T', 'Diamonds'), ('A', 'Spades')]
# 518 : Pair - [('T', 'Diamonds'), ('A', 'Hearts')]
# 519 : Pair - [('T', 'Diamonds'), ('A', 'Diamonds')]
# 520 : Pair - [('T', 'Diamonds'), ('A', 'Clubs')]
# 521 : Pair - [('T', 'Clubs'), ('Q', 'Spades')]
# 522 : Pair - [('T', 'Clubs'), ('Q', 'Hearts')]
# 523 : Pair - [('T', 'Clubs'), ('Q', 'Diamonds')]
# 524 : Pair - [('T', 'Clubs'), ('Q', 'Clubs')]
# 525 : Pair - [('T', 'Clubs'), ('K', 'Spades')]
# 526 : Pair - [('T', 'Clubs'), ('K', 'Hearts')]
# 527 : Pair - [('T', 'Clubs'), ('K', 'Diamonds')]
# 528 : Pair - [('T', 'Clubs'), ('K', 'Clubs')]
# 529 : Pair - [('T', 'Clubs'), ('A', 'Spades')]
# 530 : Pair - [('T', 'Clubs'), ('A', 'Hearts')]
# 531 : Pair - [('T', 'Clubs'), ('A', 'Diamonds')]
# 532 : Pair - [('T', 'Clubs'), ('A', 'Clubs')]
# 533 : Pair - [('J', 'Hearts'), ('Q', 'Spades')]
# 534 : Pair - [('J', 'Hearts'), ('Q', 'Hearts')]
# 535 : Pair - [('J', 'Hearts'), ('Q', 'Diamonds')]
# 536 : Pair - [('J', 'Hearts'), ('Q', 'Clubs')]
# 537 : Pair - [('J', 'Hearts'), ('K', 'Spades')]
# 538 : Pair - [('J', 'Hearts'), ('K', 'Hearts')]
# 539 : Pair - [('J', 'Hearts'), ('K', 'Diamonds')]
# 540 : Pair - [('J', 'Hearts'), ('K', 'Clubs')]
# 541 : Pair - [('J', 'Hearts'), ('A', 'Spades')]
# 542 : Pair - [('J', 'Hearts'), ('A', 'Hearts')]
# 543 : Pair - [('J', 'Hearts'), ('A', 'Diamonds')]
# 544 : Pair - [('J', 'Hearts'), ('A', 'Clubs')]
# 545 : Pair - [('J', 'Diamonds'), ('Q', 'Spades')]
# 546 : Pair - [('J', 'Diamonds'), ('Q', 'Hearts')]
# 547 : Pair - [('J', 'Diamonds'), ('Q', 'Diamonds')]
# 548 : Pair - [('J', 'Diamonds'), ('Q', 'Clubs')]
# 549 : Pair - [('J', 'Diamonds'), ('K', 'Spades')]
# 550 : Pair - [('J', 'Diamonds'), ('K', 'Hearts')]
# 551 : Pair - [('J', 'Diamonds'), ('K', 'Diamonds')]
# 552 : Pair - [('J', 'Diamonds'), ('K', 'Clubs')]
# 553 : Pair - [('J', 'Diamonds'), ('A', 'Spades')]
# 554 : Pair - [('J', 'Diamonds'), ('A', 'Hearts')]
# 555 : Pair - [('J', 'Diamonds'), ('A', 'Diamonds')]
# 556 : Pair - [('J', 'Diamonds'), ('A', 'Clubs')]
# 557 : Pair - [('Q', 'Spades'), ('Q', 'Hearts')]
# 558 : Pair - [('Q', 'Spades'), ('Q', 'Diamonds')]
# 559 : Pair - [('Q', 'Spades'), ('Q', 'Clubs')]
# 560 : Pair - [('Q', 'Hearts'), ('Q', 'Diamonds')]
# 561 : Pair - [('Q', 'Hearts'), ('Q', 'Clubs')]
# 562 : Pair - [('Q', 'Diamonds'), ('Q', 'Clubs')]
# 563 : Pair - [('K', 'Spades'), ('K', 'Hearts')]
# 564 : Pair - [('K', 'Spades'), ('K', 'Diamonds')]
# 565 : Pair - [('K', 'Spades'), ('K', 'Clubs')]
# 566 : Pair - [('K', 'Hearts'), ('K', 'Diamonds')]
# 567 : Pair - [('K', 'Hearts'), ('K', 'Clubs')]
# 568 : Pair - [('K', 'Diamonds'), ('K', 'Clubs')]
# 569 : Pair - [('A', 'Spades'), ('A', 'Hearts')]
# 570 : Pair - [('A', 'Spades'), ('A', 'Diamonds')]
# 571 : Pair - [('A', 'Spades'), ('A', 'Clubs')]
# 572 : Pair - [('A', 'Hearts'), ('A', 'Diamonds')]
# 573 : Pair - [('A', 'Hearts'), ('A', 'Clubs')]
# 574 : Pair - [('A', 'Diamonds'), ('A', 'Clubs')]
# 575 : High card - [('3', 'Spades'), ('5', 'Spades')]
# 576 : High card - [('3', 'Spades'), ('5', 'Hearts')]
# 577 : High card - [('3', 'Spades'), ('5', 'Diamonds')]
# 578 : High card - [('3', 'Spades'), ('5', 'Clubs')]
# 579 : High card - [('3', 'Spades'), ('6', 'Spades')]
# 580 : High card - [('3', 'Spades'), ('6', 'Hearts')]
# 581 : High card - [('3', 'Spades'), ('6', 'Diamonds')]
# 582 : High card - [('3', 'Spades'), ('6', 'Clubs')]
# 583 : High card - [('3', 'Spades'), ('7', 'Spades')]
# 584 : High card - [('3', 'Spades'), ('7', 'Hearts')]
# 585 : High card - [('3', 'Spades'), ('7', 'Diamonds')]
# 586 : High card - [('3', 'Spades'), ('7', 'Clubs')]
# 587 : High card - [('3', 'Spades'), ('9', 'Spades')]
# 588 : High card - [('3', 'Spades'), ('9', 'Hearts')]
# 589 : High card - [('3', 'Spades'), ('9', 'Diamonds')]
# 590 : High card - [('3', 'Spades'), ('9', 'Clubs')]
# 591 : High card - [('3', 'Spades'), ('Q', 'Spades')]
# 592 : High card - [('3', 'Spades'), ('Q', 'Hearts')]
# 593 : High card - [('3', 'Spades'), ('Q', 'Diamonds')]
# 594 : High card - [('3', 'Spades'), ('Q', 'Clubs')]
# 595 : High card - [('3', 'Spades'), ('K', 'Spades')]
# 596 : High card - [('3', 'Spades'), ('K', 'Hearts')]
# 597 : High card - [('3', 'Spades'), ('K', 'Diamonds')]
# 598 : High card - [('3', 'Spades'), ('K', 'Clubs')]
# 599 : High card - [('3', 'Spades'), ('A', 'Spades')]
# 600 : High card - [('3', 'Spades'), ('A', 'Hearts')]
# 601 : High card - [('3', 'Spades'), ('A', 'Diamonds')]
# 602 : High card - [('3', 'Spades'), ('A', 'Clubs')]
# 603 : High card - [('3', 'Hearts'), ('5', 'Spades')]
# 604 : High card - [('3', 'Hearts'), ('5', 'Hearts')]
# 605 : High card - [('3', 'Hearts'), ('5', 'Diamonds')]
# 606 : High card - [('3', 'Hearts'), ('5', 'Clubs')]
# 607 : High card - [('3', 'Hearts'), ('6', 'Spades')]
# 608 : High card - [('3', 'Hearts'), ('6', 'Hearts')]
# 609 : High card - [('3', 'Hearts'), ('6', 'Diamonds')]
# 610 : High card - [('3', 'Hearts'), ('6', 'Clubs')]
# 611 : High card - [('3', 'Hearts'), ('7', 'Spades')]
# 612 : High card - [('3', 'Hearts'), ('7', 'Hearts')]
# 613 : High card - [('3', 'Hearts'), ('7', 'Diamonds')]
# 614 : High card - [('3', 'Hearts'), ('7', 'Clubs')]
# 615 : High card - [('3', 'Hearts'), ('9', 'Spades')]
# 616 : High card - [('3', 'Hearts'), ('9', 'Hearts')]
# 617 : High card - [('3', 'Hearts'), ('9', 'Diamonds')]
# 618 : High card - [('3', 'Hearts'), ('9', 'Clubs')]
# 619 : High card - [('3', 'Hearts'), ('Q', 'Spades')]
# 620 : High card - [('3', 'Hearts'), ('Q', 'Hearts')]
# 621 : High card - [('3', 'Hearts'), ('Q', 'Diamonds')]
# 622 : High card - [('3', 'Hearts'), ('Q', 'Clubs')]
# 623 : High card - [('3', 'Hearts'), ('K', 'Spades')]
# 624 : High card - [('3', 'Hearts'), ('K', 'Hearts')]
# 625 : High card - [('3', 'Hearts'), ('K', 'Diamonds')]
# 626 : High card - [('3', 'Hearts'), ('K', 'Clubs')]
# 627 : High card - [('3', 'Hearts'), ('A', 'Spades')]
# 628 : High card - [('3', 'Hearts'), ('A', 'Hearts')]
# 629 : High card - [('3', 'Hearts'), ('A', 'Diamonds')]
# 630 : High card - [('3', 'Hearts'), ('A', 'Clubs')]
# 631 : High card - [('3', 'Diamonds'), ('5', 'Spades')]
# 632 : High card - [('3', 'Diamonds'), ('5', 'Hearts')]
# 633 : High card - [('3', 'Diamonds'), ('5', 'Diamonds')]
# 634 : High card - [('3', 'Diamonds'), ('5', 'Clubs')]
# 635 : High card - [('3', 'Diamonds'), ('6', 'Spades')]
# 636 : High card - [('3', 'Diamonds'), ('6', 'Hearts')]
# 637 : High card - [('3', 'Diamonds'), ('6', 'Diamonds')]
# 638 : High card - [('3', 'Diamonds'), ('6', 'Clubs')]
# 639 : High card - [('3', 'Diamonds'), ('7', 'Spades')]
# 640 : High card - [('3', 'Diamonds'), ('7', 'Hearts')]
# 641 : High card - [('3', 'Diamonds'), ('7', 'Diamonds')]
# 642 : High card - [('3', 'Diamonds'), ('7', 'Clubs')]
# 643 : High card - [('3', 'Diamonds'), ('9', 'Spades')]
# 644 : High card - [('3', 'Diamonds'), ('9', 'Hearts')]
# 645 : High card - [('3', 'Diamonds'), ('9', 'Diamonds')]
# 646 : High card - [('3', 'Diamonds'), ('9', 'Clubs')]
# 647 : High card - [('3', 'Diamonds'), ('Q', 'Spades')]
# 648 : High card - [('3', 'Diamonds'), ('Q', 'Hearts')]
# 649 : High card - [('3', 'Diamonds'), ('Q', 'Diamonds')]
# 650 : High card - [('3', 'Diamonds'), ('Q', 'Clubs')]
# 651 : High card - [('3', 'Diamonds'), ('K', 'Spades')]
# 652 : High card - [('3', 'Diamonds'), ('K', 'Hearts')]
# 653 : High card - [('3', 'Diamonds'), ('K', 'Diamonds')]
# 654 : High card - [('3', 'Diamonds'), ('K', 'Clubs')]
# 655 : High card - [('3', 'Diamonds'), ('A', 'Spades')]
# 656 : High card - [('3', 'Diamonds'), ('A', 'Hearts')]
# 657 : High card - [('3', 'Diamonds'), ('A', 'Diamonds')]
# 658 : High card - [('3', 'Diamonds'), ('A', 'Clubs')]
# 659 : High card - [('3', 'Clubs'), ('5', 'Spades')]
# 660 : High card - [('3', 'Clubs'), ('5', 'Hearts')]
# 661 : High card - [('3', 'Clubs'), ('5', 'Diamonds')]
# 662 : High card - [('3', 'Clubs'), ('5', 'Clubs')]
# 663 : High card - [('3', 'Clubs'), ('6', 'Spades')]
# 664 : High card - [('3', 'Clubs'), ('6', 'Hearts')]
# 665 : High card - [('3', 'Clubs'), ('6', 'Diamonds')]
# 666 : High card - [('3', 'Clubs'), ('6', 'Clubs')]
# 667 : High card - [('3', 'Clubs'), ('7', 'Spades')]
# 668 : High card - [('3', 'Clubs'), ('7', 'Hearts')]
# 669 : High card - [('3', 'Clubs'), ('7', 'Diamonds')]
# 670 : High card - [('3', 'Clubs'), ('7', 'Clubs')]
# 671 : High card - [('3', 'Clubs'), ('9', 'Spades')]
# 672 : High card - [('3', 'Clubs'), ('9', 'Hearts')]
# 673 : High card - [('3', 'Clubs'), ('9', 'Diamonds')]
# 674 : High card - [('3', 'Clubs'), ('9', 'Clubs')]
# 675 : High card - [('3', 'Clubs'), ('Q', 'Spades')]
# 676 : High card - [('3', 'Clubs'), ('Q', 'Hearts')]
# 677 : High card - [('3', 'Clubs'), ('Q', 'Diamonds')]
# 678 : High card - [('3', 'Clubs'), ('Q', 'Clubs')]
# 679 : High card - [('3', 'Clubs'), ('K', 'Spades')]
# 680 : High card - [('3', 'Clubs'), ('K', 'Hearts')]
# 681 : High card - [('3', 'Clubs'), ('K', 'Diamonds')]
# 682 : High card - [('3', 'Clubs'), ('K', 'Clubs')]
# 683 : High card - [('3', 'Clubs'), ('A', 'Spades')]
# 684 : High card - [('3', 'Clubs'), ('A', 'Hearts')]
# 685 : High card - [('3', 'Clubs'), ('A', 'Diamonds')]
# 686 : High card - [('3', 'Clubs'), ('A', 'Clubs')]
# 687 : High card - [('5', 'Spades'), ('6', 'Spades')]
# 688 : High card - [('5', 'Spades'), ('6', 'Hearts')]
# 689 : High card - [('5', 'Spades'), ('6', 'Diamonds')]
# 690 : High card - [('5', 'Spades'), ('6', 'Clubs')]
# 691 : High card - [('5', 'Spades'), ('7', 'Spades')]
# 692 : High card - [('5', 'Spades'), ('7', 'Hearts')]
# 693 : High card - [('5', 'Spades'), ('7', 'Diamonds')]
# 694 : High card - [('5', 'Spades'), ('7', 'Clubs')]
# 695 : High card - [('5', 'Spades'), ('9', 'Spades')]
# 696 : High card - [('5', 'Spades'), ('9', 'Hearts')]
# 697 : High card - [('5', 'Spades'), ('9', 'Diamonds')]
# 698 : High card - [('5', 'Spades'), ('9', 'Clubs')]
# 699 : High card - [('5', 'Spades'), ('Q', 'Spades')]
# 700 : High card - [('5', 'Spades'), ('Q', 'Hearts')]
# 701 : High card - [('5', 'Spades'), ('Q', 'Diamonds')]
# 702 : High card - [('5', 'Spades'), ('Q', 'Clubs')]
# 703 : High card - [('5', 'Spades'), ('K', 'Spades')]
# 704 : High card - [('5', 'Spades'), ('K', 'Hearts')]
# 705 : High card - [('5', 'Spades'), ('K', 'Diamonds')]
# 706 : High card - [('5', 'Spades'), ('K', 'Clubs')]
# 707 : High card - [('5', 'Spades'), ('A', 'Spades')]
# 708 : High card - [('5', 'Spades'), ('A', 'Hearts')]
# 709 : High card - [('5', 'Spades'), ('A', 'Diamonds')]
# 710 : High card - [('5', 'Spades'), ('A', 'Clubs')]
# 711 : High card - [('5', 'Hearts'), ('6', 'Spades')]
# 712 : High card - [('5', 'Hearts'), ('6', 'Hearts')]
# 713 : High card - [('5', 'Hearts'), ('6', 'Diamonds')]
# 714 : High card - [('5', 'Hearts'), ('6', 'Clubs')]
# 715 : High card - [('5', 'Hearts'), ('7', 'Spades')]
# 716 : High card - [('5', 'Hearts'), ('7', 'Hearts')]
# 717 : High card - [('5', 'Hearts'), ('7', 'Diamonds')]
# 718 : High card - [('5', 'Hearts'), ('7', 'Clubs')]
# 719 : High card - [('5', 'Hearts'), ('9', 'Spades')]
# 720 : High card - [('5', 'Hearts'), ('9', 'Hearts')]
# 721 : High card - [('5', 'Hearts'), ('9', 'Diamonds')]
# 722 : High card - [('5', 'Hearts'), ('9', 'Clubs')]
# 723 : High card - [('5', 'Hearts'), ('Q', 'Spades')]
# 724 : High card - [('5', 'Hearts'), ('Q', 'Hearts')]
# 725 : High card - [('5', 'Hearts'), ('Q', 'Diamonds')]
# 726 : High card - [('5', 'Hearts'), ('Q', 'Clubs')]
# 727 : High card - [('5', 'Hearts'), ('K', 'Spades')]
# 728 : High card - [('5', 'Hearts'), ('K', 'Hearts')]
# 729 : High card - [('5', 'Hearts'), ('K', 'Diamonds')]
# 730 : High card - [('5', 'Hearts'), ('K', 'Clubs')]
# 731 : High card - [('5', 'Hearts'), ('A', 'Spades')]
# 732 : High card - [('5', 'Hearts'), ('A', 'Hearts')]
# 733 : High card - [('5', 'Hearts'), ('A', 'Diamonds')]
# 734 : High card - [('5', 'Hearts'), ('A', 'Clubs')]
# 735 : High card - [('5', 'Diamonds'), ('6', 'Spades')]
# 736 : High card - [('5', 'Diamonds'), ('6', 'Hearts')]
# 737 : High card - [('5', 'Diamonds'), ('6', 'Diamonds')]
# 738 : High card - [('5', 'Diamonds'), ('6', 'Clubs')]
# 739 : High card - [('5', 'Diamonds'), ('7', 'Spades')]
# 740 : High card - [('5', 'Diamonds'), ('7', 'Hearts')]
# 741 : High card - [('5', 'Diamonds'), ('7', 'Diamonds')]
# 742 : High card - [('5', 'Diamonds'), ('7', 'Clubs')]
# 743 : High card - [('5', 'Diamonds'), ('9', 'Spades')]
# 744 : High card - [('5', 'Diamonds'), ('9', 'Hearts')]
# 745 : High card - [('5', 'Diamonds'), ('9', 'Diamonds')]
# 746 : High card - [('5', 'Diamonds'), ('9', 'Clubs')]
# 747 : High card - [('5', 'Diamonds'), ('Q', 'Spades')]
# 748 : High card - [('5', 'Diamonds'), ('Q', 'Hearts')]
# 749 : High card - [('5', 'Diamonds'), ('Q', 'Diamonds')]
# 750 : High card - [('5', 'Diamonds'), ('Q', 'Clubs')]
# 751 : High card - [('5', 'Diamonds'), ('K', 'Spades')]
# 752 : High card - [('5', 'Diamonds'), ('K', 'Hearts')]
# 753 : High card - [('5', 'Diamonds'), ('K', 'Diamonds')]
# 754 : High card - [('5', 'Diamonds'), ('K', 'Clubs')]
# 755 : High card - [('5', 'Diamonds'), ('A', 'Spades')]
# 756 : High card - [('5', 'Diamonds'), ('A', 'Hearts')]
# 757 : High card - [('5', 'Diamonds'), ('A', 'Diamonds')]
# 758 : High card - [('5', 'Diamonds'), ('A', 'Clubs')]
# 759 : High card - [('5', 'Clubs'), ('6', 'Spades')]
# 760 : High card - [('5', 'Clubs'), ('6', 'Hearts')]
# 761 : High card - [('5', 'Clubs'), ('6', 'Diamonds')]
# 762 : High card - [('5', 'Clubs'), ('6', 'Clubs')]
# 763 : High card - [('5', 'Clubs'), ('7', 'Spades')]
# 764 : High card - [('5', 'Clubs'), ('7', 'Hearts')]
# 765 : High card - [('5', 'Clubs'), ('7', 'Diamonds')]
# 766 : High card - [('5', 'Clubs'), ('7', 'Clubs')]
# 767 : High card - [('5', 'Clubs'), ('9', 'Spades')]
# 768 : High card - [('5', 'Clubs'), ('9', 'Hearts')]
# 769 : High card - [('5', 'Clubs'), ('9', 'Diamonds')]
# 770 : High card - [('5', 'Clubs'), ('9', 'Clubs')]
# 771 : High card - [('5', 'Clubs'), ('Q', 'Spades')]
# 772 : High card - [('5', 'Clubs'), ('Q', 'Hearts')]
# 773 : High card - [('5', 'Clubs'), ('Q', 'Diamonds')]
# 774 : High card - [('5', 'Clubs'), ('Q', 'Clubs')]
# 775 : High card - [('5', 'Clubs'), ('K', 'Spades')]
# 776 : High card - [('5', 'Clubs'), ('K', 'Hearts')]
# 777 : High card - [('5', 'Clubs'), ('K', 'Diamonds')]
# 778 : High card - [('5', 'Clubs'), ('K', 'Clubs')]
# 779 : High card - [('5', 'Clubs'), ('A', 'Spades')]
# 780 : High card - [('5', 'Clubs'), ('A', 'Hearts')]
# 781 : High card - [('5', 'Clubs'), ('A', 'Diamonds')]
# 782 : High card - [('5', 'Clubs'), ('A', 'Clubs')]
# 783 : High card - [('6', 'Spades'), ('7', 'Spades')]
# 784 : High card - [('6', 'Spades'), ('7', 'Hearts')]
# 785 : High card - [('6', 'Spades'), ('7', 'Diamonds')]
# 786 : High card - [('6', 'Spades'), ('7', 'Clubs')]
# 787 : High card - [('6', 'Spades'), ('9', 'Spades')]
# 788 : High card - [('6', 'Spades'), ('9', 'Hearts')]
# 789 : High card - [('6', 'Spades'), ('9', 'Diamonds')]
# 790 : High card - [('6', 'Spades'), ('9', 'Clubs')]
# 791 : High card - [('6', 'Spades'), ('Q', 'Spades')]
# 792 : High card - [('6', 'Spades'), ('Q', 'Hearts')]
# 793 : High card - [('6', 'Spades'), ('Q', 'Diamonds')]
# 794 : High card - [('6', 'Spades'), ('Q', 'Clubs')]
# 795 : High card - [('6', 'Spades'), ('K', 'Spades')]
# 796 : High card - [('6', 'Spades'), ('K', 'Hearts')]
# 797 : High card - [('6', 'Spades'), ('K', 'Diamonds')]
# 798 : High card - [('6', 'Spades'), ('K', 'Clubs')]
# 799 : High card - [('6', 'Spades'), ('A', 'Spades')]
# 800 : High card - [('6', 'Spades'), ('A', 'Hearts')]
# 801 : High card - [('6', 'Spades'), ('A', 'Diamonds')]
# 802 : High card - [('6', 'Spades'), ('A', 'Clubs')]
# 803 : High card - [('6', 'Hearts'), ('7', 'Spades')]
# 804 : High card - [('6', 'Hearts'), ('7', 'Hearts')]
# 805 : High card - [('6', 'Hearts'), ('7', 'Diamonds')]
# 806 : High card - [('6', 'Hearts'), ('7', 'Clubs')]
# 807 : High card - [('6', 'Hearts'), ('9', 'Spades')]
# 808 : High card - [('6', 'Hearts'), ('9', 'Hearts')]
# 809 : High card - [('6', 'Hearts'), ('9', 'Diamonds')]
# 810 : High card - [('6', 'Hearts'), ('9', 'Clubs')]
# 811 : High card - [('6', 'Hearts'), ('Q', 'Spades')]
# 812 : High card - [('6', 'Hearts'), ('Q', 'Hearts')]
# 813 : High card - [('6', 'Hearts'), ('Q', 'Diamonds')]
# 814 : High card - [('6', 'Hearts'), ('Q', 'Clubs')]
# 815 : High card - [('6', 'Hearts'), ('K', 'Spades')]
# 816 : High card - [('6', 'Hearts'), ('K', 'Hearts')]
# 817 : High card - [('6', 'Hearts'), ('K', 'Diamonds')]
# 818 : High card - [('6', 'Hearts'), ('K', 'Clubs')]
# 819 : High card - [('6', 'Hearts'), ('A', 'Spades')]
# 820 : High card - [('6', 'Hearts'), ('A', 'Hearts')]
# 821 : High card - [('6', 'Hearts'), ('A', 'Diamonds')]
# 822 : High card - [('6', 'Hearts'), ('A', 'Clubs')]
# 823 : High card - [('6', 'Diamonds'), ('7', 'Spades')]
# 824 : High card - [('6', 'Diamonds'), ('7', 'Hearts')]
# 825 : High card - [('6', 'Diamonds'), ('7', 'Diamonds')]
# 826 : High card - [('6', 'Diamonds'), ('7', 'Clubs')]
# 827 : High card - [('6', 'Diamonds'), ('9', 'Spades')]
# 828 : High card - [('6', 'Diamonds'), ('9', 'Hearts')]
# 829 : High card - [('6', 'Diamonds'), ('9', 'Diamonds')]
# 830 : High card - [('6', 'Diamonds'), ('9', 'Clubs')]
# 831 : High card - [('6', 'Diamonds'), ('Q', 'Spades')]
# 832 : High card - [('6', 'Diamonds'), ('Q', 'Hearts')]
# 833 : High card - [('6', 'Diamonds'), ('Q', 'Diamonds')]
# 834 : High card - [('6', 'Diamonds'), ('Q', 'Clubs')]
# 835 : High card - [('6', 'Diamonds'), ('K', 'Spades')]
# 836 : High card - [('6', 'Diamonds'), ('K', 'Hearts')]
# 837 : High card - [('6', 'Diamonds'), ('K', 'Diamonds')]
# 838 : High card - [('6', 'Diamonds'), ('K', 'Clubs')]
# 839 : High card - [('6', 'Diamonds'), ('A', 'Spades')]
# 840 : High card - [('6', 'Diamonds'), ('A', 'Hearts')]
# 841 : High card - [('6', 'Diamonds'), ('A', 'Diamonds')]
# 842 : High card - [('6', 'Diamonds'), ('A', 'Clubs')]
# 843 : High card - [('6', 'Clubs'), ('7', 'Spades')]
# 844 : High card - [('6', 'Clubs'), ('7', 'Hearts')]
# 845 : High card - [('6', 'Clubs'), ('7', 'Diamonds')]
# 846 : High card - [('6', 'Clubs'), ('7', 'Clubs')]
# 847 : High card - [('6', 'Clubs'), ('9', 'Spades')]
# 848 : High card - [('6', 'Clubs'), ('9', 'Hearts')]
# 849 : High card - [('6', 'Clubs'), ('9', 'Diamonds')]
# 850 : High card - [('6', 'Clubs'), ('9', 'Clubs')]
# 851 : High card - [('6', 'Clubs'), ('Q', 'Spades')]
# 852 : High card - [('6', 'Clubs'), ('Q', 'Hearts')]
# 853 : High card - [('6', 'Clubs'), ('Q', 'Diamonds')]
# 854 : High card - [('6', 'Clubs'), ('Q', 'Clubs')]
# 855 : High card - [('6', 'Clubs'), ('K', 'Spades')]
# 856 : High card - [('6', 'Clubs'), ('K', 'Hearts')]
# 857 : High card - [('6', 'Clubs'), ('K', 'Diamonds')]
# 858 : High card - [('6', 'Clubs'), ('K', 'Clubs')]
# 859 : High card - [('6', 'Clubs'), ('A', 'Spades')]
# 860 : High card - [('6', 'Clubs'), ('A', 'Hearts')]
# 861 : High card - [('6', 'Clubs'), ('A', 'Diamonds')]
# 862 : High card - [('6', 'Clubs'), ('A', 'Clubs')]
# 863 : High card - [('7', 'Spades'), ('Q', 'Spades')]
# 864 : High card - [('7', 'Spades'), ('Q', 'Hearts')]
# 865 : High card - [('7', 'Spades'), ('Q', 'Diamonds')]
# 866 : High card - [('7', 'Spades'), ('Q', 'Clubs')]
# 867 : High card - [('7', 'Spades'), ('K', 'Spades')]
# 868 : High card - [('7', 'Spades'), ('K', 'Hearts')]
# 869 : High card - [('7', 'Spades'), ('K', 'Diamonds')]
# 870 : High card - [('7', 'Spades'), ('K', 'Clubs')]
# 871 : High card - [('7', 'Spades'), ('A', 'Spades')]
# 872 : High card - [('7', 'Spades'), ('A', 'Hearts')]
# 873 : High card - [('7', 'Spades'), ('A', 'Diamonds')]
# 874 : High card - [('7', 'Spades'), ('A', 'Clubs')]
# 875 : High card - [('7', 'Hearts'), ('Q', 'Spades')]
# 876 : High card - [('7', 'Hearts'), ('Q', 'Hearts')]
# 877 : High card - [('7', 'Hearts'), ('Q', 'Diamonds')]
# 878 : High card - [('7', 'Hearts'), ('Q', 'Clubs')]
# 879 : High card - [('7', 'Hearts'), ('K', 'Spades')]
# 880 : High card - [('7', 'Hearts'), ('K', 'Hearts')]
# 881 : High card - [('7', 'Hearts'), ('K', 'Diamonds')]
# 882 : High card - [('7', 'Hearts'), ('K', 'Clubs')]
# 883 : High card - [('7', 'Hearts'), ('A', 'Spades')]
# 884 : High card - [('7', 'Hearts'), ('A', 'Hearts')]
# 885 : High card - [('7', 'Hearts'), ('A', 'Diamonds')]
# 886 : High card - [('7', 'Hearts'), ('A', 'Clubs')]
# 887 : High card - [('7', 'Diamonds'), ('Q', 'Spades')]
# 888 : High card - [('7', 'Diamonds'), ('Q', 'Hearts')]
# 889 : High card - [('7', 'Diamonds'), ('Q', 'Diamonds')]
# 890 : High card - [('7', 'Diamonds'), ('Q', 'Clubs')]
# 891 : High card - [('7', 'Diamonds'), ('K', 'Spades')]
# 892 : High card - [('7', 'Diamonds'), ('K', 'Hearts')]
# 893 : High card - [('7', 'Diamonds'), ('K', 'Diamonds')]
# 894 : High card - [('7', 'Diamonds'), ('K', 'Clubs')]
# 895 : High card - [('7', 'Diamonds'), ('A', 'Spades')]
# 896 : High card - [('7', 'Diamonds'), ('A', 'Hearts')]
# 897 : High card - [('7', 'Diamonds'), ('A', 'Diamonds')]
# 898 : High card - [('7', 'Diamonds'), ('A', 'Clubs')]
# 899 : High card - [('7', 'Clubs'), ('Q', 'Spades')]
# 900 : High card - [('7', 'Clubs'), ('Q', 'Hearts')]
# 901 : High card - [('7', 'Clubs'), ('Q', 'Diamonds')]
# 902 : High card - [('7', 'Clubs'), ('Q', 'Clubs')]
# 903 : High card - [('7', 'Clubs'), ('K', 'Spades')]
# 904 : High card - [('7', 'Clubs'), ('K', 'Hearts')]
# 905 : High card - [('7', 'Clubs'), ('K', 'Diamonds')]
# 906 : High card - [('7', 'Clubs'), ('K', 'Clubs')]
# 907 : High card - [('7', 'Clubs'), ('A', 'Spades')]
# 908 : High card - [('7', 'Clubs'), ('A', 'Hearts')]
# 909 : High card - [('7', 'Clubs'), ('A', 'Diamonds')]
# 910 : High card - [('7', 'Clubs'), ('A', 'Clubs')]
# 911 : High card - [('9', 'Spades'), ('K', 'Spades')]
# 912 : High card - [('9', 'Spades'), ('K', 'Hearts')]
# 913 : High card - [('9', 'Spades'), ('K', 'Diamonds')]
# 914 : High card - [('9', 'Spades'), ('K', 'Clubs')]
# 915 : High card - [('9', 'Spades'), ('A', 'Spades')]
# 916 : High card - [('9', 'Spades'), ('A', 'Hearts')]
# 917 : High card - [('9', 'Spades'), ('A', 'Diamonds')]
# 918 : High card - [('9', 'Spades'), ('A', 'Clubs')]
# 919 : High card - [('9', 'Hearts'), ('K', 'Spades')]
# 920 : High card - [('9', 'Hearts'), ('K', 'Hearts')]
# 921 : High card - [('9', 'Hearts'), ('K', 'Diamonds')]
# 922 : High card - [('9', 'Hearts'), ('K', 'Clubs')]
# 923 : High card - [('9', 'Hearts'), ('A', 'Spades')]
# 924 : High card - [('9', 'Hearts'), ('A', 'Hearts')]
# 925 : High card - [('9', 'Hearts'), ('A', 'Diamonds')]
# 926 : High card - [('9', 'Hearts'), ('A', 'Clubs')]
# 927 : High card - [('9', 'Diamonds'), ('K', 'Spades')]
# 928 : High card - [('9', 'Diamonds'), ('K', 'Hearts')]
# 929 : High card - [('9', 'Diamonds'), ('K', 'Diamonds')]
# 930 : High card - [('9', 'Diamonds'), ('K', 'Clubs')]
# 931 : High card - [('9', 'Diamonds'), ('A', 'Spades')]
# 932 : High card - [('9', 'Diamonds'), ('A', 'Hearts')]
# 933 : High card - [('9', 'Diamonds'), ('A', 'Diamonds')]
# 934 : High card - [('9', 'Diamonds'), ('A', 'Clubs')]
# 935 : High card - [('9', 'Clubs'), ('K', 'Spades')]
# 936 : High card - [('9', 'Clubs'), ('K', 'Hearts')]
# 937 : High card - [('9', 'Clubs'), ('K', 'Diamonds')]
# 938 : High card - [('9', 'Clubs'), ('K', 'Clubs')]
# 939 : High card - [('9', 'Clubs'), ('A', 'Spades')]
# 940 : High card - [('9', 'Clubs'), ('A', 'Hearts')]
# 941 : High card - [('9', 'Clubs'), ('A', 'Diamonds')]
# 942 : High card - [('9', 'Clubs'), ('A', 'Clubs')]
# 943 : High card - [('Q', 'Spades'), ('K', 'Spades')]
# 944 : High card - [('Q', 'Spades'), ('K', 'Hearts')]
# 945 : High card - [('Q', 'Spades'), ('K', 'Diamonds')]
# 946 : High card - [('Q', 'Spades'), ('K', 'Clubs')]
# 947 : High card - [('Q', 'Spades'), ('A', 'Spades')]
# 948 : High card - [('Q', 'Spades'), ('A', 'Hearts')]
# 949 : High card - [('Q', 'Spades'), ('A', 'Diamonds')]
# 950 : High card - [('Q', 'Spades'), ('A', 'Clubs')]
# 951 : High card - [('Q', 'Hearts'), ('K', 'Spades')]
# 952 : High card - [('Q', 'Hearts'), ('K', 'Hearts')]
# 953 : High card - [('Q', 'Hearts'), ('K', 'Diamonds')]
# 954 : High card - [('Q', 'Hearts'), ('K', 'Clubs')]
# 955 : High card - [('Q', 'Hearts'), ('A', 'Spades')]
# 956 : High card - [('Q', 'Hearts'), ('A', 'Hearts')]
# 957 : High card - [('Q', 'Hearts'), ('A', 'Diamonds')]
# 958 : High card - [('Q', 'Hearts'), ('A', 'Clubs')]
# 959 : High card - [('Q', 'Diamonds'), ('K', 'Spades')]
# 960 : High card - [('Q', 'Diamonds'), ('K', 'Hearts')]
# 961 : High card - [('Q', 'Diamonds'), ('K', 'Diamonds')]
# 962 : High card - [('Q', 'Diamonds'), ('K', 'Clubs')]
# 963 : High card - [('Q', 'Diamonds'), ('A', 'Spades')]
# 964 : High card - [('Q', 'Diamonds'), ('A', 'Hearts')]
# 965 : High card - [('Q', 'Diamonds'), ('A', 'Diamonds')]
# 966 : High card - [('Q', 'Diamonds'), ('A', 'Clubs')]
# 967 : High card - [('Q', 'Clubs'), ('K', 'Spades')]
# 968 : High card - [('Q', 'Clubs'), ('K', 'Hearts')]
# 969 : High card - [('Q', 'Clubs'), ('K', 'Diamonds')]
# 970 : High card - [('Q', 'Clubs'), ('K', 'Clubs')]
# 971 : High card - [('Q', 'Clubs'), ('A', 'Spades')]
# 972 : High card - [('Q', 'Clubs'), ('A', 'Hearts')]
# 973 : High card - [('Q', 'Clubs'), ('A', 'Diamonds')]
# 974 : High card - [('Q', 'Clubs'), ('A', 'Clubs')]
# 975 : High card - [('K', 'Spades'), ('A', 'Spades')]
# 976 : High card - [('K', 'Spades'), ('A', 'Hearts')]
# 977 : High card - [('K', 'Spades'), ('A', 'Diamonds')]
# 978 : High card - [('K', 'Spades'), ('A', 'Clubs')]
# 979 : High card - [('K', 'Hearts'), ('A', 'Spades')]
# 980 : High card - [('K', 'Hearts'), ('A', 'Hearts')]
# 981 : High card - [('K', 'Hearts'), ('A', 'Diamonds')]
# 982 : High card - [('K', 'Hearts'), ('A', 'Clubs')]
# 983 : High card - [('K', 'Diamonds'), ('A', 'Spades')]
# 984 : High card - [('K', 'Diamonds'), ('A', 'Hearts')]
# 985 : High card - [('K', 'Diamonds'), ('A', 'Diamonds')]
# 986 : High card - [('K', 'Diamonds'), ('A', 'Clubs')]
# 987 : High card - [('K', 'Clubs'), ('A', 'Spades')]
# 988 : High card - [('K', 'Clubs'), ('A', 'Hearts')]
# 989 : High card - [('K', 'Clubs'), ('A', 'Diamonds')]
# 990 : High card - [('K', 'Clubs'), ('A', 'Clubs')]

# %%
# import random
# import itertools

# def find_high_card(cards):
#     sorted_cards = sorted(cards, key=lambda x: '23456789TJQKA'.index(x[0]))
#     return sorted_cards[-1]

# def generate_random_cards(num_cards):
#     ranks = '23456789TJQKA'
#     suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
#     deck = [(rank, suit) for rank in ranks for suit in suits]
#     return random.sample(deck, num_cards)

# def print_combination(hand_type, winning_cards, winning_combination, high_card):
#     if hand_type == "Pair":
#         print("Combination: Pair of", winning_cards[0][0] + "s")
#     elif hand_type == "Two pair":
#         pair1_rank = winning_cards[0][0]
#         pair2_rank = winning_cards[2][0]
#         print("Combination: Two Pair - Pair of", pair1_rank + "s and Pair of", pair2_rank + "s")
#     # Add more elif blocks for other combinations
#     else:
#         print("Combination:", winning_combination)

# def predict_poker_hand(hand, table_cards):
#     all_cards = hand + table_cards
#     sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

#     suits = [card[1] for card in all_cards]
#     ranks = [card[0] for card in all_cards]

#     for suit in set(suits):
#         if suits.count(suit) >= 5:
#             flush_cards = [card for card in all_cards if card[1] == suit]
#             flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
#             if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
#                 if flush_sorted[-1][0] == 'A':
#                     return "Royal flush", None, "Royal Flush"
#                 else:
#                     return "Straight flush", None, "Straight Flush"

#     # Check for Straight
#     unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
#     straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
#     for i in range(len(unique_ranks) - 4):
#         if ''.join(unique_ranks[i:i+5]) in straight_ranks:
#             return "Straight", None, "Straight"

#     counts = [ranks.count(rank) for rank in set(ranks)]

#     if 4 in counts:  # Four of a kind
#         return "Four of a kind", None, "Four of a Kind"

#     if 3 in counts and 2 in counts:  # Full house
#         return "Full house", None, "Full House"

#     if 3 in counts:  # Three of a kind
#         three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
#         three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
#         return "Three of a kind", three_kind_cards, "Three of a Kind", find_high_card(three_kind_cards)

#     if counts.count(2) == 2:  # Two pair
#         two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
#         two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
#         return "Two pair", two_pair_cards, "Two Pair", find_high_card(two_pair_cards)

#     if counts.count(2) == 1:  # Pair
#         pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
#         pair_cards = [card for card in all_cards if card[0] in pair_rank]
#         return "Pair", pair_cards, "Pair", find_high_card(pair_cards)

#     high_card = find_high_card(all_cards)
#     return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

# def generate_remaining_cards(initial_hand, table_cards):
#     ranks = '23456789TJQKA'
#     suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
#     deck = [(rank, suit) for rank in ranks for suit in suits]
    
#     remaining_cards = [card for card in deck if card not in initial_hand and card not in table_cards]
    
#     return remaining_cards

# def generate_hand_combinations(initial_hand, remaining_cards):
#     return itertools.combinations(remaining_cards, 2)

# def evaluate_hand_combinations(hand_combinations, table_cards):
#     evaluated_hands = []
#     for hand_combination in hand_combinations:
#         hand = list(hand_combination)
#         result = predict_poker_hand(hand, table_cards)
#         hand_type = result[0]
#         evaluated_hands.append((hand, hand_type))
    
#     # Sort hands based on their ranks
#     evaluated_hands.sort(key=lambda x: hand_ranking.index(x[1]))
    
#     return evaluated_hands

# def determine_betting_multiplier(hand_strength, hand_rankings):
#     # Return the multiplier based on hand strength
#     return hand_rankings.get(hand_strength, 0)

# def determine_betting(player_hand, table_cards, stack_size=100000, bluff_chance=0.1):
#     # Evaluate hand strength
#     hand_strength = predict_poker_hand(player_hand, table_cards)[0]
    
#     hand_rankings = {
#         "Royal flush": 100,
#         "Straight flush": 80,
#         "Four of a kind": 60,
#         "Full house": 40,
#         "Flush": 30,
#         "Straight": 30,
#         "Three of a kind": 20,
#         "Two pair": 15,
#         "Pair": 10,
#         "High card": 5
#     }
    
#     # Determine betting amount based on hand strength
#     if bluff_chance >= random.random():  # Bluff
#         bet_amount = stack_size  # All in
#     else:
#         bet_multiplier = determine_betting_multiplier(hand_strength, hand_rankings)
#         bet_amount = min(int(stack_size * bet_multiplier), 1000)  # Cap 
    
#     return "bet", bet_amount

# hand_ranking = [
#     "Royal flush",
#     "Straight flush",
#     "Four of a kind",
#     "Full house",
#     "Flush",
#     "Straight",
#     "Three of a kind",
#     "Two pair",
#     "Pair",
#     "High card"
# ]

# # Example usage:
# player_hand = [('J', 'Spades'), ('8', 'Spades')]
# table_cards = [('4', 'Diamonds'), ('J', 'Clubs'), ('T', 'Hearts'), ('8', 'Clubs'), ('2', 'Spades')]

# result = predict_poker_hand(player_hand, table_cards)
# hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

# print_combination(hand_type, winning_cards, winning_combination, high_card)

# remaining_cards = generate_remaining_cards(player_hand, table_cards)
# hand_combinations = generate_hand_combinations(player_hand, remaining_cards)
# evaluated_hands = evaluate_hand_combinations(hand_combinations, table_cards)

# # print("Ranking of other hand combinations:")
# # for i, (hand, hand_type) in enumerate(evaluated_hands, 1):
# #     print(i, ":", hand_type, "-", hand)

# action, bet_amount = determine_betting(player_hand, table_cards)
# print("Player's betting action:", action)
# print("Player's betting amount:", bet_amount)
# Out:
# Combination: Two Pair - Pair of Js and Pair of Js
# Player's betting action: bet
# Player's betting amount: 1000
