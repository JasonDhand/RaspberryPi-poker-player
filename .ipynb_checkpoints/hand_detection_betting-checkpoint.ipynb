# %%
def predict_poker_hand(hand, table_cards):
    all_cards = hand + table_cards
    sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

    suits = [card[1] for card in all_cards]
    ranks = [card[0] for card in all_cards]

    for suit in set(suits):
        if suits.count(suit) >= 5:
            flush_cards = [card for card in all_cards if card[1] == suit]
            flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
            if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
                if flush_sorted[-1][0] == 'A':
                    return "Royal flush", None, "Royal Flush"
                else:
                    return "Straight flush", None, "Straight Flush"

    # Check for Straight
    unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
    straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
    for i in range(len(unique_ranks) - 4):
        if ''.join(unique_ranks[i:i+5]) in straight_ranks:
            return "Straight", None, "Straight"

    counts = [ranks.count(rank) for rank in set(ranks)]

    if 4 in counts:  # Four of a kind
        return "Four of a kind", None, "Four of a Kind"

    if 3 in counts and 2 in counts:  # Full house
        return "Full house", None, "Full House"

    if 3 in counts:  # Three of a kind
        three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
        three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
        return "Three of a kind", three_kind_cards, "Three of a Kind", find_high_card(three_kind_cards)

    if counts.count(2) == 2:  # Two pair
        two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
        two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
        return "Two pair", two_pair_cards, "Two Pair", find_high_card(two_pair_cards)

    if counts.count(2) == 1:  # Pair
        pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
        pair_cards = [card for card in all_cards if card[0] in pair_rank]
        return "Pair", pair_cards, "Pair", find_high_card(pair_cards)

    high_card = find_high_card(all_cards)
    return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

hand = [('2', 'Clubs'), ('2', 'Hearts')]
table_cards = [('Q', 'Clubs'), ('Q', 'Diamonds'), ('5', 'Diamonds'), ('Q', 'Spades'), ('6', 'Clubs')]

result = predict_poker_hand(hand, table_cards)
hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

print_combination(hand_type, winning_cards, winning_combination, high_card)
# Out:
# Full house - Full House

# %%
import random
import itertools

def generate_remaining_cards(initial_hand, table_cards):
    ranks = '23456789TJQKA'
    suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
    deck = [(rank, suit) for rank in ranks for suit in suits]
    
    remaining_cards = [card for card in deck if card not in initial_hand and card not in table_cards]
    
    return remaining_cards

def generate_hand_combinations(initial_hand, remaining_cards):
    return itertools.combinations(remaining_cards, 2)

def predict_poker_hand(hand, table_cards):
    all_cards = hand + table_cards
    sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

    suits = [card[1] for card in all_cards]
    ranks = [card[0] for card in all_cards]

    for suit in set(suits):
        if suits.count(suit) >= 5:
            flush_cards = [card for card in all_cards if card[1] == suit]
            flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
            if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
                if flush_sorted[-1][0] == 'A':
                    return "Royal flush", None, "Royal Flush"
                else:
                    return "Straight flush", None, "Straight Flush"

    # Check for Straight
    unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
    straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
    for i in range(len(unique_ranks) - 4):
        if ''.join(unique_ranks[i:i+5]) in straight_ranks:
            return "Straight", None, "Straight"

    # Rest
    counts = [ranks.count(rank) for rank in set(ranks)]

    if 4 in counts: 
        return "Four of a kind", None, "Four of a Kind"

    if 3 in counts and 2 in counts:
        return "Full house", None, "Full House"

    if 3 in counts:  
        three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
        three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
        return "Three of a kind", three_kind_cards, "Three of a Kind"

    if counts.count(2) == 2: 
        two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
        two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
        return "Two pair", two_pair_cards, "Two Pair"

    if counts.count(2) == 1:  
        pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
        pair_cards = [card for card in all_cards if card[0] in pair_rank]
        return "Pair", pair_cards, "Pair"

    high_card = find_high_card(all_cards)
    return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

def evaluate_hand_combinations(hand_combinations, table_cards):
    evaluated_hands = []
    for hand_combination in hand_combinations:
        hand = list(hand_combination)
        result = predict_poker_hand(hand, table_cards)
        hand_type = result[0]
        evaluated_hands.append((hand, hand_type))
    
    # Sort hands based on their ranks
    evaluated_hands.sort(key=lambda x: hand_ranking.index(x[1]))
    
    return evaluated_hands

hand_ranking = [
    "Royal flush",
    "Straight flush",
    "Four of a kind",
    "Full house",
    "Flush",
    "Straight",
    "Three of a kind",
    "Two pair",
    "Pair",
    "High card"
]


hand = [('2', 'Clubs'), ('2', 'Hearts')]
table_cards = [('4', 'Clubs'), ('Q', 'Diamonds'), ('5', 'Diamonds'), ('9', 'Spades'), ('6', 'Clubs')]

result = predict_poker_hand(hand, table_cards)
hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

print_combination(hand_type, winning_cards, winning_combination, high_card)

remaining_cards = generate_remaining_cards(initial_hand, table_cards)
hand_combinations = generate_hand_combinations(initial_hand, remaining_cards)
evaluated_hands = evaluate_hand_combinations(hand_combinations, table_cards)

print("Ranking of other hand combinations:")
for i, (hand, hand_type) in enumerate(evaluated_hands, 1):
    print(i, ":", hand_type, "-", hand)
# Out:
# Pair - Pair: [('2', 'Clubs'), ('2', 'Hearts')]
# Ranking of other hand combinations:
# 1 : Straight - [('2', 'Spades'), ('3', 'Spades')]
# 2 : Straight - [('2', 'Spades'), ('3', 'Hearts')]
# 3 : Straight - [('2', 'Spades'), ('3', 'Diamonds')]
# 4 : Straight - [('2', 'Spades'), ('3', 'Clubs')]
# 5 : Straight - [('2', 'Hearts'), ('3', 'Spades')]
# 6 : Straight - [('2', 'Hearts'), ('3', 'Hearts')]
# 7 : Straight - [('2', 'Hearts'), ('3', 'Diamonds')]
# 8 : Straight - [('2', 'Hearts'), ('3', 'Clubs')]
# 9 : Straight - [('2', 'Diamonds'), ('3', 'Spades')]
# 10 : Straight - [('2', 'Diamonds'), ('3', 'Hearts')]
# 11 : Straight - [('2', 'Diamonds'), ('3', 'Diamonds')]
# 12 : Straight - [('2', 'Diamonds'), ('3', 'Clubs')]
# 13 : Straight - [('3', 'Spades'), ('7', 'Spades')]
# 14 : Straight - [('3', 'Spades'), ('7', 'Hearts')]
# 15 : Straight - [('3', 'Spades'), ('7', 'Diamonds')]
# 16 : Straight - [('3', 'Spades'), ('7', 'Clubs')]
# 17 : Straight - [('3', 'Hearts'), ('7', 'Spades')]
# 18 : Straight - [('3', 'Hearts'), ('7', 'Hearts')]
# 19 : Straight - [('3', 'Hearts'), ('7', 'Diamonds')]
# 20 : Straight - [('3', 'Hearts'), ('7', 'Clubs')]
# 21 : Straight - [('3', 'Diamonds'), ('7', 'Spades')]
# 22 : Straight - [('3', 'Diamonds'), ('7', 'Hearts')]
# 23 : Straight - [('3', 'Diamonds'), ('7', 'Diamonds')]
# 24 : Straight - [('3', 'Diamonds'), ('7', 'Clubs')]
# 25 : Straight - [('3', 'Clubs'), ('7', 'Spades')]
# 26 : Straight - [('3', 'Clubs'), ('7', 'Hearts')]
# 27 : Straight - [('3', 'Clubs'), ('7', 'Diamonds')]
# 28 : Straight - [('3', 'Clubs'), ('7', 'Clubs')]
# 29 : Straight - [('7', 'Spades'), ('8', 'Spades')]
# 30 : Straight - [('7', 'Spades'), ('8', 'Hearts')]
# 31 : Straight - [('7', 'Spades'), ('8', 'Diamonds')]
# 32 : Straight - [('7', 'Spades'), ('8', 'Clubs')]
# 33 : Straight - [('7', 'Hearts'), ('8', 'Spades')]
# 34 : Straight - [('7', 'Hearts'), ('8', 'Hearts')]
# 35 : Straight - [('7', 'Hearts'), ('8', 'Diamonds')]
# 36 : Straight - [('7', 'Hearts'), ('8', 'Clubs')]
# 37 : Straight - [('7', 'Diamonds'), ('8', 'Spades')]
# 38 : Straight - [('7', 'Diamonds'), ('8', 'Hearts')]
# 39 : Straight - [('7', 'Diamonds'), ('8', 'Diamonds')]
# 40 : Straight - [('7', 'Diamonds'), ('8', 'Clubs')]
# 41 : Straight - [('7', 'Clubs'), ('8', 'Spades')]
# 42 : Straight - [('7', 'Clubs'), ('8', 'Hearts')]
# 43 : Straight - [('7', 'Clubs'), ('8', 'Diamonds')]
# 44 : Straight - [('7', 'Clubs'), ('8', 'Clubs')]
# 45 : Three of a kind - [('4', 'Spades'), ('4', 'Hearts')]
# 46 : Three of a kind - [('4', 'Spades'), ('4', 'Diamonds')]
# 47 : Three of a kind - [('4', 'Hearts'), ('4', 'Diamonds')]
# 48 : Three of a kind - [('5', 'Spades'), ('5', 'Hearts')]
# 49 : Three of a kind - [('5', 'Spades'), ('5', 'Clubs')]
# 50 : Three of a kind - [('5', 'Hearts'), ('5', 'Clubs')]
# 51 : Three of a kind - [('6', 'Spades'), ('6', 'Hearts')]
# 52 : Three of a kind - [('6', 'Spades'), ('6', 'Diamonds')]
# 53 : Three of a kind - [('6', 'Hearts'), ('6', 'Diamonds')]
# 54 : Three of a kind - [('9', 'Hearts'), ('9', 'Diamonds')]
# 55 : Three of a kind - [('9', 'Hearts'), ('9', 'Clubs')]
# 56 : Three of a kind - [('9', 'Diamonds'), ('9', 'Clubs')]
# 57 : Three of a kind - [('Q', 'Spades'), ('Q', 'Clubs')]
# 58 : Two pair - [('4', 'Spades'), ('5', 'Spades')]
# 59 : Two pair - [('4', 'Spades'), ('5', 'Hearts')]
# 60 : Two pair - [('4', 'Spades'), ('5', 'Clubs')]
# 61 : Two pair - [('4', 'Spades'), ('6', 'Spades')]
# 62 : Two pair - [('4', 'Spades'), ('6', 'Hearts')]
# 63 : Two pair - [('4', 'Spades'), ('6', 'Diamonds')]
# 64 : Two pair - [('4', 'Spades'), ('9', 'Hearts')]
# 65 : Two pair - [('4', 'Spades'), ('9', 'Diamonds')]
# 66 : Two pair - [('4', 'Spades'), ('9', 'Clubs')]
# 67 : Two pair - [('4', 'Spades'), ('Q', 'Spades')]
# 68 : Two pair - [('4', 'Spades'), ('Q', 'Clubs')]
# 69 : Two pair - [('4', 'Hearts'), ('5', 'Spades')]
# 70 : Two pair - [('4', 'Hearts'), ('5', 'Hearts')]
# 71 : Two pair - [('4', 'Hearts'), ('5', 'Clubs')]
# 72 : Two pair - [('4', 'Hearts'), ('6', 'Spades')]
# 73 : Two pair - [('4', 'Hearts'), ('6', 'Hearts')]
# 74 : Two pair - [('4', 'Hearts'), ('6', 'Diamonds')]
# 75 : Two pair - [('4', 'Hearts'), ('9', 'Hearts')]
# 76 : Two pair - [('4', 'Hearts'), ('9', 'Diamonds')]
# 77 : Two pair - [('4', 'Hearts'), ('9', 'Clubs')]
# 78 : Two pair - [('4', 'Hearts'), ('Q', 'Spades')]
# 79 : Two pair - [('4', 'Hearts'), ('Q', 'Clubs')]
# 80 : Two pair - [('4', 'Diamonds'), ('5', 'Spades')]
# 81 : Two pair - [('4', 'Diamonds'), ('5', 'Hearts')]
# 82 : Two pair - [('4', 'Diamonds'), ('5', 'Clubs')]
# 83 : Two pair - [('4', 'Diamonds'), ('6', 'Spades')]
# 84 : Two pair - [('4', 'Diamonds'), ('6', 'Hearts')]
# 85 : Two pair - [('4', 'Diamonds'), ('6', 'Diamonds')]
# 86 : Two pair - [('4', 'Diamonds'), ('9', 'Hearts')]
# 87 : Two pair - [('4', 'Diamonds'), ('9', 'Diamonds')]
# 88 : Two pair - [('4', 'Diamonds'), ('9', 'Clubs')]
# 89 : Two pair - [('4', 'Diamonds'), ('Q', 'Spades')]
# 90 : Two pair - [('4', 'Diamonds'), ('Q', 'Clubs')]
# 91 : Two pair - [('5', 'Spades'), ('6', 'Spades')]
# 92 : Two pair - [('5', 'Spades'), ('6', 'Hearts')]
# 93 : Two pair - [('5', 'Spades'), ('6', 'Diamonds')]
# 94 : Two pair - [('5', 'Spades'), ('9', 'Hearts')]
# 95 : Two pair - [('5', 'Spades'), ('9', 'Diamonds')]
# 96 : Two pair - [('5', 'Spades'), ('9', 'Clubs')]
# 97 : Two pair - [('5', 'Spades'), ('Q', 'Spades')]
# 98 : Two pair - [('5', 'Spades'), ('Q', 'Clubs')]
# 99 : Two pair - [('5', 'Hearts'), ('6', 'Spades')]
# 100 : Two pair - [('5', 'Hearts'), ('6', 'Hearts')]
# 101 : Two pair - [('5', 'Hearts'), ('6', 'Diamonds')]
# 102 : Two pair - [('5', 'Hearts'), ('9', 'Hearts')]
# 103 : Two pair - [('5', 'Hearts'), ('9', 'Diamonds')]
# 104 : Two pair - [('5', 'Hearts'), ('9', 'Clubs')]
# 105 : Two pair - [('5', 'Hearts'), ('Q', 'Spades')]
# 106 : Two pair - [('5', 'Hearts'), ('Q', 'Clubs')]
# 107 : Two pair - [('5', 'Clubs'), ('6', 'Spades')]
# 108 : Two pair - [('5', 'Clubs'), ('6', 'Hearts')]
# 109 : Two pair - [('5', 'Clubs'), ('6', 'Diamonds')]
# 110 : Two pair - [('5', 'Clubs'), ('9', 'Hearts')]
# 111 : Two pair - [('5', 'Clubs'), ('9', 'Diamonds')]
# 112 : Two pair - [('5', 'Clubs'), ('9', 'Clubs')]
# 113 : Two pair - [('5', 'Clubs'), ('Q', 'Spades')]
# 114 : Two pair - [('5', 'Clubs'), ('Q', 'Clubs')]
# 115 : Two pair - [('6', 'Spades'), ('9', 'Hearts')]
# 116 : Two pair - [('6', 'Spades'), ('9', 'Diamonds')]
# 117 : Two pair - [('6', 'Spades'), ('9', 'Clubs')]
# 118 : Two pair - [('6', 'Spades'), ('Q', 'Spades')]
# 119 : Two pair - [('6', 'Spades'), ('Q', 'Clubs')]
# 120 : Two pair - [('6', 'Hearts'), ('9', 'Hearts')]
# 121 : Two pair - [('6', 'Hearts'), ('9', 'Diamonds')]
# 122 : Two pair - [('6', 'Hearts'), ('9', 'Clubs')]
# 123 : Two pair - [('6', 'Hearts'), ('Q', 'Spades')]
# 124 : Two pair - [('6', 'Hearts'), ('Q', 'Clubs')]
# 125 : Two pair - [('6', 'Diamonds'), ('9', 'Hearts')]
# 126 : Two pair - [('6', 'Diamonds'), ('9', 'Diamonds')]
# 127 : Two pair - [('6', 'Diamonds'), ('9', 'Clubs')]
# 128 : Two pair - [('6', 'Diamonds'), ('Q', 'Spades')]
# 129 : Two pair - [('6', 'Diamonds'), ('Q', 'Clubs')]
# 130 : Two pair - [('9', 'Hearts'), ('Q', 'Spades')]
# 131 : Two pair - [('9', 'Hearts'), ('Q', 'Clubs')]
# 132 : Two pair - [('9', 'Diamonds'), ('Q', 'Spades')]
# 133 : Two pair - [('9', 'Diamonds'), ('Q', 'Clubs')]
# 134 : Two pair - [('9', 'Clubs'), ('Q', 'Spades')]
# 135 : Two pair - [('9', 'Clubs'), ('Q', 'Clubs')]
# 136 : Pair - [('2', 'Spades'), ('2', 'Hearts')]
# 137 : Pair - [('2', 'Spades'), ('2', 'Diamonds')]
# 138 : Pair - [('2', 'Spades'), ('4', 'Spades')]
# 139 : Pair - [('2', 'Spades'), ('4', 'Hearts')]
# 140 : Pair - [('2', 'Spades'), ('4', 'Diamonds')]
# 141 : Pair - [('2', 'Spades'), ('5', 'Spades')]
# 142 : Pair - [('2', 'Spades'), ('5', 'Hearts')]
# 143 : Pair - [('2', 'Spades'), ('5', 'Clubs')]
# 144 : Pair - [('2', 'Spades'), ('6', 'Spades')]
# 145 : Pair - [('2', 'Spades'), ('6', 'Hearts')]
# 146 : Pair - [('2', 'Spades'), ('6', 'Diamonds')]
# 147 : Pair - [('2', 'Spades'), ('9', 'Hearts')]
# 148 : Pair - [('2', 'Spades'), ('9', 'Diamonds')]
# 149 : Pair - [('2', 'Spades'), ('9', 'Clubs')]
# 150 : Pair - [('2', 'Spades'), ('Q', 'Spades')]
# 151 : Pair - [('2', 'Spades'), ('Q', 'Clubs')]
# 152 : Pair - [('2', 'Hearts'), ('2', 'Diamonds')]
# 153 : Pair - [('2', 'Hearts'), ('4', 'Spades')]
# 154 : Pair - [('2', 'Hearts'), ('4', 'Hearts')]
# 155 : Pair - [('2', 'Hearts'), ('4', 'Diamonds')]
# 156 : Pair - [('2', 'Hearts'), ('5', 'Spades')]
# 157 : Pair - [('2', 'Hearts'), ('5', 'Hearts')]
# 158 : Pair - [('2', 'Hearts'), ('5', 'Clubs')]
# 159 : Pair - [('2', 'Hearts'), ('6', 'Spades')]
# 160 : Pair - [('2', 'Hearts'), ('6', 'Hearts')]
# 161 : Pair - [('2', 'Hearts'), ('6', 'Diamonds')]
# 162 : Pair - [('2', 'Hearts'), ('9', 'Hearts')]
# 163 : Pair - [('2', 'Hearts'), ('9', 'Diamonds')]
# 164 : Pair - [('2', 'Hearts'), ('9', 'Clubs')]
# 165 : Pair - [('2', 'Hearts'), ('Q', 'Spades')]
# 166 : Pair - [('2', 'Hearts'), ('Q', 'Clubs')]
# 167 : Pair - [('2', 'Diamonds'), ('4', 'Spades')]
# 168 : Pair - [('2', 'Diamonds'), ('4', 'Hearts')]
# 169 : Pair - [('2', 'Diamonds'), ('4', 'Diamonds')]
# 170 : Pair - [('2', 'Diamonds'), ('5', 'Spades')]
# 171 : Pair - [('2', 'Diamonds'), ('5', 'Hearts')]
# 172 : Pair - [('2', 'Diamonds'), ('5', 'Clubs')]
# 173 : Pair - [('2', 'Diamonds'), ('6', 'Spades')]
# 174 : Pair - [('2', 'Diamonds'), ('6', 'Hearts')]
# 175 : Pair - [('2', 'Diamonds'), ('6', 'Diamonds')]
# 176 : Pair - [('2', 'Diamonds'), ('9', 'Hearts')]
# 177 : Pair - [('2', 'Diamonds'), ('9', 'Diamonds')]
# 178 : Pair - [('2', 'Diamonds'), ('9', 'Clubs')]
# 179 : Pair - [('2', 'Diamonds'), ('Q', 'Spades')]
# 180 : Pair - [('2', 'Diamonds'), ('Q', 'Clubs')]
# 181 : Pair - [('3', 'Spades'), ('3', 'Hearts')]
# 182 : Pair - [('3', 'Spades'), ('3', 'Diamonds')]
# 183 : Pair - [('3', 'Spades'), ('3', 'Clubs')]
# 184 : Pair - [('3', 'Spades'), ('4', 'Spades')]
# 185 : Pair - [('3', 'Spades'), ('4', 'Hearts')]
# 186 : Pair - [('3', 'Spades'), ('4', 'Diamonds')]
# 187 : Pair - [('3', 'Spades'), ('5', 'Spades')]
# 188 : Pair - [('3', 'Spades'), ('5', 'Hearts')]
# 189 : Pair - [('3', 'Spades'), ('5', 'Clubs')]
# 190 : Pair - [('3', 'Spades'), ('6', 'Spades')]
# 191 : Pair - [('3', 'Spades'), ('6', 'Hearts')]
# 192 : Pair - [('3', 'Spades'), ('6', 'Diamonds')]
# 193 : Pair - [('3', 'Spades'), ('9', 'Hearts')]
# 194 : Pair - [('3', 'Spades'), ('9', 'Diamonds')]
# 195 : Pair - [('3', 'Spades'), ('9', 'Clubs')]
# 196 : Pair - [('3', 'Spades'), ('Q', 'Spades')]
# 197 : Pair - [('3', 'Spades'), ('Q', 'Clubs')]
# 198 : Pair - [('3', 'Hearts'), ('3', 'Diamonds')]
# 199 : Pair - [('3', 'Hearts'), ('3', 'Clubs')]
# 200 : Pair - [('3', 'Hearts'), ('4', 'Spades')]
# 201 : Pair - [('3', 'Hearts'), ('4', 'Hearts')]
# 202 : Pair - [('3', 'Hearts'), ('4', 'Diamonds')]
# 203 : Pair - [('3', 'Hearts'), ('5', 'Spades')]
# 204 : Pair - [('3', 'Hearts'), ('5', 'Hearts')]
# 205 : Pair - [('3', 'Hearts'), ('5', 'Clubs')]
# 206 : Pair - [('3', 'Hearts'), ('6', 'Spades')]
# 207 : Pair - [('3', 'Hearts'), ('6', 'Hearts')]
# 208 : Pair - [('3', 'Hearts'), ('6', 'Diamonds')]
# 209 : Pair - [('3', 'Hearts'), ('9', 'Hearts')]
# 210 : Pair - [('3', 'Hearts'), ('9', 'Diamonds')]
# 211 : Pair - [('3', 'Hearts'), ('9', 'Clubs')]
# 212 : Pair - [('3', 'Hearts'), ('Q', 'Spades')]
# 213 : Pair - [('3', 'Hearts'), ('Q', 'Clubs')]
# 214 : Pair - [('3', 'Diamonds'), ('3', 'Clubs')]
# 215 : Pair - [('3', 'Diamonds'), ('4', 'Spades')]
# 216 : Pair - [('3', 'Diamonds'), ('4', 'Hearts')]
# 217 : Pair - [('3', 'Diamonds'), ('4', 'Diamonds')]
# 218 : Pair - [('3', 'Diamonds'), ('5', 'Spades')]
# 219 : Pair - [('3', 'Diamonds'), ('5', 'Hearts')]
# 220 : Pair - [('3', 'Diamonds'), ('5', 'Clubs')]
# 221 : Pair - [('3', 'Diamonds'), ('6', 'Spades')]
# 222 : Pair - [('3', 'Diamonds'), ('6', 'Hearts')]
# 223 : Pair - [('3', 'Diamonds'), ('6', 'Diamonds')]
# 224 : Pair - [('3', 'Diamonds'), ('9', 'Hearts')]
# 225 : Pair - [('3', 'Diamonds'), ('9', 'Diamonds')]
# 226 : Pair - [('3', 'Diamonds'), ('9', 'Clubs')]
# 227 : Pair - [('3', 'Diamonds'), ('Q', 'Spades')]
# 228 : Pair - [('3', 'Diamonds'), ('Q', 'Clubs')]
# 229 : Pair - [('3', 'Clubs'), ('4', 'Spades')]
# 230 : Pair - [('3', 'Clubs'), ('4', 'Hearts')]
# 231 : Pair - [('3', 'Clubs'), ('4', 'Diamonds')]
# 232 : Pair - [('3', 'Clubs'), ('5', 'Spades')]
# 233 : Pair - [('3', 'Clubs'), ('5', 'Hearts')]
# 234 : Pair - [('3', 'Clubs'), ('5', 'Clubs')]
# 235 : Pair - [('3', 'Clubs'), ('6', 'Spades')]
# 236 : Pair - [('3', 'Clubs'), ('6', 'Hearts')]
# 237 : Pair - [('3', 'Clubs'), ('6', 'Diamonds')]
# 238 : Pair - [('3', 'Clubs'), ('9', 'Hearts')]
# 239 : Pair - [('3', 'Clubs'), ('9', 'Diamonds')]
# 240 : Pair - [('3', 'Clubs'), ('9', 'Clubs')]
# 241 : Pair - [('3', 'Clubs'), ('Q', 'Spades')]
# 242 : Pair - [('3', 'Clubs'), ('Q', 'Clubs')]
# 243 : Pair - [('4', 'Spades'), ('7', 'Spades')]
# 244 : Pair - [('4', 'Spades'), ('7', 'Hearts')]
# 245 : Pair - [('4', 'Spades'), ('7', 'Diamonds')]
# 246 : Pair - [('4', 'Spades'), ('7', 'Clubs')]
# 247 : Pair - [('4', 'Spades'), ('8', 'Spades')]
# 248 : Pair - [('4', 'Spades'), ('8', 'Hearts')]
# 249 : Pair - [('4', 'Spades'), ('8', 'Diamonds')]
# 250 : Pair - [('4', 'Spades'), ('8', 'Clubs')]
# 251 : Pair - [('4', 'Spades'), ('T', 'Spades')]
# 252 : Pair - [('4', 'Spades'), ('T', 'Hearts')]
# 253 : Pair - [('4', 'Spades'), ('T', 'Diamonds')]
# 254 : Pair - [('4', 'Spades'), ('T', 'Clubs')]
# 255 : Pair - [('4', 'Spades'), ('J', 'Spades')]
# 256 : Pair - [('4', 'Spades'), ('J', 'Hearts')]
# 257 : Pair - [('4', 'Spades'), ('J', 'Diamonds')]
# 258 : Pair - [('4', 'Spades'), ('J', 'Clubs')]
# 259 : Pair - [('4', 'Spades'), ('K', 'Spades')]
# 260 : Pair - [('4', 'Spades'), ('K', 'Hearts')]
# 261 : Pair - [('4', 'Spades'), ('K', 'Diamonds')]
# 262 : Pair - [('4', 'Spades'), ('K', 'Clubs')]
# 263 : Pair - [('4', 'Spades'), ('A', 'Spades')]
# 264 : Pair - [('4', 'Spades'), ('A', 'Hearts')]
# 265 : Pair - [('4', 'Spades'), ('A', 'Diamonds')]
# 266 : Pair - [('4', 'Spades'), ('A', 'Clubs')]
# 267 : Pair - [('4', 'Hearts'), ('7', 'Spades')]
# 268 : Pair - [('4', 'Hearts'), ('7', 'Hearts')]
# 269 : Pair - [('4', 'Hearts'), ('7', 'Diamonds')]
# 270 : Pair - [('4', 'Hearts'), ('7', 'Clubs')]
# 271 : Pair - [('4', 'Hearts'), ('8', 'Spades')]
# 272 : Pair - [('4', 'Hearts'), ('8', 'Hearts')]
# 273 : Pair - [('4', 'Hearts'), ('8', 'Diamonds')]
# 274 : Pair - [('4', 'Hearts'), ('8', 'Clubs')]
# 275 : Pair - [('4', 'Hearts'), ('T', 'Spades')]
# 276 : Pair - [('4', 'Hearts'), ('T', 'Hearts')]
# 277 : Pair - [('4', 'Hearts'), ('T', 'Diamonds')]
# 278 : Pair - [('4', 'Hearts'), ('T', 'Clubs')]
# 279 : Pair - [('4', 'Hearts'), ('J', 'Spades')]
# 280 : Pair - [('4', 'Hearts'), ('J', 'Hearts')]
# 281 : Pair - [('4', 'Hearts'), ('J', 'Diamonds')]
# 282 : Pair - [('4', 'Hearts'), ('J', 'Clubs')]
# 283 : Pair - [('4', 'Hearts'), ('K', 'Spades')]
# 284 : Pair - [('4', 'Hearts'), ('K', 'Hearts')]
# 285 : Pair - [('4', 'Hearts'), ('K', 'Diamonds')]
# 286 : Pair - [('4', 'Hearts'), ('K', 'Clubs')]
# 287 : Pair - [('4', 'Hearts'), ('A', 'Spades')]
# 288 : Pair - [('4', 'Hearts'), ('A', 'Hearts')]
# 289 : Pair - [('4', 'Hearts'), ('A', 'Diamonds')]
# 290 : Pair - [('4', 'Hearts'), ('A', 'Clubs')]
# 291 : Pair - [('4', 'Diamonds'), ('7', 'Spades')]
# 292 : Pair - [('4', 'Diamonds'), ('7', 'Hearts')]
# 293 : Pair - [('4', 'Diamonds'), ('7', 'Diamonds')]
# 294 : Pair - [('4', 'Diamonds'), ('7', 'Clubs')]
# 295 : Pair - [('4', 'Diamonds'), ('8', 'Spades')]
# 296 : Pair - [('4', 'Diamonds'), ('8', 'Hearts')]
# 297 : Pair - [('4', 'Diamonds'), ('8', 'Diamonds')]
# 298 : Pair - [('4', 'Diamonds'), ('8', 'Clubs')]
# 299 : Pair - [('4', 'Diamonds'), ('T', 'Spades')]
# 300 : Pair - [('4', 'Diamonds'), ('T', 'Hearts')]
# 301 : Pair - [('4', 'Diamonds'), ('T', 'Diamonds')]
# 302 : Pair - [('4', 'Diamonds'), ('T', 'Clubs')]
# 303 : Pair - [('4', 'Diamonds'), ('J', 'Spades')]
# 304 : Pair - [('4', 'Diamonds'), ('J', 'Hearts')]
# 305 : Pair - [('4', 'Diamonds'), ('J', 'Diamonds')]
# 306 : Pair - [('4', 'Diamonds'), ('J', 'Clubs')]
# 307 : Pair - [('4', 'Diamonds'), ('K', 'Spades')]
# 308 : Pair - [('4', 'Diamonds'), ('K', 'Hearts')]
# 309 : Pair - [('4', 'Diamonds'), ('K', 'Diamonds')]
# 310 : Pair - [('4', 'Diamonds'), ('K', 'Clubs')]
# 311 : Pair - [('4', 'Diamonds'), ('A', 'Spades')]
# 312 : Pair - [('4', 'Diamonds'), ('A', 'Hearts')]
# 313 : Pair - [('4', 'Diamonds'), ('A', 'Diamonds')]
# 314 : Pair - [('4', 'Diamonds'), ('A', 'Clubs')]
# 315 : Pair - [('5', 'Spades'), ('7', 'Spades')]
# 316 : Pair - [('5', 'Spades'), ('7', 'Hearts')]
# 317 : Pair - [('5', 'Spades'), ('7', 'Diamonds')]
# 318 : Pair - [('5', 'Spades'), ('7', 'Clubs')]
# 319 : Pair - [('5', 'Spades'), ('8', 'Spades')]
# 320 : Pair - [('5', 'Spades'), ('8', 'Hearts')]
# 321 : Pair - [('5', 'Spades'), ('8', 'Diamonds')]
# 322 : Pair - [('5', 'Spades'), ('8', 'Clubs')]
# 323 : Pair - [('5', 'Spades'), ('T', 'Spades')]
# 324 : Pair - [('5', 'Spades'), ('T', 'Hearts')]
# 325 : Pair - [('5', 'Spades'), ('T', 'Diamonds')]
# 326 : Pair - [('5', 'Spades'), ('T', 'Clubs')]
# 327 : Pair - [('5', 'Spades'), ('J', 'Spades')]
# 328 : Pair - [('5', 'Spades'), ('J', 'Hearts')]
# 329 : Pair - [('5', 'Spades'), ('J', 'Diamonds')]
# 330 : Pair - [('5', 'Spades'), ('J', 'Clubs')]
# 331 : Pair - [('5', 'Spades'), ('K', 'Spades')]
# 332 : Pair - [('5', 'Spades'), ('K', 'Hearts')]
# 333 : Pair - [('5', 'Spades'), ('K', 'Diamonds')]
# 334 : Pair - [('5', 'Spades'), ('K', 'Clubs')]
# 335 : Pair - [('5', 'Spades'), ('A', 'Spades')]
# 336 : Pair - [('5', 'Spades'), ('A', 'Hearts')]
# 337 : Pair - [('5', 'Spades'), ('A', 'Diamonds')]
# 338 : Pair - [('5', 'Spades'), ('A', 'Clubs')]
# 339 : Pair - [('5', 'Hearts'), ('7', 'Spades')]
# 340 : Pair - [('5', 'Hearts'), ('7', 'Hearts')]
# 341 : Pair - [('5', 'Hearts'), ('7', 'Diamonds')]
# 342 : Pair - [('5', 'Hearts'), ('7', 'Clubs')]
# 343 : Pair - [('5', 'Hearts'), ('8', 'Spades')]
# 344 : Pair - [('5', 'Hearts'), ('8', 'Hearts')]
# 345 : Pair - [('5', 'Hearts'), ('8', 'Diamonds')]
# 346 : Pair - [('5', 'Hearts'), ('8', 'Clubs')]
# 347 : Pair - [('5', 'Hearts'), ('T', 'Spades')]
# 348 : Pair - [('5', 'Hearts'), ('T', 'Hearts')]
# 349 : Pair - [('5', 'Hearts'), ('T', 'Diamonds')]
# 350 : Pair - [('5', 'Hearts'), ('T', 'Clubs')]
# 351 : Pair - [('5', 'Hearts'), ('J', 'Spades')]
# 352 : Pair - [('5', 'Hearts'), ('J', 'Hearts')]
# 353 : Pair - [('5', 'Hearts'), ('J', 'Diamonds')]
# 354 : Pair - [('5', 'Hearts'), ('J', 'Clubs')]
# 355 : Pair - [('5', 'Hearts'), ('K', 'Spades')]
# 356 : Pair - [('5', 'Hearts'), ('K', 'Hearts')]
# 357 : Pair - [('5', 'Hearts'), ('K', 'Diamonds')]
# 358 : Pair - [('5', 'Hearts'), ('K', 'Clubs')]
# 359 : Pair - [('5', 'Hearts'), ('A', 'Spades')]
# 360 : Pair - [('5', 'Hearts'), ('A', 'Hearts')]
# 361 : Pair - [('5', 'Hearts'), ('A', 'Diamonds')]
# 362 : Pair - [('5', 'Hearts'), ('A', 'Clubs')]
# 363 : Pair - [('5', 'Clubs'), ('7', 'Spades')]
# 364 : Pair - [('5', 'Clubs'), ('7', 'Hearts')]
# 365 : Pair - [('5', 'Clubs'), ('7', 'Diamonds')]
# 366 : Pair - [('5', 'Clubs'), ('7', 'Clubs')]
# 367 : Pair - [('5', 'Clubs'), ('8', 'Spades')]
# 368 : Pair - [('5', 'Clubs'), ('8', 'Hearts')]
# 369 : Pair - [('5', 'Clubs'), ('8', 'Diamonds')]
# 370 : Pair - [('5', 'Clubs'), ('8', 'Clubs')]
# 371 : Pair - [('5', 'Clubs'), ('T', 'Spades')]
# 372 : Pair - [('5', 'Clubs'), ('T', 'Hearts')]
# 373 : Pair - [('5', 'Clubs'), ('T', 'Diamonds')]
# 374 : Pair - [('5', 'Clubs'), ('T', 'Clubs')]
# 375 : Pair - [('5', 'Clubs'), ('J', 'Spades')]
# 376 : Pair - [('5', 'Clubs'), ('J', 'Hearts')]
# 377 : Pair - [('5', 'Clubs'), ('J', 'Diamonds')]
# 378 : Pair - [('5', 'Clubs'), ('J', 'Clubs')]
# 379 : Pair - [('5', 'Clubs'), ('K', 'Spades')]
# 380 : Pair - [('5', 'Clubs'), ('K', 'Hearts')]
# 381 : Pair - [('5', 'Clubs'), ('K', 'Diamonds')]
# 382 : Pair - [('5', 'Clubs'), ('K', 'Clubs')]
# 383 : Pair - [('5', 'Clubs'), ('A', 'Spades')]
# 384 : Pair - [('5', 'Clubs'), ('A', 'Hearts')]
# 385 : Pair - [('5', 'Clubs'), ('A', 'Diamonds')]
# 386 : Pair - [('5', 'Clubs'), ('A', 'Clubs')]
# 387 : Pair - [('6', 'Spades'), ('7', 'Spades')]
# 388 : Pair - [('6', 'Spades'), ('7', 'Hearts')]
# 389 : Pair - [('6', 'Spades'), ('7', 'Diamonds')]
# 390 : Pair - [('6', 'Spades'), ('7', 'Clubs')]
# 391 : Pair - [('6', 'Spades'), ('8', 'Spades')]
# 392 : Pair - [('6', 'Spades'), ('8', 'Hearts')]
# 393 : Pair - [('6', 'Spades'), ('8', 'Diamonds')]
# 394 : Pair - [('6', 'Spades'), ('8', 'Clubs')]
# 395 : Pair - [('6', 'Spades'), ('T', 'Spades')]
# 396 : Pair - [('6', 'Spades'), ('T', 'Hearts')]
# 397 : Pair - [('6', 'Spades'), ('T', 'Diamonds')]
# 398 : Pair - [('6', 'Spades'), ('T', 'Clubs')]
# 399 : Pair - [('6', 'Spades'), ('J', 'Spades')]
# 400 : Pair - [('6', 'Spades'), ('J', 'Hearts')]
# 401 : Pair - [('6', 'Spades'), ('J', 'Diamonds')]
# 402 : Pair - [('6', 'Spades'), ('J', 'Clubs')]
# 403 : Pair - [('6', 'Spades'), ('K', 'Spades')]
# 404 : Pair - [('6', 'Spades'), ('K', 'Hearts')]
# 405 : Pair - [('6', 'Spades'), ('K', 'Diamonds')]
# 406 : Pair - [('6', 'Spades'), ('K', 'Clubs')]
# 407 : Pair - [('6', 'Spades'), ('A', 'Spades')]
# 408 : Pair - [('6', 'Spades'), ('A', 'Hearts')]
# 409 : Pair - [('6', 'Spades'), ('A', 'Diamonds')]
# 410 : Pair - [('6', 'Spades'), ('A', 'Clubs')]
# 411 : Pair - [('6', 'Hearts'), ('7', 'Spades')]
# 412 : Pair - [('6', 'Hearts'), ('7', 'Hearts')]
# 413 : Pair - [('6', 'Hearts'), ('7', 'Diamonds')]
# 414 : Pair - [('6', 'Hearts'), ('7', 'Clubs')]
# 415 : Pair - [('6', 'Hearts'), ('8', 'Spades')]
# 416 : Pair - [('6', 'Hearts'), ('8', 'Hearts')]
# 417 : Pair - [('6', 'Hearts'), ('8', 'Diamonds')]
# 418 : Pair - [('6', 'Hearts'), ('8', 'Clubs')]
# 419 : Pair - [('6', 'Hearts'), ('T', 'Spades')]
# 420 : Pair - [('6', 'Hearts'), ('T', 'Hearts')]
# 421 : Pair - [('6', 'Hearts'), ('T', 'Diamonds')]
# 422 : Pair - [('6', 'Hearts'), ('T', 'Clubs')]
# 423 : Pair - [('6', 'Hearts'), ('J', 'Spades')]
# 424 : Pair - [('6', 'Hearts'), ('J', 'Hearts')]
# 425 : Pair - [('6', 'Hearts'), ('J', 'Diamonds')]
# 426 : Pair - [('6', 'Hearts'), ('J', 'Clubs')]
# 427 : Pair - [('6', 'Hearts'), ('K', 'Spades')]
# 428 : Pair - [('6', 'Hearts'), ('K', 'Hearts')]
# 429 : Pair - [('6', 'Hearts'), ('K', 'Diamonds')]
# 430 : Pair - [('6', 'Hearts'), ('K', 'Clubs')]
# 431 : Pair - [('6', 'Hearts'), ('A', 'Spades')]
# 432 : Pair - [('6', 'Hearts'), ('A', 'Hearts')]
# 433 : Pair - [('6', 'Hearts'), ('A', 'Diamonds')]
# 434 : Pair - [('6', 'Hearts'), ('A', 'Clubs')]
# 435 : Pair - [('6', 'Diamonds'), ('7', 'Spades')]
# 436 : Pair - [('6', 'Diamonds'), ('7', 'Hearts')]
# 437 : Pair - [('6', 'Diamonds'), ('7', 'Diamonds')]
# 438 : Pair - [('6', 'Diamonds'), ('7', 'Clubs')]
# 439 : Pair - [('6', 'Diamonds'), ('8', 'Spades')]
# 440 : Pair - [('6', 'Diamonds'), ('8', 'Hearts')]
# 441 : Pair - [('6', 'Diamonds'), ('8', 'Diamonds')]
# 442 : Pair - [('6', 'Diamonds'), ('8', 'Clubs')]
# 443 : Pair - [('6', 'Diamonds'), ('T', 'Spades')]
# 444 : Pair - [('6', 'Diamonds'), ('T', 'Hearts')]
# 445 : Pair - [('6', 'Diamonds'), ('T', 'Diamonds')]
# 446 : Pair - [('6', 'Diamonds'), ('T', 'Clubs')]
# 447 : Pair - [('6', 'Diamonds'), ('J', 'Spades')]
# 448 : Pair - [('6', 'Diamonds'), ('J', 'Hearts')]
# 449 : Pair - [('6', 'Diamonds'), ('J', 'Diamonds')]
# 450 : Pair - [('6', 'Diamonds'), ('J', 'Clubs')]
# 451 : Pair - [('6', 'Diamonds'), ('K', 'Spades')]
# 452 : Pair - [('6', 'Diamonds'), ('K', 'Hearts')]
# 453 : Pair - [('6', 'Diamonds'), ('K', 'Diamonds')]
# 454 : Pair - [('6', 'Diamonds'), ('K', 'Clubs')]
# 455 : Pair - [('6', 'Diamonds'), ('A', 'Spades')]
# 456 : Pair - [('6', 'Diamonds'), ('A', 'Hearts')]
# 457 : Pair - [('6', 'Diamonds'), ('A', 'Diamonds')]
# 458 : Pair - [('6', 'Diamonds'), ('A', 'Clubs')]
# 459 : Pair - [('7', 'Spades'), ('7', 'Hearts')]
# 460 : Pair - [('7', 'Spades'), ('7', 'Diamonds')]
# 461 : Pair - [('7', 'Spades'), ('7', 'Clubs')]
# 462 : Pair - [('7', 'Spades'), ('9', 'Hearts')]
# 463 : Pair - [('7', 'Spades'), ('9', 'Diamonds')]
# 464 : Pair - [('7', 'Spades'), ('9', 'Clubs')]
# 465 : Pair - [('7', 'Spades'), ('Q', 'Spades')]
# 466 : Pair - [('7', 'Spades'), ('Q', 'Clubs')]
# 467 : Pair - [('7', 'Hearts'), ('7', 'Diamonds')]
# 468 : Pair - [('7', 'Hearts'), ('7', 'Clubs')]
# 469 : Pair - [('7', 'Hearts'), ('9', 'Hearts')]
# 470 : Pair - [('7', 'Hearts'), ('9', 'Diamonds')]
# 471 : Pair - [('7', 'Hearts'), ('9', 'Clubs')]
# 472 : Pair - [('7', 'Hearts'), ('Q', 'Spades')]
# 473 : Pair - [('7', 'Hearts'), ('Q', 'Clubs')]
# 474 : Pair - [('7', 'Diamonds'), ('7', 'Clubs')]
# 475 : Pair - [('7', 'Diamonds'), ('9', 'Hearts')]
# 476 : Pair - [('7', 'Diamonds'), ('9', 'Diamonds')]
# 477 : Pair - [('7', 'Diamonds'), ('9', 'Clubs')]
# 478 : Pair - [('7', 'Diamonds'), ('Q', 'Spades')]
# 479 : Pair - [('7', 'Diamonds'), ('Q', 'Clubs')]
# 480 : Pair - [('7', 'Clubs'), ('9', 'Hearts')]
# 481 : Pair - [('7', 'Clubs'), ('9', 'Diamonds')]
# 482 : Pair - [('7', 'Clubs'), ('9', 'Clubs')]
# 483 : Pair - [('7', 'Clubs'), ('Q', 'Spades')]
# 484 : Pair - [('7', 'Clubs'), ('Q', 'Clubs')]
# 485 : Pair - [('8', 'Spades'), ('8', 'Hearts')]
# 486 : Pair - [('8', 'Spades'), ('8', 'Diamonds')]
# 487 : Pair - [('8', 'Spades'), ('8', 'Clubs')]
# 488 : Pair - [('8', 'Spades'), ('9', 'Hearts')]
# 489 : Pair - [('8', 'Spades'), ('9', 'Diamonds')]
# 490 : Pair - [('8', 'Spades'), ('9', 'Clubs')]
# 491 : Pair - [('8', 'Spades'), ('Q', 'Spades')]
# 492 : Pair - [('8', 'Spades'), ('Q', 'Clubs')]
# 493 : Pair - [('8', 'Hearts'), ('8', 'Diamonds')]
# 494 : Pair - [('8', 'Hearts'), ('8', 'Clubs')]
# 495 : Pair - [('8', 'Hearts'), ('9', 'Hearts')]
# 496 : Pair - [('8', 'Hearts'), ('9', 'Diamonds')]
# 497 : Pair - [('8', 'Hearts'), ('9', 'Clubs')]
# 498 : Pair - [('8', 'Hearts'), ('Q', 'Spades')]
# 499 : Pair - [('8', 'Hearts'), ('Q', 'Clubs')]
# 500 : Pair - [('8', 'Diamonds'), ('8', 'Clubs')]
# 501 : Pair - [('8', 'Diamonds'), ('9', 'Hearts')]
# 502 : Pair - [('8', 'Diamonds'), ('9', 'Diamonds')]
# 503 : Pair - [('8', 'Diamonds'), ('9', 'Clubs')]
# 504 : Pair - [('8', 'Diamonds'), ('Q', 'Spades')]
# 505 : Pair - [('8', 'Diamonds'), ('Q', 'Clubs')]
# 506 : Pair - [('8', 'Clubs'), ('9', 'Hearts')]
# 507 : Pair - [('8', 'Clubs'), ('9', 'Diamonds')]
# 508 : Pair - [('8', 'Clubs'), ('9', 'Clubs')]
# 509 : Pair - [('8', 'Clubs'), ('Q', 'Spades')]
# 510 : Pair - [('8', 'Clubs'), ('Q', 'Clubs')]
# 511 : Pair - [('9', 'Hearts'), ('T', 'Spades')]
# 512 : Pair - [('9', 'Hearts'), ('T', 'Hearts')]
# 513 : Pair - [('9', 'Hearts'), ('T', 'Diamonds')]
# 514 : Pair - [('9', 'Hearts'), ('T', 'Clubs')]
# 515 : Pair - [('9', 'Hearts'), ('J', 'Spades')]
# 516 : Pair - [('9', 'Hearts'), ('J', 'Hearts')]
# 517 : Pair - [('9', 'Hearts'), ('J', 'Diamonds')]
# 518 : Pair - [('9', 'Hearts'), ('J', 'Clubs')]
# 519 : Pair - [('9', 'Hearts'), ('K', 'Spades')]
# 520 : Pair - [('9', 'Hearts'), ('K', 'Hearts')]
# 521 : Pair - [('9', 'Hearts'), ('K', 'Diamonds')]
# 522 : Pair - [('9', 'Hearts'), ('K', 'Clubs')]
# 523 : Pair - [('9', 'Hearts'), ('A', 'Spades')]
# 524 : Pair - [('9', 'Hearts'), ('A', 'Hearts')]
# 525 : Pair - [('9', 'Hearts'), ('A', 'Diamonds')]
# 526 : Pair - [('9', 'Hearts'), ('A', 'Clubs')]
# 527 : Pair - [('9', 'Diamonds'), ('T', 'Spades')]
# 528 : Pair - [('9', 'Diamonds'), ('T', 'Hearts')]
# 529 : Pair - [('9', 'Diamonds'), ('T', 'Diamonds')]
# 530 : Pair - [('9', 'Diamonds'), ('T', 'Clubs')]
# 531 : Pair - [('9', 'Diamonds'), ('J', 'Spades')]
# 532 : Pair - [('9', 'Diamonds'), ('J', 'Hearts')]
# 533 : Pair - [('9', 'Diamonds'), ('J', 'Diamonds')]
# 534 : Pair - [('9', 'Diamonds'), ('J', 'Clubs')]
# 535 : Pair - [('9', 'Diamonds'), ('K', 'Spades')]
# 536 : Pair - [('9', 'Diamonds'), ('K', 'Hearts')]
# 537 : Pair - [('9', 'Diamonds'), ('K', 'Diamonds')]
# 538 : Pair - [('9', 'Diamonds'), ('K', 'Clubs')]
# 539 : Pair - [('9', 'Diamonds'), ('A', 'Spades')]
# 540 : Pair - [('9', 'Diamonds'), ('A', 'Hearts')]
# 541 : Pair - [('9', 'Diamonds'), ('A', 'Diamonds')]
# 542 : Pair - [('9', 'Diamonds'), ('A', 'Clubs')]
# 543 : Pair - [('9', 'Clubs'), ('T', 'Spades')]
# 544 : Pair - [('9', 'Clubs'), ('T', 'Hearts')]
# 545 : Pair - [('9', 'Clubs'), ('T', 'Diamonds')]
# 546 : Pair - [('9', 'Clubs'), ('T', 'Clubs')]
# 547 : Pair - [('9', 'Clubs'), ('J', 'Spades')]
# 548 : Pair - [('9', 'Clubs'), ('J', 'Hearts')]
# 549 : Pair - [('9', 'Clubs'), ('J', 'Diamonds')]
# 550 : Pair - [('9', 'Clubs'), ('J', 'Clubs')]
# 551 : Pair - [('9', 'Clubs'), ('K', 'Spades')]
# 552 : Pair - [('9', 'Clubs'), ('K', 'Hearts')]
# 553 : Pair - [('9', 'Clubs'), ('K', 'Diamonds')]
# 554 : Pair - [('9', 'Clubs'), ('K', 'Clubs')]
# 555 : Pair - [('9', 'Clubs'), ('A', 'Spades')]
# 556 : Pair - [('9', 'Clubs'), ('A', 'Hearts')]
# 557 : Pair - [('9', 'Clubs'), ('A', 'Diamonds')]
# 558 : Pair - [('9', 'Clubs'), ('A', 'Clubs')]
# 559 : Pair - [('T', 'Spades'), ('T', 'Hearts')]
# 560 : Pair - [('T', 'Spades'), ('T', 'Diamonds')]
# 561 : Pair - [('T', 'Spades'), ('T', 'Clubs')]
# 562 : Pair - [('T', 'Spades'), ('Q', 'Spades')]
# 563 : Pair - [('T', 'Spades'), ('Q', 'Clubs')]
# 564 : Pair - [('T', 'Hearts'), ('T', 'Diamonds')]
# 565 : Pair - [('T', 'Hearts'), ('T', 'Clubs')]
# 566 : Pair - [('T', 'Hearts'), ('Q', 'Spades')]
# 567 : Pair - [('T', 'Hearts'), ('Q', 'Clubs')]
# 568 : Pair - [('T', 'Diamonds'), ('T', 'Clubs')]
# 569 : Pair - [('T', 'Diamonds'), ('Q', 'Spades')]
# 570 : Pair - [('T', 'Diamonds'), ('Q', 'Clubs')]
# 571 : Pair - [('T', 'Clubs'), ('Q', 'Spades')]
# 572 : Pair - [('T', 'Clubs'), ('Q', 'Clubs')]
# 573 : Pair - [('J', 'Spades'), ('J', 'Hearts')]
# 574 : Pair - [('J', 'Spades'), ('J', 'Diamonds')]
# 575 : Pair - [('J', 'Spades'), ('J', 'Clubs')]
# 576 : Pair - [('J', 'Spades'), ('Q', 'Spades')]
# 577 : Pair - [('J', 'Spades'), ('Q', 'Clubs')]
# 578 : Pair - [('J', 'Hearts'), ('J', 'Diamonds')]
# 579 : Pair - [('J', 'Hearts'), ('J', 'Clubs')]
# 580 : Pair - [('J', 'Hearts'), ('Q', 'Spades')]
# 581 : Pair - [('J', 'Hearts'), ('Q', 'Clubs')]
# 582 : Pair - [('J', 'Diamonds'), ('J', 'Clubs')]
# 583 : Pair - [('J', 'Diamonds'), ('Q', 'Spades')]
# 584 : Pair - [('J', 'Diamonds'), ('Q', 'Clubs')]
# 585 : Pair - [('J', 'Clubs'), ('Q', 'Spades')]
# 586 : Pair - [('J', 'Clubs'), ('Q', 'Clubs')]
# 587 : Pair - [('Q', 'Spades'), ('K', 'Spades')]
# 588 : Pair - [('Q', 'Spades'), ('K', 'Hearts')]
# 589 : Pair - [('Q', 'Spades'), ('K', 'Diamonds')]
# 590 : Pair - [('Q', 'Spades'), ('K', 'Clubs')]
# 591 : Pair - [('Q', 'Spades'), ('A', 'Spades')]
# 592 : Pair - [('Q', 'Spades'), ('A', 'Hearts')]
# 593 : Pair - [('Q', 'Spades'), ('A', 'Diamonds')]
# 594 : Pair - [('Q', 'Spades'), ('A', 'Clubs')]
# 595 : Pair - [('Q', 'Clubs'), ('K', 'Spades')]
# 596 : Pair - [('Q', 'Clubs'), ('K', 'Hearts')]
# 597 : Pair - [('Q', 'Clubs'), ('K', 'Diamonds')]
# 598 : Pair - [('Q', 'Clubs'), ('K', 'Clubs')]
# 599 : Pair - [('Q', 'Clubs'), ('A', 'Spades')]
# 600 : Pair - [('Q', 'Clubs'), ('A', 'Hearts')]
# 601 : Pair - [('Q', 'Clubs'), ('A', 'Diamonds')]
# 602 : Pair - [('Q', 'Clubs'), ('A', 'Clubs')]
# 603 : Pair - [('K', 'Spades'), ('K', 'Hearts')]
# 604 : Pair - [('K', 'Spades'), ('K', 'Diamonds')]
# 605 : Pair - [('K', 'Spades'), ('K', 'Clubs')]
# 606 : Pair - [('K', 'Hearts'), ('K', 'Diamonds')]
# 607 : Pair - [('K', 'Hearts'), ('K', 'Clubs')]
# 608 : Pair - [('K', 'Diamonds'), ('K', 'Clubs')]
# 609 : Pair - [('A', 'Spades'), ('A', 'Hearts')]
# 610 : Pair - [('A', 'Spades'), ('A', 'Diamonds')]
# 611 : Pair - [('A', 'Spades'), ('A', 'Clubs')]
# 612 : Pair - [('A', 'Hearts'), ('A', 'Diamonds')]
# 613 : Pair - [('A', 'Hearts'), ('A', 'Clubs')]
# 614 : Pair - [('A', 'Diamonds'), ('A', 'Clubs')]
# 615 : High card - [('2', 'Spades'), ('7', 'Spades')]
# 616 : High card - [('2', 'Spades'), ('7', 'Hearts')]
# 617 : High card - [('2', 'Spades'), ('7', 'Diamonds')]
# 618 : High card - [('2', 'Spades'), ('7', 'Clubs')]
# 619 : High card - [('2', 'Spades'), ('8', 'Spades')]
# 620 : High card - [('2', 'Spades'), ('8', 'Hearts')]
# 621 : High card - [('2', 'Spades'), ('8', 'Diamonds')]
# 622 : High card - [('2', 'Spades'), ('8', 'Clubs')]
# 623 : High card - [('2', 'Spades'), ('T', 'Spades')]
# 624 : High card - [('2', 'Spades'), ('T', 'Hearts')]
# 625 : High card - [('2', 'Spades'), ('T', 'Diamonds')]
# 626 : High card - [('2', 'Spades'), ('T', 'Clubs')]
# 627 : High card - [('2', 'Spades'), ('J', 'Spades')]
# 628 : High card - [('2', 'Spades'), ('J', 'Hearts')]
# 629 : High card - [('2', 'Spades'), ('J', 'Diamonds')]
# 630 : High card - [('2', 'Spades'), ('J', 'Clubs')]
# 631 : High card - [('2', 'Spades'), ('K', 'Spades')]
# 632 : High card - [('2', 'Spades'), ('K', 'Hearts')]
# 633 : High card - [('2', 'Spades'), ('K', 'Diamonds')]
# 634 : High card - [('2', 'Spades'), ('K', 'Clubs')]
# 635 : High card - [('2', 'Spades'), ('A', 'Spades')]
# 636 : High card - [('2', 'Spades'), ('A', 'Hearts')]
# 637 : High card - [('2', 'Spades'), ('A', 'Diamonds')]
# 638 : High card - [('2', 'Spades'), ('A', 'Clubs')]
# 639 : High card - [('2', 'Hearts'), ('7', 'Spades')]
# 640 : High card - [('2', 'Hearts'), ('7', 'Hearts')]
# 641 : High card - [('2', 'Hearts'), ('7', 'Diamonds')]
# 642 : High card - [('2', 'Hearts'), ('7', 'Clubs')]
# 643 : High card - [('2', 'Hearts'), ('8', 'Spades')]
# 644 : High card - [('2', 'Hearts'), ('8', 'Hearts')]
# 645 : High card - [('2', 'Hearts'), ('8', 'Diamonds')]
# 646 : High card - [('2', 'Hearts'), ('8', 'Clubs')]
# 647 : High card - [('2', 'Hearts'), ('T', 'Spades')]
# 648 : High card - [('2', 'Hearts'), ('T', 'Hearts')]
# 649 : High card - [('2', 'Hearts'), ('T', 'Diamonds')]
# 650 : High card - [('2', 'Hearts'), ('T', 'Clubs')]
# 651 : High card - [('2', 'Hearts'), ('J', 'Spades')]
# 652 : High card - [('2', 'Hearts'), ('J', 'Hearts')]
# 653 : High card - [('2', 'Hearts'), ('J', 'Diamonds')]
# 654 : High card - [('2', 'Hearts'), ('J', 'Clubs')]
# 655 : High card - [('2', 'Hearts'), ('K', 'Spades')]
# 656 : High card - [('2', 'Hearts'), ('K', 'Hearts')]
# 657 : High card - [('2', 'Hearts'), ('K', 'Diamonds')]
# 658 : High card - [('2', 'Hearts'), ('K', 'Clubs')]
# 659 : High card - [('2', 'Hearts'), ('A', 'Spades')]
# 660 : High card - [('2', 'Hearts'), ('A', 'Hearts')]
# 661 : High card - [('2', 'Hearts'), ('A', 'Diamonds')]
# 662 : High card - [('2', 'Hearts'), ('A', 'Clubs')]
# 663 : High card - [('2', 'Diamonds'), ('7', 'Spades')]
# 664 : High card - [('2', 'Diamonds'), ('7', 'Hearts')]
# 665 : High card - [('2', 'Diamonds'), ('7', 'Diamonds')]
# 666 : High card - [('2', 'Diamonds'), ('7', 'Clubs')]
# 667 : High card - [('2', 'Diamonds'), ('8', 'Spades')]
# 668 : High card - [('2', 'Diamonds'), ('8', 'Hearts')]
# 669 : High card - [('2', 'Diamonds'), ('8', 'Diamonds')]
# 670 : High card - [('2', 'Diamonds'), ('8', 'Clubs')]
# 671 : High card - [('2', 'Diamonds'), ('T', 'Spades')]
# 672 : High card - [('2', 'Diamonds'), ('T', 'Hearts')]
# 673 : High card - [('2', 'Diamonds'), ('T', 'Diamonds')]
# 674 : High card - [('2', 'Diamonds'), ('T', 'Clubs')]
# 675 : High card - [('2', 'Diamonds'), ('J', 'Spades')]
# 676 : High card - [('2', 'Diamonds'), ('J', 'Hearts')]
# 677 : High card - [('2', 'Diamonds'), ('J', 'Diamonds')]
# 678 : High card - [('2', 'Diamonds'), ('J', 'Clubs')]
# 679 : High card - [('2', 'Diamonds'), ('K', 'Spades')]
# 680 : High card - [('2', 'Diamonds'), ('K', 'Hearts')]
# 681 : High card - [('2', 'Diamonds'), ('K', 'Diamonds')]
# 682 : High card - [('2', 'Diamonds'), ('K', 'Clubs')]
# 683 : High card - [('2', 'Diamonds'), ('A', 'Spades')]
# 684 : High card - [('2', 'Diamonds'), ('A', 'Hearts')]
# 685 : High card - [('2', 'Diamonds'), ('A', 'Diamonds')]
# 686 : High card - [('2', 'Diamonds'), ('A', 'Clubs')]
# 687 : High card - [('3', 'Spades'), ('8', 'Spades')]
# 688 : High card - [('3', 'Spades'), ('8', 'Hearts')]
# 689 : High card - [('3', 'Spades'), ('8', 'Diamonds')]
# 690 : High card - [('3', 'Spades'), ('8', 'Clubs')]
# 691 : High card - [('3', 'Spades'), ('T', 'Spades')]
# 692 : High card - [('3', 'Spades'), ('T', 'Hearts')]
# 693 : High card - [('3', 'Spades'), ('T', 'Diamonds')]
# 694 : High card - [('3', 'Spades'), ('T', 'Clubs')]
# 695 : High card - [('3', 'Spades'), ('J', 'Spades')]
# 696 : High card - [('3', 'Spades'), ('J', 'Hearts')]
# 697 : High card - [('3', 'Spades'), ('J', 'Diamonds')]
# 698 : High card - [('3', 'Spades'), ('J', 'Clubs')]
# 699 : High card - [('3', 'Spades'), ('K', 'Spades')]
# 700 : High card - [('3', 'Spades'), ('K', 'Hearts')]
# 701 : High card - [('3', 'Spades'), ('K', 'Diamonds')]
# 702 : High card - [('3', 'Spades'), ('K', 'Clubs')]
# 703 : High card - [('3', 'Spades'), ('A', 'Spades')]
# 704 : High card - [('3', 'Spades'), ('A', 'Hearts')]
# 705 : High card - [('3', 'Spades'), ('A', 'Diamonds')]
# 706 : High card - [('3', 'Spades'), ('A', 'Clubs')]
# 707 : High card - [('3', 'Hearts'), ('8', 'Spades')]
# 708 : High card - [('3', 'Hearts'), ('8', 'Hearts')]
# 709 : High card - [('3', 'Hearts'), ('8', 'Diamonds')]
# 710 : High card - [('3', 'Hearts'), ('8', 'Clubs')]
# 711 : High card - [('3', 'Hearts'), ('T', 'Spades')]
# 712 : High card - [('3', 'Hearts'), ('T', 'Hearts')]
# 713 : High card - [('3', 'Hearts'), ('T', 'Diamonds')]
# 714 : High card - [('3', 'Hearts'), ('T', 'Clubs')]
# 715 : High card - [('3', 'Hearts'), ('J', 'Spades')]
# 716 : High card - [('3', 'Hearts'), ('J', 'Hearts')]
# 717 : High card - [('3', 'Hearts'), ('J', 'Diamonds')]
# 718 : High card - [('3', 'Hearts'), ('J', 'Clubs')]
# 719 : High card - [('3', 'Hearts'), ('K', 'Spades')]
# 720 : High card - [('3', 'Hearts'), ('K', 'Hearts')]
# 721 : High card - [('3', 'Hearts'), ('K', 'Diamonds')]
# 722 : High card - [('3', 'Hearts'), ('K', 'Clubs')]
# 723 : High card - [('3', 'Hearts'), ('A', 'Spades')]
# 724 : High card - [('3', 'Hearts'), ('A', 'Hearts')]
# 725 : High card - [('3', 'Hearts'), ('A', 'Diamonds')]
# 726 : High card - [('3', 'Hearts'), ('A', 'Clubs')]
# 727 : High card - [('3', 'Diamonds'), ('8', 'Spades')]
# 728 : High card - [('3', 'Diamonds'), ('8', 'Hearts')]
# 729 : High card - [('3', 'Diamonds'), ('8', 'Diamonds')]
# 730 : High card - [('3', 'Diamonds'), ('8', 'Clubs')]
# 731 : High card - [('3', 'Diamonds'), ('T', 'Spades')]
# 732 : High card - [('3', 'Diamonds'), ('T', 'Hearts')]
# 733 : High card - [('3', 'Diamonds'), ('T', 'Diamonds')]
# 734 : High card - [('3', 'Diamonds'), ('T', 'Clubs')]
# 735 : High card - [('3', 'Diamonds'), ('J', 'Spades')]
# 736 : High card - [('3', 'Diamonds'), ('J', 'Hearts')]
# 737 : High card - [('3', 'Diamonds'), ('J', 'Diamonds')]
# 738 : High card - [('3', 'Diamonds'), ('J', 'Clubs')]
# 739 : High card - [('3', 'Diamonds'), ('K', 'Spades')]
# 740 : High card - [('3', 'Diamonds'), ('K', 'Hearts')]
# 741 : High card - [('3', 'Diamonds'), ('K', 'Diamonds')]
# 742 : High card - [('3', 'Diamonds'), ('K', 'Clubs')]
# 743 : High card - [('3', 'Diamonds'), ('A', 'Spades')]
# 744 : High card - [('3', 'Diamonds'), ('A', 'Hearts')]
# 745 : High card - [('3', 'Diamonds'), ('A', 'Diamonds')]
# 746 : High card - [('3', 'Diamonds'), ('A', 'Clubs')]
# 747 : High card - [('3', 'Clubs'), ('8', 'Spades')]
# 748 : High card - [('3', 'Clubs'), ('8', 'Hearts')]
# 749 : High card - [('3', 'Clubs'), ('8', 'Diamonds')]
# 750 : High card - [('3', 'Clubs'), ('8', 'Clubs')]
# 751 : High card - [('3', 'Clubs'), ('T', 'Spades')]
# 752 : High card - [('3', 'Clubs'), ('T', 'Hearts')]
# 753 : High card - [('3', 'Clubs'), ('T', 'Diamonds')]
# 754 : High card - [('3', 'Clubs'), ('T', 'Clubs')]
# 755 : High card - [('3', 'Clubs'), ('J', 'Spades')]
# 756 : High card - [('3', 'Clubs'), ('J', 'Hearts')]
# 757 : High card - [('3', 'Clubs'), ('J', 'Diamonds')]
# 758 : High card - [('3', 'Clubs'), ('J', 'Clubs')]
# 759 : High card - [('3', 'Clubs'), ('K', 'Spades')]
# 760 : High card - [('3', 'Clubs'), ('K', 'Hearts')]
# 761 : High card - [('3', 'Clubs'), ('K', 'Diamonds')]
# 762 : High card - [('3', 'Clubs'), ('K', 'Clubs')]
# 763 : High card - [('3', 'Clubs'), ('A', 'Spades')]
# 764 : High card - [('3', 'Clubs'), ('A', 'Hearts')]
# 765 : High card - [('3', 'Clubs'), ('A', 'Diamonds')]
# 766 : High card - [('3', 'Clubs'), ('A', 'Clubs')]
# 767 : High card - [('7', 'Spades'), ('T', 'Spades')]
# 768 : High card - [('7', 'Spades'), ('T', 'Hearts')]
# 769 : High card - [('7', 'Spades'), ('T', 'Diamonds')]
# 770 : High card - [('7', 'Spades'), ('T', 'Clubs')]
# 771 : High card - [('7', 'Spades'), ('J', 'Spades')]
# 772 : High card - [('7', 'Spades'), ('J', 'Hearts')]
# 773 : High card - [('7', 'Spades'), ('J', 'Diamonds')]
# 774 : High card - [('7', 'Spades'), ('J', 'Clubs')]
# 775 : High card - [('7', 'Spades'), ('K', 'Spades')]
# 776 : High card - [('7', 'Spades'), ('K', 'Hearts')]
# 777 : High card - [('7', 'Spades'), ('K', 'Diamonds')]
# 778 : High card - [('7', 'Spades'), ('K', 'Clubs')]
# 779 : High card - [('7', 'Spades'), ('A', 'Spades')]
# 780 : High card - [('7', 'Spades'), ('A', 'Hearts')]
# 781 : High card - [('7', 'Spades'), ('A', 'Diamonds')]
# 782 : High card - [('7', 'Spades'), ('A', 'Clubs')]
# 783 : High card - [('7', 'Hearts'), ('T', 'Spades')]
# 784 : High card - [('7', 'Hearts'), ('T', 'Hearts')]
# 785 : High card - [('7', 'Hearts'), ('T', 'Diamonds')]
# 786 : High card - [('7', 'Hearts'), ('T', 'Clubs')]
# 787 : High card - [('7', 'Hearts'), ('J', 'Spades')]
# 788 : High card - [('7', 'Hearts'), ('J', 'Hearts')]
# 789 : High card - [('7', 'Hearts'), ('J', 'Diamonds')]
# 790 : High card - [('7', 'Hearts'), ('J', 'Clubs')]
# 791 : High card - [('7', 'Hearts'), ('K', 'Spades')]
# 792 : High card - [('7', 'Hearts'), ('K', 'Hearts')]
# 793 : High card - [('7', 'Hearts'), ('K', 'Diamonds')]
# 794 : High card - [('7', 'Hearts'), ('K', 'Clubs')]
# 795 : High card - [('7', 'Hearts'), ('A', 'Spades')]
# 796 : High card - [('7', 'Hearts'), ('A', 'Hearts')]
# 797 : High card - [('7', 'Hearts'), ('A', 'Diamonds')]
# 798 : High card - [('7', 'Hearts'), ('A', 'Clubs')]
# 799 : High card - [('7', 'Diamonds'), ('T', 'Spades')]
# 800 : High card - [('7', 'Diamonds'), ('T', 'Hearts')]
# 801 : High card - [('7', 'Diamonds'), ('T', 'Diamonds')]
# 802 : High card - [('7', 'Diamonds'), ('T', 'Clubs')]
# 803 : High card - [('7', 'Diamonds'), ('J', 'Spades')]
# 804 : High card - [('7', 'Diamonds'), ('J', 'Hearts')]
# 805 : High card - [('7', 'Diamonds'), ('J', 'Diamonds')]
# 806 : High card - [('7', 'Diamonds'), ('J', 'Clubs')]
# 807 : High card - [('7', 'Diamonds'), ('K', 'Spades')]
# 808 : High card - [('7', 'Diamonds'), ('K', 'Hearts')]
# 809 : High card - [('7', 'Diamonds'), ('K', 'Diamonds')]
# 810 : High card - [('7', 'Diamonds'), ('K', 'Clubs')]
# 811 : High card - [('7', 'Diamonds'), ('A', 'Spades')]
# 812 : High card - [('7', 'Diamonds'), ('A', 'Hearts')]
# 813 : High card - [('7', 'Diamonds'), ('A', 'Diamonds')]
# 814 : High card - [('7', 'Diamonds'), ('A', 'Clubs')]
# 815 : High card - [('7', 'Clubs'), ('T', 'Spades')]
# 816 : High card - [('7', 'Clubs'), ('T', 'Hearts')]
# 817 : High card - [('7', 'Clubs'), ('T', 'Diamonds')]
# 818 : High card - [('7', 'Clubs'), ('T', 'Clubs')]
# 819 : High card - [('7', 'Clubs'), ('J', 'Spades')]
# 820 : High card - [('7', 'Clubs'), ('J', 'Hearts')]
# 821 : High card - [('7', 'Clubs'), ('J', 'Diamonds')]
# 822 : High card - [('7', 'Clubs'), ('J', 'Clubs')]
# 823 : High card - [('7', 'Clubs'), ('K', 'Spades')]
# 824 : High card - [('7', 'Clubs'), ('K', 'Hearts')]
# 825 : High card - [('7', 'Clubs'), ('K', 'Diamonds')]
# 826 : High card - [('7', 'Clubs'), ('K', 'Clubs')]
# 827 : High card - [('7', 'Clubs'), ('A', 'Spades')]
# 828 : High card - [('7', 'Clubs'), ('A', 'Hearts')]
# 829 : High card - [('7', 'Clubs'), ('A', 'Diamonds')]
# 830 : High card - [('7', 'Clubs'), ('A', 'Clubs')]
# 831 : High card - [('8', 'Spades'), ('T', 'Spades')]
# 832 : High card - [('8', 'Spades'), ('T', 'Hearts')]
# 833 : High card - [('8', 'Spades'), ('T', 'Diamonds')]
# 834 : High card - [('8', 'Spades'), ('T', 'Clubs')]
# 835 : High card - [('8', 'Spades'), ('J', 'Spades')]
# 836 : High card - [('8', 'Spades'), ('J', 'Hearts')]
# 837 : High card - [('8', 'Spades'), ('J', 'Diamonds')]
# 838 : High card - [('8', 'Spades'), ('J', 'Clubs')]
# 839 : High card - [('8', 'Spades'), ('K', 'Spades')]
# 840 : High card - [('8', 'Spades'), ('K', 'Hearts')]
# 841 : High card - [('8', 'Spades'), ('K', 'Diamonds')]
# 842 : High card - [('8', 'Spades'), ('K', 'Clubs')]
# 843 : High card - [('8', 'Spades'), ('A', 'Spades')]
# 844 : High card - [('8', 'Spades'), ('A', 'Hearts')]
# 845 : High card - [('8', 'Spades'), ('A', 'Diamonds')]
# 846 : High card - [('8', 'Spades'), ('A', 'Clubs')]
# 847 : High card - [('8', 'Hearts'), ('T', 'Spades')]
# 848 : High card - [('8', 'Hearts'), ('T', 'Hearts')]
# 849 : High card - [('8', 'Hearts'), ('T', 'Diamonds')]
# 850 : High card - [('8', 'Hearts'), ('T', 'Clubs')]
# 851 : High card - [('8', 'Hearts'), ('J', 'Spades')]
# 852 : High card - [('8', 'Hearts'), ('J', 'Hearts')]
# 853 : High card - [('8', 'Hearts'), ('J', 'Diamonds')]
# 854 : High card - [('8', 'Hearts'), ('J', 'Clubs')]
# 855 : High card - [('8', 'Hearts'), ('K', 'Spades')]
# 856 : High card - [('8', 'Hearts'), ('K', 'Hearts')]
# 857 : High card - [('8', 'Hearts'), ('K', 'Diamonds')]
# 858 : High card - [('8', 'Hearts'), ('K', 'Clubs')]
# 859 : High card - [('8', 'Hearts'), ('A', 'Spades')]
# 860 : High card - [('8', 'Hearts'), ('A', 'Hearts')]
# 861 : High card - [('8', 'Hearts'), ('A', 'Diamonds')]
# 862 : High card - [('8', 'Hearts'), ('A', 'Clubs')]
# 863 : High card - [('8', 'Diamonds'), ('T', 'Spades')]
# 864 : High card - [('8', 'Diamonds'), ('T', 'Hearts')]
# 865 : High card - [('8', 'Diamonds'), ('T', 'Diamonds')]
# 866 : High card - [('8', 'Diamonds'), ('T', 'Clubs')]
# 867 : High card - [('8', 'Diamonds'), ('J', 'Spades')]
# 868 : High card - [('8', 'Diamonds'), ('J', 'Hearts')]
# 869 : High card - [('8', 'Diamonds'), ('J', 'Diamonds')]
# 870 : High card - [('8', 'Diamonds'), ('J', 'Clubs')]
# 871 : High card - [('8', 'Diamonds'), ('K', 'Spades')]
# 872 : High card - [('8', 'Diamonds'), ('K', 'Hearts')]
# 873 : High card - [('8', 'Diamonds'), ('K', 'Diamonds')]
# 874 : High card - [('8', 'Diamonds'), ('K', 'Clubs')]
# 875 : High card - [('8', 'Diamonds'), ('A', 'Spades')]
# 876 : High card - [('8', 'Diamonds'), ('A', 'Hearts')]
# 877 : High card - [('8', 'Diamonds'), ('A', 'Diamonds')]
# 878 : High card - [('8', 'Diamonds'), ('A', 'Clubs')]
# 879 : High card - [('8', 'Clubs'), ('T', 'Spades')]
# 880 : High card - [('8', 'Clubs'), ('T', 'Hearts')]
# 881 : High card - [('8', 'Clubs'), ('T', 'Diamonds')]
# 882 : High card - [('8', 'Clubs'), ('T', 'Clubs')]
# 883 : High card - [('8', 'Clubs'), ('J', 'Spades')]
# 884 : High card - [('8', 'Clubs'), ('J', 'Hearts')]
# 885 : High card - [('8', 'Clubs'), ('J', 'Diamonds')]
# 886 : High card - [('8', 'Clubs'), ('J', 'Clubs')]
# 887 : High card - [('8', 'Clubs'), ('K', 'Spades')]
# 888 : High card - [('8', 'Clubs'), ('K', 'Hearts')]
# 889 : High card - [('8', 'Clubs'), ('K', 'Diamonds')]
# 890 : High card - [('8', 'Clubs'), ('K', 'Clubs')]
# 891 : High card - [('8', 'Clubs'), ('A', 'Spades')]
# 892 : High card - [('8', 'Clubs'), ('A', 'Hearts')]
# 893 : High card - [('8', 'Clubs'), ('A', 'Diamonds')]
# 894 : High card - [('8', 'Clubs'), ('A', 'Clubs')]
# 895 : High card - [('T', 'Spades'), ('J', 'Spades')]
# 896 : High card - [('T', 'Spades'), ('J', 'Hearts')]
# 897 : High card - [('T', 'Spades'), ('J', 'Diamonds')]
# 898 : High card - [('T', 'Spades'), ('J', 'Clubs')]
# 899 : High card - [('T', 'Spades'), ('K', 'Spades')]
# 900 : High card - [('T', 'Spades'), ('K', 'Hearts')]
# 901 : High card - [('T', 'Spades'), ('K', 'Diamonds')]
# 902 : High card - [('T', 'Spades'), ('K', 'Clubs')]
# 903 : High card - [('T', 'Spades'), ('A', 'Spades')]
# 904 : High card - [('T', 'Spades'), ('A', 'Hearts')]
# 905 : High card - [('T', 'Spades'), ('A', 'Diamonds')]
# 906 : High card - [('T', 'Spades'), ('A', 'Clubs')]
# 907 : High card - [('T', 'Hearts'), ('J', 'Spades')]
# 908 : High card - [('T', 'Hearts'), ('J', 'Hearts')]
# 909 : High card - [('T', 'Hearts'), ('J', 'Diamonds')]
# 910 : High card - [('T', 'Hearts'), ('J', 'Clubs')]
# 911 : High card - [('T', 'Hearts'), ('K', 'Spades')]
# 912 : High card - [('T', 'Hearts'), ('K', 'Hearts')]
# 913 : High card - [('T', 'Hearts'), ('K', 'Diamonds')]
# 914 : High card - [('T', 'Hearts'), ('K', 'Clubs')]
# 915 : High card - [('T', 'Hearts'), ('A', 'Spades')]
# 916 : High card - [('T', 'Hearts'), ('A', 'Hearts')]
# 917 : High card - [('T', 'Hearts'), ('A', 'Diamonds')]
# 918 : High card - [('T', 'Hearts'), ('A', 'Clubs')]
# 919 : High card - [('T', 'Diamonds'), ('J', 'Spades')]
# 920 : High card - [('T', 'Diamonds'), ('J', 'Hearts')]
# 921 : High card - [('T', 'Diamonds'), ('J', 'Diamonds')]
# 922 : High card - [('T', 'Diamonds'), ('J', 'Clubs')]
# 923 : High card - [('T', 'Diamonds'), ('K', 'Spades')]
# 924 : High card - [('T', 'Diamonds'), ('K', 'Hearts')]
# 925 : High card - [('T', 'Diamonds'), ('K', 'Diamonds')]
# 926 : High card - [('T', 'Diamonds'), ('K', 'Clubs')]
# 927 : High card - [('T', 'Diamonds'), ('A', 'Spades')]
# 928 : High card - [('T', 'Diamonds'), ('A', 'Hearts')]
# 929 : High card - [('T', 'Diamonds'), ('A', 'Diamonds')]
# 930 : High card - [('T', 'Diamonds'), ('A', 'Clubs')]
# 931 : High card - [('T', 'Clubs'), ('J', 'Spades')]
# 932 : High card - [('T', 'Clubs'), ('J', 'Hearts')]
# 933 : High card - [('T', 'Clubs'), ('J', 'Diamonds')]
# 934 : High card - [('T', 'Clubs'), ('J', 'Clubs')]
# 935 : High card - [('T', 'Clubs'), ('K', 'Spades')]
# 936 : High card - [('T', 'Clubs'), ('K', 'Hearts')]
# 937 : High card - [('T', 'Clubs'), ('K', 'Diamonds')]
# 938 : High card - [('T', 'Clubs'), ('K', 'Clubs')]
# 939 : High card - [('T', 'Clubs'), ('A', 'Spades')]
# 940 : High card - [('T', 'Clubs'), ('A', 'Hearts')]
# 941 : High card - [('T', 'Clubs'), ('A', 'Diamonds')]
# 942 : High card - [('T', 'Clubs'), ('A', 'Clubs')]
# 943 : High card - [('J', 'Spades'), ('K', 'Spades')]
# 944 : High card - [('J', 'Spades'), ('K', 'Hearts')]
# 945 : High card - [('J', 'Spades'), ('K', 'Diamonds')]
# 946 : High card - [('J', 'Spades'), ('K', 'Clubs')]
# 947 : High card - [('J', 'Spades'), ('A', 'Spades')]
# 948 : High card - [('J', 'Spades'), ('A', 'Hearts')]
# 949 : High card - [('J', 'Spades'), ('A', 'Diamonds')]
# 950 : High card - [('J', 'Spades'), ('A', 'Clubs')]
# 951 : High card - [('J', 'Hearts'), ('K', 'Spades')]
# 952 : High card - [('J', 'Hearts'), ('K', 'Hearts')]
# 953 : High card - [('J', 'Hearts'), ('K', 'Diamonds')]
# 954 : High card - [('J', 'Hearts'), ('K', 'Clubs')]
# 955 : High card - [('J', 'Hearts'), ('A', 'Spades')]
# 956 : High card - [('J', 'Hearts'), ('A', 'Hearts')]
# 957 : High card - [('J', 'Hearts'), ('A', 'Diamonds')]
# 958 : High card - [('J', 'Hearts'), ('A', 'Clubs')]
# 959 : High card - [('J', 'Diamonds'), ('K', 'Spades')]
# 960 : High card - [('J', 'Diamonds'), ('K', 'Hearts')]
# 961 : High card - [('J', 'Diamonds'), ('K', 'Diamonds')]
# 962 : High card - [('J', 'Diamonds'), ('K', 'Clubs')]
# 963 : High card - [('J', 'Diamonds'), ('A', 'Spades')]
# 964 : High card - [('J', 'Diamonds'), ('A', 'Hearts')]
# 965 : High card - [('J', 'Diamonds'), ('A', 'Diamonds')]
# 966 : High card - [('J', 'Diamonds'), ('A', 'Clubs')]
# 967 : High card - [('J', 'Clubs'), ('K', 'Spades')]
# 968 : High card - [('J', 'Clubs'), ('K', 'Hearts')]
# 969 : High card - [('J', 'Clubs'), ('K', 'Diamonds')]
# 970 : High card - [('J', 'Clubs'), ('K', 'Clubs')]
# 971 : High card - [('J', 'Clubs'), ('A', 'Spades')]
# 972 : High card - [('J', 'Clubs'), ('A', 'Hearts')]
# 973 : High card - [('J', 'Clubs'), ('A', 'Diamonds')]
# 974 : High card - [('J', 'Clubs'), ('A', 'Clubs')]
# 975 : High card - [('K', 'Spades'), ('A', 'Spades')]
# 976 : High card - [('K', 'Spades'), ('A', 'Hearts')]
# 977 : High card - [('K', 'Spades'), ('A', 'Diamonds')]
# 978 : High card - [('K', 'Spades'), ('A', 'Clubs')]
# 979 : High card - [('K', 'Hearts'), ('A', 'Spades')]
# 980 : High card - [('K', 'Hearts'), ('A', 'Hearts')]
# 981 : High card - [('K', 'Hearts'), ('A', 'Diamonds')]
# 982 : High card - [('K', 'Hearts'), ('A', 'Clubs')]
# 983 : High card - [('K', 'Diamonds'), ('A', 'Spades')]
# 984 : High card - [('K', 'Diamonds'), ('A', 'Hearts')]
# 985 : High card - [('K', 'Diamonds'), ('A', 'Diamonds')]
# 986 : High card - [('K', 'Diamonds'), ('A', 'Clubs')]
# 987 : High card - [('K', 'Clubs'), ('A', 'Spades')]
# 988 : High card - [('K', 'Clubs'), ('A', 'Hearts')]
# 989 : High card - [('K', 'Clubs'), ('A', 'Diamonds')]
# 990 : High card - [('K', 'Clubs'), ('A', 'Clubs')]

# %%
def basic_betting_algorithm(hand_type):
    if hand_type == "Royal flush":
        return "All in"  
    elif hand_type in ["Straight flush", "Four of a kind", "Full house"]:
        return "Raise"  
    elif hand_type in ["Flush", "Straight", "Three of a kind"]:
        return "Call"  
    elif hand_type in ["Two pair", "Pair"]:
        return "Check"  
    else:
        return "Fold"  

# Example usage:
hand_type = result[0]
bet_decision = basic_betting_algorithm(hand_type)
print("Betting Decision:", bet_decision)
# Out:
# Betting Decision: Check

# %%
import random

def advanced_betting_algorithm(hand_type, bankroll, bluff_chance=0.2):

    bet_amounts = {
        "Royal flush": 100,
        "Straight flush": 80,
        "Four of a kind": 60,
        "Full house": 50,
        "Flush": 40,
        "Straight": 30,
        "Three of a kind": 25,
        "Two pair": 20,
        "Pair": 15,
        "High card": 10
    }

    if hand_type == "Royal flush":
        return "All in", bet_amounts["Royal flush"]  
    elif hand_type in ["Straight flush", "Four of a kind", "Full house"]:
        if random.random() < bluff_chance:
            return "Bluff", bet_amounts["Full house"] 
        else:
            return "Raise", min(bet_amounts[hand_type], bankroll) 
    elif hand_type in ["Flush", "Straight", "Three of a kind"]:
        return "Call", min(bet_amounts[hand_type], bankroll)  
    elif hand_type in ["Two pair", "Pair"]:
        if random.random() < bluff_chance:
            return "Bluff", bet_amounts["Pair"] 
        else:
            return "Check", 0
    else:
        if random.random() < bluff_chance:
            return "Bluff", 50  
        else:
            return "Fold", 0 


hand_type = result[0]
bankroll = 100 
bet_decision, bet_amount = advanced_betting_algorithm(hand_type, bankroll)
print("Betting Decision:", bet_decision)
print("Bet Amount:", bet_amount)
# Out:
# Betting Decision: Check
# Bet Amount: 0

# %%
def calculate_raise_amount(hand_type, predicted_hand_types):
    raise_ranges = {
        "Royal flush": (10, 20),
        "Straight flush": (8, 15),  
        "Four of a kind": (6, 12),  
        "Full house": (5, 10),  
        "Flush": (4, 8),  
        "Straight": (3, 6),  
        "Three of a kind": (2, 5),  
        "Two pair": (1, 4),  
        "Pair": (1, 3),  
        "High card": (1, 2)
    }
    
    min_raise, max_raise = raise_ranges.get(hand_type, (1, 2))
    
    for predicted_type, _ in predicted_hand_types:
        if predicted_type == "Royal flush":
            min_raise = 1
    
    return min_raise, max_raise

def basic_betting_algorithm(hand_type, predicted_hand_types):
    bet_decision = ""
    if hand_type == "Royal flush":
        bet_decision = "All in"
    elif hand_type in ["Straight flush", "Four of a kind", "Full house"]:
        min_raise, max_raise = calculate_raise_amount(hand_type, predicted_hand_types)
        bet_decision = f"Raise {min_raise}-{max_raise}"
    elif hand_type in ["Flush", "Straight", "Three of a kind"]:
        bet_decision = "Call"
    elif hand_type in ["Two pair", "Pair"]:
        bet_decision = "Check"
    else:
        bet_decision = "Fold"
    return bet_decision

hand_type = result[0]
predicted_hand_types = [("Straight flush", 0.7), ("Pair", 0.3)]
bet_decision = basic_betting_algorithm(hand_type, predicted_hand_types)
print("Betting Decision:", bet_decision)
# Out:
# Betting Decision: Check
