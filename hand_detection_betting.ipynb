# %%
import random

def find_high_card(cards):
    sorted_cards = sorted(cards, key=lambda x: '23456789TJQKA'.index(x[0]))
    return sorted_cards[-1]

def generate_random_cards(num_cards):
    ranks = '23456789TJQKA'
    suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
    deck = [(rank, suit) for rank in ranks for suit in suits]
    return random.sample(deck, num_cards)

def print_combination(hand_type, winning_cards, winning_combination, high_card):
    if hand_type == "Pair":
        print("Combination: Pair of", winning_cards[0][0] + "s")
    elif hand_type == "Two pair":
        pair1_rank = winning_cards[0][0]
        pair2_rank = winning_cards[2][0]
        print("Combination: Two Pair - Pair of", pair1_rank + "s and Pair of", pair2_rank + "s")
    elif hand_type == "Three of a kind":
        print("Combination: Three of a Kind of", winning_cards[0][0] + "s")
    elif hand_type == "Straight":
        print("Combination: Straight")
    elif hand_type == "Flush":
        print("Combination: Flush")
    elif hand_type == "Full house":
        print("Combination: Full House")
    elif hand_type == "Four of a kind":
        print("Combination: Four of a Kind")
    elif hand_type == "Straight flush":
        print("Combination: Straight Flush")
    elif hand_type == "Royal flush":
        print("Combination: Royal Flush")
    else:
        print("Combination:", winning_combination)

def predict_poker_hand(hand, table_cards):
    all_cards = hand + table_cards
    sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

    suits = [card[1] for card in all_cards]
    ranks = [card[0] for card in all_cards]

    for suit in set(suits):
        if suits.count(suit) >= 5:
            flush_cards = [card for card in all_cards if card[1] == suit]
            flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
            if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
                if flush_sorted[-1][0] == 'A':
                    return "Royal flush", None, "Royal Flush"
                else:
                    return "Straight flush", None, "Straight Flush"

    # Check for Straight
    unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
    straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
    for i in range(len(unique_ranks) - 4):
        if ''.join(unique_ranks[i:i+5]) in straight_ranks:
            return "Straight", None, "Straight"

    counts = [ranks.count(rank) for rank in set(ranks)]

    if 4 in counts:  # Four of a kind
        return "Four of a kind", None, "Four of a Kind"

    if 3 in counts and 2 in counts:  # Full house
        return "Full house", None, "Full House"

    if 3 in counts:  # Three of a kind
        three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
        three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
        return "Three of a kind", three_kind_cards, "Three of a Kind", find_high_card(three_kind_cards)

    if counts.count(2) == 2:  # Two pair
        two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
        two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
        return "Two pair", two_pair_cards, "Two Pair", find_high_card(two_pair_cards)

    if counts.count(2) == 1:  # Pair
        pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
        pair_cards = [card for card in all_cards if card[0] in pair_rank]
        return "Pair", pair_cards, "Pair", find_high_card(pair_cards)

    high_card = find_high_card(all_cards)
    return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

hand = [('2', 'Clubs'), ('2', 'Hearts')]
table_cards = [('Q', 'Clubs'), ('Q', 'Diamonds'), ('5', 'Diamonds'), ('Q', 'Spades'), ('6', 'Clubs')]

result = predict_poker_hand(hand, table_cards)
hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

print_combination(hand_type, winning_cards, winning_combination, high_card)
# Out:
# Combination: Full House

# %%
import random
import itertools

def generate_remaining_cards(initial_hand, table_cards):
    ranks = '23456789TJQKA'
    suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
    deck = [(rank, suit) for rank in ranks for suit in suits]
    
    remaining_cards = [card for card in deck if card not in initial_hand and card not in table_cards]
    
    return remaining_cards

def generate_hand_combinations(initial_hand, remaining_cards):
    return itertools.combinations(remaining_cards, 2)

def evaluate_hand_combinations(hand_combinations, table_cards):
    evaluated_hands = []
    for hand_combination in hand_combinations:
        hand = list(hand_combination)
        result = predict_poker_hand(hand, table_cards)
        hand_type = result[0]
        evaluated_hands.append((hand, hand_type))
    
    # Sort hands based on their ranks
    evaluated_hands.sort(key=lambda x: hand_ranking.index(x[1]))
    
    return evaluated_hands

hand_ranking = [
    "Royal flush",
    "Straight flush",
    "Four of a kind",
    "Full house",
    "Flush",
    "Straight",
    "Three of a kind",
    "Two pair",
    "Pair",
    "High card"
]

# Function to print the combination
def print_combination(hand_type, winning_cards, winning_combination, high_card):
    if hand_type == "Pair":
        print("Combination: Pair of", winning_cards[0][0] + "s")
    elif hand_type == "Two pair":
        pair1_rank = winning_cards[0][0]
        pair2_rank = winning_cards[2][0]
        print("Combination: Two Pair - Pair of", pair1_rank + "s and Pair of", pair2_rank + "s")
    # Add more elif blocks for other combinations
    else:
        print("Combination:", winning_combination)

def predict_poker_hand(hand, table_cards):
    all_cards = hand + table_cards
    sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

    suits = [card[1] for card in all_cards]
    ranks = [card[0] for card in all_cards]

    for suit in set(suits):
        if suits.count(suit) >= 5:
            flush_cards = [card for card in all_cards if card[1] == suit]
            flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
            if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
                if flush_sorted[-1][0] == 'A':
                    return "Royal flush", None, "Royal Flush"
                else:
                    return "Straight flush", None, "Straight Flush"

    # Check for Straight
    unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
    straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
    for i in range(len(unique_ranks) - 4):
        if ''.join(unique_ranks[i:i+5]) in straight_ranks:
            return "Straight", None, "Straight"

    # Rest
    counts = [ranks.count(rank) for rank in set(ranks)]

    if 4 in counts: 
        return "Four of a kind", None, "Four of a Kind"

    if 3 in counts and 2 in counts:
        return "Full house", None, "Full House"

    if 3 in counts:  
        three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
        three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
        return "Three of a kind", three_kind_cards, "Three of a Kind"

    if counts.count(2) == 2: 
        two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
        two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
        return "Two pair", two_pair_cards, "Two Pair"

    if counts.count(2) == 1:  
        pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
        pair_cards = [card for card in all_cards if card[0] in pair_rank]
        return "Pair", pair_cards, "Pair"

    high_card = find_high_card(all_cards)
    return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

# Previous hand and table cards
hand = [('2', 'Clubs'), ('2', 'Hearts')]
table_cards = [('Q', 'Clubs'), ('Q', 'Diamonds'), ('5', 'Diamonds'), ('Q', 'Spades'), ('6', 'Clubs')]

result = predict_poker_hand(hand, table_cards)
hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

print_combination(hand_type, winning_cards, winning_combination, high_card)

# Generate remaining cards and hand combinations
remaining_cards = generate_remaining_cards(hand, table_cards)
hand_combinations = generate_hand_combinations(hand, remaining_cards)
evaluated_hands = evaluate_hand_combinations(hand_combinations, table_cards)

print("Ranking of other hand combinations:")
for i, (hand, hand_type) in enumerate(evaluated_hands, 1):
    print(i, ":", hand_type, "-", hand)
# Out:
# Combination: Full House
# Ranking of other hand combinations:
# 1 : Four of a kind - [('2', 'Spades'), ('Q', 'Hearts')]
# 2 : Four of a kind - [('2', 'Diamonds'), ('Q', 'Hearts')]
# 3 : Four of a kind - [('3', 'Spades'), ('Q', 'Hearts')]
# 4 : Four of a kind - [('3', 'Hearts'), ('Q', 'Hearts')]
# 5 : Four of a kind - [('3', 'Diamonds'), ('Q', 'Hearts')]
# 6 : Four of a kind - [('3', 'Clubs'), ('Q', 'Hearts')]
# 7 : Four of a kind - [('4', 'Spades'), ('Q', 'Hearts')]
# 8 : Four of a kind - [('4', 'Hearts'), ('Q', 'Hearts')]
# 9 : Four of a kind - [('4', 'Diamonds'), ('Q', 'Hearts')]
# 10 : Four of a kind - [('4', 'Clubs'), ('Q', 'Hearts')]
# 11 : Four of a kind - [('5', 'Spades'), ('Q', 'Hearts')]
# 12 : Four of a kind - [('5', 'Hearts'), ('Q', 'Hearts')]
# 13 : Four of a kind - [('5', 'Clubs'), ('Q', 'Hearts')]
# 14 : Four of a kind - [('6', 'Spades'), ('Q', 'Hearts')]
# 15 : Four of a kind - [('6', 'Hearts'), ('Q', 'Hearts')]
# 16 : Four of a kind - [('6', 'Diamonds'), ('Q', 'Hearts')]
# 17 : Four of a kind - [('7', 'Spades'), ('Q', 'Hearts')]
# 18 : Four of a kind - [('7', 'Hearts'), ('Q', 'Hearts')]
# 19 : Four of a kind - [('7', 'Diamonds'), ('Q', 'Hearts')]
# 20 : Four of a kind - [('7', 'Clubs'), ('Q', 'Hearts')]
# 21 : Four of a kind - [('8', 'Spades'), ('Q', 'Hearts')]
# 22 : Four of a kind - [('8', 'Hearts'), ('Q', 'Hearts')]
# 23 : Four of a kind - [('8', 'Diamonds'), ('Q', 'Hearts')]
# 24 : Four of a kind - [('8', 'Clubs'), ('Q', 'Hearts')]
# 25 : Four of a kind - [('9', 'Spades'), ('Q', 'Hearts')]
# 26 : Four of a kind - [('9', 'Hearts'), ('Q', 'Hearts')]
# 27 : Four of a kind - [('9', 'Diamonds'), ('Q', 'Hearts')]
# 28 : Four of a kind - [('9', 'Clubs'), ('Q', 'Hearts')]
# 29 : Four of a kind - [('T', 'Spades'), ('Q', 'Hearts')]
# 30 : Four of a kind - [('T', 'Hearts'), ('Q', 'Hearts')]
# 31 : Four of a kind - [('T', 'Diamonds'), ('Q', 'Hearts')]
# 32 : Four of a kind - [('T', 'Clubs'), ('Q', 'Hearts')]
# 33 : Four of a kind - [('J', 'Spades'), ('Q', 'Hearts')]
# 34 : Four of a kind - [('J', 'Hearts'), ('Q', 'Hearts')]
# 35 : Four of a kind - [('J', 'Diamonds'), ('Q', 'Hearts')]
# 36 : Four of a kind - [('J', 'Clubs'), ('Q', 'Hearts')]
# 37 : Four of a kind - [('Q', 'Hearts'), ('K', 'Spades')]
# 38 : Four of a kind - [('Q', 'Hearts'), ('K', 'Hearts')]
# 39 : Four of a kind - [('Q', 'Hearts'), ('K', 'Diamonds')]
# 40 : Four of a kind - [('Q', 'Hearts'), ('K', 'Clubs')]
# 41 : Four of a kind - [('Q', 'Hearts'), ('A', 'Spades')]
# 42 : Four of a kind - [('Q', 'Hearts'), ('A', 'Hearts')]
# 43 : Four of a kind - [('Q', 'Hearts'), ('A', 'Diamonds')]
# 44 : Four of a kind - [('Q', 'Hearts'), ('A', 'Clubs')]
# 45 : Full house - [('2', 'Spades'), ('2', 'Diamonds')]
# 46 : Full house - [('2', 'Spades'), ('5', 'Spades')]
# 47 : Full house - [('2', 'Spades'), ('5', 'Hearts')]
# 48 : Full house - [('2', 'Spades'), ('5', 'Clubs')]
# 49 : Full house - [('2', 'Spades'), ('6', 'Spades')]
# 50 : Full house - [('2', 'Spades'), ('6', 'Hearts')]
# 51 : Full house - [('2', 'Spades'), ('6', 'Diamonds')]
# 52 : Full house - [('2', 'Diamonds'), ('5', 'Spades')]
# 53 : Full house - [('2', 'Diamonds'), ('5', 'Hearts')]
# 54 : Full house - [('2', 'Diamonds'), ('5', 'Clubs')]
# 55 : Full house - [('2', 'Diamonds'), ('6', 'Spades')]
# 56 : Full house - [('2', 'Diamonds'), ('6', 'Hearts')]
# 57 : Full house - [('2', 'Diamonds'), ('6', 'Diamonds')]
# 58 : Full house - [('3', 'Spades'), ('3', 'Hearts')]
# 59 : Full house - [('3', 'Spades'), ('3', 'Diamonds')]
# 60 : Full house - [('3', 'Spades'), ('3', 'Clubs')]
# 61 : Full house - [('3', 'Spades'), ('5', 'Spades')]
# 62 : Full house - [('3', 'Spades'), ('5', 'Hearts')]
# 63 : Full house - [('3', 'Spades'), ('5', 'Clubs')]
# 64 : Full house - [('3', 'Spades'), ('6', 'Spades')]
# 65 : Full house - [('3', 'Spades'), ('6', 'Hearts')]
# 66 : Full house - [('3', 'Spades'), ('6', 'Diamonds')]
# 67 : Full house - [('3', 'Hearts'), ('3', 'Diamonds')]
# 68 : Full house - [('3', 'Hearts'), ('3', 'Clubs')]
# 69 : Full house - [('3', 'Hearts'), ('5', 'Spades')]
# 70 : Full house - [('3', 'Hearts'), ('5', 'Hearts')]
# 71 : Full house - [('3', 'Hearts'), ('5', 'Clubs')]
# 72 : Full house - [('3', 'Hearts'), ('6', 'Spades')]
# 73 : Full house - [('3', 'Hearts'), ('6', 'Hearts')]
# 74 : Full house - [('3', 'Hearts'), ('6', 'Diamonds')]
# 75 : Full house - [('3', 'Diamonds'), ('3', 'Clubs')]
# 76 : Full house - [('3', 'Diamonds'), ('5', 'Spades')]
# 77 : Full house - [('3', 'Diamonds'), ('5', 'Hearts')]
# 78 : Full house - [('3', 'Diamonds'), ('5', 'Clubs')]
# 79 : Full house - [('3', 'Diamonds'), ('6', 'Spades')]
# 80 : Full house - [('3', 'Diamonds'), ('6', 'Hearts')]
# 81 : Full house - [('3', 'Diamonds'), ('6', 'Diamonds')]
# 82 : Full house - [('3', 'Clubs'), ('5', 'Spades')]
# 83 : Full house - [('3', 'Clubs'), ('5', 'Hearts')]
# 84 : Full house - [('3', 'Clubs'), ('5', 'Clubs')]
# 85 : Full house - [('3', 'Clubs'), ('6', 'Spades')]
# 86 : Full house - [('3', 'Clubs'), ('6', 'Hearts')]
# 87 : Full house - [('3', 'Clubs'), ('6', 'Diamonds')]
# 88 : Full house - [('4', 'Spades'), ('4', 'Hearts')]
# 89 : Full house - [('4', 'Spades'), ('4', 'Diamonds')]
# 90 : Full house - [('4', 'Spades'), ('4', 'Clubs')]
# 91 : Full house - [('4', 'Spades'), ('5', 'Spades')]
# 92 : Full house - [('4', 'Spades'), ('5', 'Hearts')]
# 93 : Full house - [('4', 'Spades'), ('5', 'Clubs')]
# 94 : Full house - [('4', 'Spades'), ('6', 'Spades')]
# 95 : Full house - [('4', 'Spades'), ('6', 'Hearts')]
# 96 : Full house - [('4', 'Spades'), ('6', 'Diamonds')]
# 97 : Full house - [('4', 'Hearts'), ('4', 'Diamonds')]
# 98 : Full house - [('4', 'Hearts'), ('4', 'Clubs')]
# 99 : Full house - [('4', 'Hearts'), ('5', 'Spades')]
# 100 : Full house - [('4', 'Hearts'), ('5', 'Hearts')]
# 101 : Full house - [('4', 'Hearts'), ('5', 'Clubs')]
# 102 : Full house - [('4', 'Hearts'), ('6', 'Spades')]
# 103 : Full house - [('4', 'Hearts'), ('6', 'Hearts')]
# 104 : Full house - [('4', 'Hearts'), ('6', 'Diamonds')]
# 105 : Full house - [('4', 'Diamonds'), ('4', 'Clubs')]
# 106 : Full house - [('4', 'Diamonds'), ('5', 'Spades')]
# 107 : Full house - [('4', 'Diamonds'), ('5', 'Hearts')]
# 108 : Full house - [('4', 'Diamonds'), ('5', 'Clubs')]
# 109 : Full house - [('4', 'Diamonds'), ('6', 'Spades')]
# 110 : Full house - [('4', 'Diamonds'), ('6', 'Hearts')]
# 111 : Full house - [('4', 'Diamonds'), ('6', 'Diamonds')]
# 112 : Full house - [('4', 'Clubs'), ('5', 'Spades')]
# 113 : Full house - [('4', 'Clubs'), ('5', 'Hearts')]
# 114 : Full house - [('4', 'Clubs'), ('5', 'Clubs')]
# 115 : Full house - [('4', 'Clubs'), ('6', 'Spades')]
# 116 : Full house - [('4', 'Clubs'), ('6', 'Hearts')]
# 117 : Full house - [('4', 'Clubs'), ('6', 'Diamonds')]
# 118 : Full house - [('5', 'Spades'), ('6', 'Spades')]
# 119 : Full house - [('5', 'Spades'), ('6', 'Hearts')]
# 120 : Full house - [('5', 'Spades'), ('6', 'Diamonds')]
# 121 : Full house - [('5', 'Spades'), ('7', 'Spades')]
# 122 : Full house - [('5', 'Spades'), ('7', 'Hearts')]
# 123 : Full house - [('5', 'Spades'), ('7', 'Diamonds')]
# 124 : Full house - [('5', 'Spades'), ('7', 'Clubs')]
# 125 : Full house - [('5', 'Spades'), ('8', 'Spades')]
# 126 : Full house - [('5', 'Spades'), ('8', 'Hearts')]
# 127 : Full house - [('5', 'Spades'), ('8', 'Diamonds')]
# 128 : Full house - [('5', 'Spades'), ('8', 'Clubs')]
# 129 : Full house - [('5', 'Spades'), ('9', 'Spades')]
# 130 : Full house - [('5', 'Spades'), ('9', 'Hearts')]
# 131 : Full house - [('5', 'Spades'), ('9', 'Diamonds')]
# 132 : Full house - [('5', 'Spades'), ('9', 'Clubs')]
# 133 : Full house - [('5', 'Spades'), ('T', 'Spades')]
# 134 : Full house - [('5', 'Spades'), ('T', 'Hearts')]
# 135 : Full house - [('5', 'Spades'), ('T', 'Diamonds')]
# 136 : Full house - [('5', 'Spades'), ('T', 'Clubs')]
# 137 : Full house - [('5', 'Spades'), ('J', 'Spades')]
# 138 : Full house - [('5', 'Spades'), ('J', 'Hearts')]
# 139 : Full house - [('5', 'Spades'), ('J', 'Diamonds')]
# 140 : Full house - [('5', 'Spades'), ('J', 'Clubs')]
# 141 : Full house - [('5', 'Spades'), ('K', 'Spades')]
# 142 : Full house - [('5', 'Spades'), ('K', 'Hearts')]
# 143 : Full house - [('5', 'Spades'), ('K', 'Diamonds')]
# 144 : Full house - [('5', 'Spades'), ('K', 'Clubs')]
# 145 : Full house - [('5', 'Spades'), ('A', 'Spades')]
# 146 : Full house - [('5', 'Spades'), ('A', 'Hearts')]
# 147 : Full house - [('5', 'Spades'), ('A', 'Diamonds')]
# 148 : Full house - [('5', 'Spades'), ('A', 'Clubs')]
# 149 : Full house - [('5', 'Hearts'), ('6', 'Spades')]
# 150 : Full house - [('5', 'Hearts'), ('6', 'Hearts')]
# 151 : Full house - [('5', 'Hearts'), ('6', 'Diamonds')]
# 152 : Full house - [('5', 'Hearts'), ('7', 'Spades')]
# 153 : Full house - [('5', 'Hearts'), ('7', 'Hearts')]
# 154 : Full house - [('5', 'Hearts'), ('7', 'Diamonds')]
# 155 : Full house - [('5', 'Hearts'), ('7', 'Clubs')]
# 156 : Full house - [('5', 'Hearts'), ('8', 'Spades')]
# 157 : Full house - [('5', 'Hearts'), ('8', 'Hearts')]
# 158 : Full house - [('5', 'Hearts'), ('8', 'Diamonds')]
# 159 : Full house - [('5', 'Hearts'), ('8', 'Clubs')]
# 160 : Full house - [('5', 'Hearts'), ('9', 'Spades')]
# 161 : Full house - [('5', 'Hearts'), ('9', 'Hearts')]
# 162 : Full house - [('5', 'Hearts'), ('9', 'Diamonds')]
# 163 : Full house - [('5', 'Hearts'), ('9', 'Clubs')]
# 164 : Full house - [('5', 'Hearts'), ('T', 'Spades')]
# 165 : Full house - [('5', 'Hearts'), ('T', 'Hearts')]
# 166 : Full house - [('5', 'Hearts'), ('T', 'Diamonds')]
# 167 : Full house - [('5', 'Hearts'), ('T', 'Clubs')]
# 168 : Full house - [('5', 'Hearts'), ('J', 'Spades')]
# 169 : Full house - [('5', 'Hearts'), ('J', 'Hearts')]
# 170 : Full house - [('5', 'Hearts'), ('J', 'Diamonds')]
# 171 : Full house - [('5', 'Hearts'), ('J', 'Clubs')]
# 172 : Full house - [('5', 'Hearts'), ('K', 'Spades')]
# 173 : Full house - [('5', 'Hearts'), ('K', 'Hearts')]
# 174 : Full house - [('5', 'Hearts'), ('K', 'Diamonds')]
# 175 : Full house - [('5', 'Hearts'), ('K', 'Clubs')]
# 176 : Full house - [('5', 'Hearts'), ('A', 'Spades')]
# 177 : Full house - [('5', 'Hearts'), ('A', 'Hearts')]
# 178 : Full house - [('5', 'Hearts'), ('A', 'Diamonds')]
# 179 : Full house - [('5', 'Hearts'), ('A', 'Clubs')]
# 180 : Full house - [('5', 'Clubs'), ('6', 'Spades')]
# 181 : Full house - [('5', 'Clubs'), ('6', 'Hearts')]
# 182 : Full house - [('5', 'Clubs'), ('6', 'Diamonds')]
# 183 : Full house - [('5', 'Clubs'), ('7', 'Spades')]
# 184 : Full house - [('5', 'Clubs'), ('7', 'Hearts')]
# 185 : Full house - [('5', 'Clubs'), ('7', 'Diamonds')]
# 186 : Full house - [('5', 'Clubs'), ('7', 'Clubs')]
# 187 : Full house - [('5', 'Clubs'), ('8', 'Spades')]
# 188 : Full house - [('5', 'Clubs'), ('8', 'Hearts')]
# 189 : Full house - [('5', 'Clubs'), ('8', 'Diamonds')]
# 190 : Full house - [('5', 'Clubs'), ('8', 'Clubs')]
# 191 : Full house - [('5', 'Clubs'), ('9', 'Spades')]
# 192 : Full house - [('5', 'Clubs'), ('9', 'Hearts')]
# 193 : Full house - [('5', 'Clubs'), ('9', 'Diamonds')]
# 194 : Full house - [('5', 'Clubs'), ('9', 'Clubs')]
# 195 : Full house - [('5', 'Clubs'), ('T', 'Spades')]
# 196 : Full house - [('5', 'Clubs'), ('T', 'Hearts')]
# 197 : Full house - [('5', 'Clubs'), ('T', 'Diamonds')]
# 198 : Full house - [('5', 'Clubs'), ('T', 'Clubs')]
# 199 : Full house - [('5', 'Clubs'), ('J', 'Spades')]
# 200 : Full house - [('5', 'Clubs'), ('J', 'Hearts')]
# 201 : Full house - [('5', 'Clubs'), ('J', 'Diamonds')]
# 202 : Full house - [('5', 'Clubs'), ('J', 'Clubs')]
# 203 : Full house - [('5', 'Clubs'), ('K', 'Spades')]
# 204 : Full house - [('5', 'Clubs'), ('K', 'Hearts')]
# 205 : Full house - [('5', 'Clubs'), ('K', 'Diamonds')]
# 206 : Full house - [('5', 'Clubs'), ('K', 'Clubs')]
# 207 : Full house - [('5', 'Clubs'), ('A', 'Spades')]
# 208 : Full house - [('5', 'Clubs'), ('A', 'Hearts')]
# 209 : Full house - [('5', 'Clubs'), ('A', 'Diamonds')]
# 210 : Full house - [('5', 'Clubs'), ('A', 'Clubs')]
# 211 : Full house - [('6', 'Spades'), ('7', 'Spades')]
# 212 : Full house - [('6', 'Spades'), ('7', 'Hearts')]
# 213 : Full house - [('6', 'Spades'), ('7', 'Diamonds')]
# 214 : Full house - [('6', 'Spades'), ('7', 'Clubs')]
# 215 : Full house - [('6', 'Spades'), ('8', 'Spades')]
# 216 : Full house - [('6', 'Spades'), ('8', 'Hearts')]
# 217 : Full house - [('6', 'Spades'), ('8', 'Diamonds')]
# 218 : Full house - [('6', 'Spades'), ('8', 'Clubs')]
# 219 : Full house - [('6', 'Spades'), ('9', 'Spades')]
# 220 : Full house - [('6', 'Spades'), ('9', 'Hearts')]
# 221 : Full house - [('6', 'Spades'), ('9', 'Diamonds')]
# 222 : Full house - [('6', 'Spades'), ('9', 'Clubs')]
# 223 : Full house - [('6', 'Spades'), ('T', 'Spades')]
# 224 : Full house - [('6', 'Spades'), ('T', 'Hearts')]
# 225 : Full house - [('6', 'Spades'), ('T', 'Diamonds')]
# 226 : Full house - [('6', 'Spades'), ('T', 'Clubs')]
# 227 : Full house - [('6', 'Spades'), ('J', 'Spades')]
# 228 : Full house - [('6', 'Spades'), ('J', 'Hearts')]
# 229 : Full house - [('6', 'Spades'), ('J', 'Diamonds')]
# 230 : Full house - [('6', 'Spades'), ('J', 'Clubs')]
# 231 : Full house - [('6', 'Spades'), ('K', 'Spades')]
# 232 : Full house - [('6', 'Spades'), ('K', 'Hearts')]
# 233 : Full house - [('6', 'Spades'), ('K', 'Diamonds')]
# 234 : Full house - [('6', 'Spades'), ('K', 'Clubs')]
# 235 : Full house - [('6', 'Spades'), ('A', 'Spades')]
# 236 : Full house - [('6', 'Spades'), ('A', 'Hearts')]
# 237 : Full house - [('6', 'Spades'), ('A', 'Diamonds')]
# 238 : Full house - [('6', 'Spades'), ('A', 'Clubs')]
# 239 : Full house - [('6', 'Hearts'), ('7', 'Spades')]
# 240 : Full house - [('6', 'Hearts'), ('7', 'Hearts')]
# 241 : Full house - [('6', 'Hearts'), ('7', 'Diamonds')]
# 242 : Full house - [('6', 'Hearts'), ('7', 'Clubs')]
# 243 : Full house - [('6', 'Hearts'), ('8', 'Spades')]
# 244 : Full house - [('6', 'Hearts'), ('8', 'Hearts')]
# 245 : Full house - [('6', 'Hearts'), ('8', 'Diamonds')]
# 246 : Full house - [('6', 'Hearts'), ('8', 'Clubs')]
# 247 : Full house - [('6', 'Hearts'), ('9', 'Spades')]
# 248 : Full house - [('6', 'Hearts'), ('9', 'Hearts')]
# 249 : Full house - [('6', 'Hearts'), ('9', 'Diamonds')]
# 250 : Full house - [('6', 'Hearts'), ('9', 'Clubs')]
# 251 : Full house - [('6', 'Hearts'), ('T', 'Spades')]
# 252 : Full house - [('6', 'Hearts'), ('T', 'Hearts')]
# 253 : Full house - [('6', 'Hearts'), ('T', 'Diamonds')]
# 254 : Full house - [('6', 'Hearts'), ('T', 'Clubs')]
# 255 : Full house - [('6', 'Hearts'), ('J', 'Spades')]
# 256 : Full house - [('6', 'Hearts'), ('J', 'Hearts')]
# 257 : Full house - [('6', 'Hearts'), ('J', 'Diamonds')]
# 258 : Full house - [('6', 'Hearts'), ('J', 'Clubs')]
# 259 : Full house - [('6', 'Hearts'), ('K', 'Spades')]
# 260 : Full house - [('6', 'Hearts'), ('K', 'Hearts')]
# 261 : Full house - [('6', 'Hearts'), ('K', 'Diamonds')]
# 262 : Full house - [('6', 'Hearts'), ('K', 'Clubs')]
# 263 : Full house - [('6', 'Hearts'), ('A', 'Spades')]
# 264 : Full house - [('6', 'Hearts'), ('A', 'Hearts')]
# 265 : Full house - [('6', 'Hearts'), ('A', 'Diamonds')]
# 266 : Full house - [('6', 'Hearts'), ('A', 'Clubs')]
# 267 : Full house - [('6', 'Diamonds'), ('7', 'Spades')]
# 268 : Full house - [('6', 'Diamonds'), ('7', 'Hearts')]
# 269 : Full house - [('6', 'Diamonds'), ('7', 'Diamonds')]
# 270 : Full house - [('6', 'Diamonds'), ('7', 'Clubs')]
# 271 : Full house - [('6', 'Diamonds'), ('8', 'Spades')]
# 272 : Full house - [('6', 'Diamonds'), ('8', 'Hearts')]
# 273 : Full house - [('6', 'Diamonds'), ('8', 'Diamonds')]
# 274 : Full house - [('6', 'Diamonds'), ('8', 'Clubs')]
# 275 : Full house - [('6', 'Diamonds'), ('9', 'Spades')]
# 276 : Full house - [('6', 'Diamonds'), ('9', 'Hearts')]
# 277 : Full house - [('6', 'Diamonds'), ('9', 'Diamonds')]
# 278 : Full house - [('6', 'Diamonds'), ('9', 'Clubs')]
# 279 : Full house - [('6', 'Diamonds'), ('T', 'Spades')]
# 280 : Full house - [('6', 'Diamonds'), ('T', 'Hearts')]
# 281 : Full house - [('6', 'Diamonds'), ('T', 'Diamonds')]
# 282 : Full house - [('6', 'Diamonds'), ('T', 'Clubs')]
# 283 : Full house - [('6', 'Diamonds'), ('J', 'Spades')]
# 284 : Full house - [('6', 'Diamonds'), ('J', 'Hearts')]
# 285 : Full house - [('6', 'Diamonds'), ('J', 'Diamonds')]
# 286 : Full house - [('6', 'Diamonds'), ('J', 'Clubs')]
# 287 : Full house - [('6', 'Diamonds'), ('K', 'Spades')]
# 288 : Full house - [('6', 'Diamonds'), ('K', 'Hearts')]
# 289 : Full house - [('6', 'Diamonds'), ('K', 'Diamonds')]
# 290 : Full house - [('6', 'Diamonds'), ('K', 'Clubs')]
# 291 : Full house - [('6', 'Diamonds'), ('A', 'Spades')]
# 292 : Full house - [('6', 'Diamonds'), ('A', 'Hearts')]
# 293 : Full house - [('6', 'Diamonds'), ('A', 'Diamonds')]
# 294 : Full house - [('6', 'Diamonds'), ('A', 'Clubs')]
# 295 : Full house - [('7', 'Spades'), ('7', 'Hearts')]
# 296 : Full house - [('7', 'Spades'), ('7', 'Diamonds')]
# 297 : Full house - [('7', 'Spades'), ('7', 'Clubs')]
# 298 : Full house - [('7', 'Hearts'), ('7', 'Diamonds')]
# 299 : Full house - [('7', 'Hearts'), ('7', 'Clubs')]
# 300 : Full house - [('7', 'Diamonds'), ('7', 'Clubs')]
# 301 : Full house - [('8', 'Spades'), ('8', 'Hearts')]
# 302 : Full house - [('8', 'Spades'), ('8', 'Diamonds')]
# 303 : Full house - [('8', 'Spades'), ('8', 'Clubs')]
# 304 : Full house - [('8', 'Hearts'), ('8', 'Diamonds')]
# 305 : Full house - [('8', 'Hearts'), ('8', 'Clubs')]
# 306 : Full house - [('8', 'Diamonds'), ('8', 'Clubs')]
# 307 : Full house - [('9', 'Spades'), ('9', 'Hearts')]
# 308 : Full house - [('9', 'Spades'), ('9', 'Diamonds')]
# 309 : Full house - [('9', 'Spades'), ('9', 'Clubs')]
# 310 : Full house - [('9', 'Hearts'), ('9', 'Diamonds')]
# 311 : Full house - [('9', 'Hearts'), ('9', 'Clubs')]
# 312 : Full house - [('9', 'Diamonds'), ('9', 'Clubs')]
# 313 : Full house - [('T', 'Spades'), ('T', 'Hearts')]
# 314 : Full house - [('T', 'Spades'), ('T', 'Diamonds')]
# 315 : Full house - [('T', 'Spades'), ('T', 'Clubs')]
# 316 : Full house - [('T', 'Hearts'), ('T', 'Diamonds')]
# 317 : Full house - [('T', 'Hearts'), ('T', 'Clubs')]
# 318 : Full house - [('T', 'Diamonds'), ('T', 'Clubs')]
# 319 : Full house - [('J', 'Spades'), ('J', 'Hearts')]
# 320 : Full house - [('J', 'Spades'), ('J', 'Diamonds')]
# 321 : Full house - [('J', 'Spades'), ('J', 'Clubs')]
# 322 : Full house - [('J', 'Hearts'), ('J', 'Diamonds')]
# 323 : Full house - [('J', 'Hearts'), ('J', 'Clubs')]
# 324 : Full house - [('J', 'Diamonds'), ('J', 'Clubs')]
# 325 : Full house - [('K', 'Spades'), ('K', 'Hearts')]
# 326 : Full house - [('K', 'Spades'), ('K', 'Diamonds')]
# 327 : Full house - [('K', 'Spades'), ('K', 'Clubs')]
# 328 : Full house - [('K', 'Hearts'), ('K', 'Diamonds')]
# 329 : Full house - [('K', 'Hearts'), ('K', 'Clubs')]
# 330 : Full house - [('K', 'Diamonds'), ('K', 'Clubs')]
# 331 : Full house - [('A', 'Spades'), ('A', 'Hearts')]
# 332 : Full house - [('A', 'Spades'), ('A', 'Diamonds')]
# 333 : Full house - [('A', 'Spades'), ('A', 'Clubs')]
# 334 : Full house - [('A', 'Hearts'), ('A', 'Diamonds')]
# 335 : Full house - [('A', 'Hearts'), ('A', 'Clubs')]
# 336 : Full house - [('A', 'Diamonds'), ('A', 'Clubs')]
# 337 : Three of a kind - [('2', 'Spades'), ('3', 'Spades')]
# 338 : Three of a kind - [('2', 'Spades'), ('3', 'Hearts')]
# 339 : Three of a kind - [('2', 'Spades'), ('3', 'Diamonds')]
# 340 : Three of a kind - [('2', 'Spades'), ('3', 'Clubs')]
# 341 : Three of a kind - [('2', 'Spades'), ('4', 'Spades')]
# 342 : Three of a kind - [('2', 'Spades'), ('4', 'Hearts')]
# 343 : Three of a kind - [('2', 'Spades'), ('4', 'Diamonds')]
# 344 : Three of a kind - [('2', 'Spades'), ('4', 'Clubs')]
# 345 : Three of a kind - [('2', 'Spades'), ('7', 'Spades')]
# 346 : Three of a kind - [('2', 'Spades'), ('7', 'Hearts')]
# 347 : Three of a kind - [('2', 'Spades'), ('7', 'Diamonds')]
# 348 : Three of a kind - [('2', 'Spades'), ('7', 'Clubs')]
# 349 : Three of a kind - [('2', 'Spades'), ('8', 'Spades')]
# 350 : Three of a kind - [('2', 'Spades'), ('8', 'Hearts')]
# 351 : Three of a kind - [('2', 'Spades'), ('8', 'Diamonds')]
# 352 : Three of a kind - [('2', 'Spades'), ('8', 'Clubs')]
# 353 : Three of a kind - [('2', 'Spades'), ('9', 'Spades')]
# 354 : Three of a kind - [('2', 'Spades'), ('9', 'Hearts')]
# 355 : Three of a kind - [('2', 'Spades'), ('9', 'Diamonds')]
# 356 : Three of a kind - [('2', 'Spades'), ('9', 'Clubs')]
# 357 : Three of a kind - [('2', 'Spades'), ('T', 'Spades')]
# 358 : Three of a kind - [('2', 'Spades'), ('T', 'Hearts')]
# 359 : Three of a kind - [('2', 'Spades'), ('T', 'Diamonds')]
# 360 : Three of a kind - [('2', 'Spades'), ('T', 'Clubs')]
# 361 : Three of a kind - [('2', 'Spades'), ('J', 'Spades')]
# 362 : Three of a kind - [('2', 'Spades'), ('J', 'Hearts')]
# 363 : Three of a kind - [('2', 'Spades'), ('J', 'Diamonds')]
# 364 : Three of a kind - [('2', 'Spades'), ('J', 'Clubs')]
# 365 : Three of a kind - [('2', 'Spades'), ('K', 'Spades')]
# 366 : Three of a kind - [('2', 'Spades'), ('K', 'Hearts')]
# 367 : Three of a kind - [('2', 'Spades'), ('K', 'Diamonds')]
# 368 : Three of a kind - [('2', 'Spades'), ('K', 'Clubs')]
# 369 : Three of a kind - [('2', 'Spades'), ('A', 'Spades')]
# 370 : Three of a kind - [('2', 'Spades'), ('A', 'Hearts')]
# 371 : Three of a kind - [('2', 'Spades'), ('A', 'Diamonds')]
# 372 : Three of a kind - [('2', 'Spades'), ('A', 'Clubs')]
# 373 : Three of a kind - [('2', 'Diamonds'), ('3', 'Spades')]
# 374 : Three of a kind - [('2', 'Diamonds'), ('3', 'Hearts')]
# 375 : Three of a kind - [('2', 'Diamonds'), ('3', 'Diamonds')]
# 376 : Three of a kind - [('2', 'Diamonds'), ('3', 'Clubs')]
# 377 : Three of a kind - [('2', 'Diamonds'), ('4', 'Spades')]
# 378 : Three of a kind - [('2', 'Diamonds'), ('4', 'Hearts')]
# 379 : Three of a kind - [('2', 'Diamonds'), ('4', 'Diamonds')]
# 380 : Three of a kind - [('2', 'Diamonds'), ('4', 'Clubs')]
# 381 : Three of a kind - [('2', 'Diamonds'), ('7', 'Spades')]
# 382 : Three of a kind - [('2', 'Diamonds'), ('7', 'Hearts')]
# 383 : Three of a kind - [('2', 'Diamonds'), ('7', 'Diamonds')]
# 384 : Three of a kind - [('2', 'Diamonds'), ('7', 'Clubs')]
# 385 : Three of a kind - [('2', 'Diamonds'), ('8', 'Spades')]
# 386 : Three of a kind - [('2', 'Diamonds'), ('8', 'Hearts')]
# 387 : Three of a kind - [('2', 'Diamonds'), ('8', 'Diamonds')]
# 388 : Three of a kind - [('2', 'Diamonds'), ('8', 'Clubs')]
# 389 : Three of a kind - [('2', 'Diamonds'), ('9', 'Spades')]
# 390 : Three of a kind - [('2', 'Diamonds'), ('9', 'Hearts')]
# 391 : Three of a kind - [('2', 'Diamonds'), ('9', 'Diamonds')]
# 392 : Three of a kind - [('2', 'Diamonds'), ('9', 'Clubs')]
# 393 : Three of a kind - [('2', 'Diamonds'), ('T', 'Spades')]
# 394 : Three of a kind - [('2', 'Diamonds'), ('T', 'Hearts')]
# 395 : Three of a kind - [('2', 'Diamonds'), ('T', 'Diamonds')]
# 396 : Three of a kind - [('2', 'Diamonds'), ('T', 'Clubs')]
# 397 : Three of a kind - [('2', 'Diamonds'), ('J', 'Spades')]
# 398 : Three of a kind - [('2', 'Diamonds'), ('J', 'Hearts')]
# 399 : Three of a kind - [('2', 'Diamonds'), ('J', 'Diamonds')]
# 400 : Three of a kind - [('2', 'Diamonds'), ('J', 'Clubs')]
# 401 : Three of a kind - [('2', 'Diamonds'), ('K', 'Spades')]
# 402 : Three of a kind - [('2', 'Diamonds'), ('K', 'Hearts')]
# 403 : Three of a kind - [('2', 'Diamonds'), ('K', 'Diamonds')]
# 404 : Three of a kind - [('2', 'Diamonds'), ('K', 'Clubs')]
# 405 : Three of a kind - [('2', 'Diamonds'), ('A', 'Spades')]
# 406 : Three of a kind - [('2', 'Diamonds'), ('A', 'Hearts')]
# 407 : Three of a kind - [('2', 'Diamonds'), ('A', 'Diamonds')]
# 408 : Three of a kind - [('2', 'Diamonds'), ('A', 'Clubs')]
# 409 : Three of a kind - [('3', 'Spades'), ('4', 'Spades')]
# 410 : Three of a kind - [('3', 'Spades'), ('4', 'Hearts')]
# 411 : Three of a kind - [('3', 'Spades'), ('4', 'Diamonds')]
# 412 : Three of a kind - [('3', 'Spades'), ('4', 'Clubs')]
# 413 : Three of a kind - [('3', 'Spades'), ('7', 'Spades')]
# 414 : Three of a kind - [('3', 'Spades'), ('7', 'Hearts')]
# 415 : Three of a kind - [('3', 'Spades'), ('7', 'Diamonds')]
# 416 : Three of a kind - [('3', 'Spades'), ('7', 'Clubs')]
# 417 : Three of a kind - [('3', 'Spades'), ('8', 'Spades')]
# 418 : Three of a kind - [('3', 'Spades'), ('8', 'Hearts')]
# 419 : Three of a kind - [('3', 'Spades'), ('8', 'Diamonds')]
# 420 : Three of a kind - [('3', 'Spades'), ('8', 'Clubs')]
# 421 : Three of a kind - [('3', 'Spades'), ('9', 'Spades')]
# 422 : Three of a kind - [('3', 'Spades'), ('9', 'Hearts')]
# 423 : Three of a kind - [('3', 'Spades'), ('9', 'Diamonds')]
# 424 : Three of a kind - [('3', 'Spades'), ('9', 'Clubs')]
# 425 : Three of a kind - [('3', 'Spades'), ('T', 'Spades')]
# 426 : Three of a kind - [('3', 'Spades'), ('T', 'Hearts')]
# 427 : Three of a kind - [('3', 'Spades'), ('T', 'Diamonds')]
# 428 : Three of a kind - [('3', 'Spades'), ('T', 'Clubs')]
# 429 : Three of a kind - [('3', 'Spades'), ('J', 'Spades')]
# 430 : Three of a kind - [('3', 'Spades'), ('J', 'Hearts')]
# 431 : Three of a kind - [('3', 'Spades'), ('J', 'Diamonds')]
# 432 : Three of a kind - [('3', 'Spades'), ('J', 'Clubs')]
# 433 : Three of a kind - [('3', 'Spades'), ('K', 'Spades')]
# 434 : Three of a kind - [('3', 'Spades'), ('K', 'Hearts')]
# 435 : Three of a kind - [('3', 'Spades'), ('K', 'Diamonds')]
# 436 : Three of a kind - [('3', 'Spades'), ('K', 'Clubs')]
# 437 : Three of a kind - [('3', 'Spades'), ('A', 'Spades')]
# 438 : Three of a kind - [('3', 'Spades'), ('A', 'Hearts')]
# 439 : Three of a kind - [('3', 'Spades'), ('A', 'Diamonds')]
# 440 : Three of a kind - [('3', 'Spades'), ('A', 'Clubs')]
# 441 : Three of a kind - [('3', 'Hearts'), ('4', 'Spades')]
# 442 : Three of a kind - [('3', 'Hearts'), ('4', 'Hearts')]
# 443 : Three of a kind - [('3', 'Hearts'), ('4', 'Diamonds')]
# 444 : Three of a kind - [('3', 'Hearts'), ('4', 'Clubs')]
# 445 : Three of a kind - [('3', 'Hearts'), ('7', 'Spades')]
# 446 : Three of a kind - [('3', 'Hearts'), ('7', 'Hearts')]
# 447 : Three of a kind - [('3', 'Hearts'), ('7', 'Diamonds')]
# 448 : Three of a kind - [('3', 'Hearts'), ('7', 'Clubs')]
# 449 : Three of a kind - [('3', 'Hearts'), ('8', 'Spades')]
# 450 : Three of a kind - [('3', 'Hearts'), ('8', 'Hearts')]
# 451 : Three of a kind - [('3', 'Hearts'), ('8', 'Diamonds')]
# 452 : Three of a kind - [('3', 'Hearts'), ('8', 'Clubs')]
# 453 : Three of a kind - [('3', 'Hearts'), ('9', 'Spades')]
# 454 : Three of a kind - [('3', 'Hearts'), ('9', 'Hearts')]
# 455 : Three of a kind - [('3', 'Hearts'), ('9', 'Diamonds')]
# 456 : Three of a kind - [('3', 'Hearts'), ('9', 'Clubs')]
# 457 : Three of a kind - [('3', 'Hearts'), ('T', 'Spades')]
# 458 : Three of a kind - [('3', 'Hearts'), ('T', 'Hearts')]
# 459 : Three of a kind - [('3', 'Hearts'), ('T', 'Diamonds')]
# 460 : Three of a kind - [('3', 'Hearts'), ('T', 'Clubs')]
# 461 : Three of a kind - [('3', 'Hearts'), ('J', 'Spades')]
# 462 : Three of a kind - [('3', 'Hearts'), ('J', 'Hearts')]
# 463 : Three of a kind - [('3', 'Hearts'), ('J', 'Diamonds')]
# 464 : Three of a kind - [('3', 'Hearts'), ('J', 'Clubs')]
# 465 : Three of a kind - [('3', 'Hearts'), ('K', 'Spades')]
# 466 : Three of a kind - [('3', 'Hearts'), ('K', 'Hearts')]
# 467 : Three of a kind - [('3', 'Hearts'), ('K', 'Diamonds')]
# 468 : Three of a kind - [('3', 'Hearts'), ('K', 'Clubs')]
# 469 : Three of a kind - [('3', 'Hearts'), ('A', 'Spades')]
# 470 : Three of a kind - [('3', 'Hearts'), ('A', 'Hearts')]
# 471 : Three of a kind - [('3', 'Hearts'), ('A', 'Diamonds')]
# 472 : Three of a kind - [('3', 'Hearts'), ('A', 'Clubs')]
# 473 : Three of a kind - [('3', 'Diamonds'), ('4', 'Spades')]
# 474 : Three of a kind - [('3', 'Diamonds'), ('4', 'Hearts')]
# 475 : Three of a kind - [('3', 'Diamonds'), ('4', 'Diamonds')]
# 476 : Three of a kind - [('3', 'Diamonds'), ('4', 'Clubs')]
# 477 : Three of a kind - [('3', 'Diamonds'), ('7', 'Spades')]
# 478 : Three of a kind - [('3', 'Diamonds'), ('7', 'Hearts')]
# 479 : Three of a kind - [('3', 'Diamonds'), ('7', 'Diamonds')]
# 480 : Three of a kind - [('3', 'Diamonds'), ('7', 'Clubs')]
# 481 : Three of a kind - [('3', 'Diamonds'), ('8', 'Spades')]
# 482 : Three of a kind - [('3', 'Diamonds'), ('8', 'Hearts')]
# 483 : Three of a kind - [('3', 'Diamonds'), ('8', 'Diamonds')]
# 484 : Three of a kind - [('3', 'Diamonds'), ('8', 'Clubs')]
# 485 : Three of a kind - [('3', 'Diamonds'), ('9', 'Spades')]
# 486 : Three of a kind - [('3', 'Diamonds'), ('9', 'Hearts')]
# 487 : Three of a kind - [('3', 'Diamonds'), ('9', 'Diamonds')]
# 488 : Three of a kind - [('3', 'Diamonds'), ('9', 'Clubs')]
# 489 : Three of a kind - [('3', 'Diamonds'), ('T', 'Spades')]
# 490 : Three of a kind - [('3', 'Diamonds'), ('T', 'Hearts')]
# 491 : Three of a kind - [('3', 'Diamonds'), ('T', 'Diamonds')]
# 492 : Three of a kind - [('3', 'Diamonds'), ('T', 'Clubs')]
# 493 : Three of a kind - [('3', 'Diamonds'), ('J', 'Spades')]
# 494 : Three of a kind - [('3', 'Diamonds'), ('J', 'Hearts')]
# 495 : Three of a kind - [('3', 'Diamonds'), ('J', 'Diamonds')]
# 496 : Three of a kind - [('3', 'Diamonds'), ('J', 'Clubs')]
# 497 : Three of a kind - [('3', 'Diamonds'), ('K', 'Spades')]
# 498 : Three of a kind - [('3', 'Diamonds'), ('K', 'Hearts')]
# 499 : Three of a kind - [('3', 'Diamonds'), ('K', 'Diamonds')]
# 500 : Three of a kind - [('3', 'Diamonds'), ('K', 'Clubs')]
# 501 : Three of a kind - [('3', 'Diamonds'), ('A', 'Spades')]
# 502 : Three of a kind - [('3', 'Diamonds'), ('A', 'Hearts')]
# 503 : Three of a kind - [('3', 'Diamonds'), ('A', 'Diamonds')]
# 504 : Three of a kind - [('3', 'Diamonds'), ('A', 'Clubs')]
# 505 : Three of a kind - [('3', 'Clubs'), ('4', 'Spades')]
# 506 : Three of a kind - [('3', 'Clubs'), ('4', 'Hearts')]
# 507 : Three of a kind - [('3', 'Clubs'), ('4', 'Diamonds')]
# 508 : Three of a kind - [('3', 'Clubs'), ('4', 'Clubs')]
# 509 : Three of a kind - [('3', 'Clubs'), ('7', 'Spades')]
# 510 : Three of a kind - [('3', 'Clubs'), ('7', 'Hearts')]
# 511 : Three of a kind - [('3', 'Clubs'), ('7', 'Diamonds')]
# 512 : Three of a kind - [('3', 'Clubs'), ('7', 'Clubs')]
# 513 : Three of a kind - [('3', 'Clubs'), ('8', 'Spades')]
# 514 : Three of a kind - [('3', 'Clubs'), ('8', 'Hearts')]
# 515 : Three of a kind - [('3', 'Clubs'), ('8', 'Diamonds')]
# 516 : Three of a kind - [('3', 'Clubs'), ('8', 'Clubs')]
# 517 : Three of a kind - [('3', 'Clubs'), ('9', 'Spades')]
# 518 : Three of a kind - [('3', 'Clubs'), ('9', 'Hearts')]
# 519 : Three of a kind - [('3', 'Clubs'), ('9', 'Diamonds')]
# 520 : Three of a kind - [('3', 'Clubs'), ('9', 'Clubs')]
# 521 : Three of a kind - [('3', 'Clubs'), ('T', 'Spades')]
# 522 : Three of a kind - [('3', 'Clubs'), ('T', 'Hearts')]
# 523 : Three of a kind - [('3', 'Clubs'), ('T', 'Diamonds')]
# 524 : Three of a kind - [('3', 'Clubs'), ('T', 'Clubs')]
# 525 : Three of a kind - [('3', 'Clubs'), ('J', 'Spades')]
# 526 : Three of a kind - [('3', 'Clubs'), ('J', 'Hearts')]
# 527 : Three of a kind - [('3', 'Clubs'), ('J', 'Diamonds')]
# 528 : Three of a kind - [('3', 'Clubs'), ('J', 'Clubs')]
# 529 : Three of a kind - [('3', 'Clubs'), ('K', 'Spades')]
# 530 : Three of a kind - [('3', 'Clubs'), ('K', 'Hearts')]
# 531 : Three of a kind - [('3', 'Clubs'), ('K', 'Diamonds')]
# 532 : Three of a kind - [('3', 'Clubs'), ('K', 'Clubs')]
# 533 : Three of a kind - [('3', 'Clubs'), ('A', 'Spades')]
# 534 : Three of a kind - [('3', 'Clubs'), ('A', 'Hearts')]
# 535 : Three of a kind - [('3', 'Clubs'), ('A', 'Diamonds')]
# 536 : Three of a kind - [('3', 'Clubs'), ('A', 'Clubs')]
# 537 : Three of a kind - [('4', 'Spades'), ('7', 'Spades')]
# 538 : Three of a kind - [('4', 'Spades'), ('7', 'Hearts')]
# 539 : Three of a kind - [('4', 'Spades'), ('7', 'Diamonds')]
# 540 : Three of a kind - [('4', 'Spades'), ('7', 'Clubs')]
# 541 : Three of a kind - [('4', 'Spades'), ('8', 'Spades')]
# 542 : Three of a kind - [('4', 'Spades'), ('8', 'Hearts')]
# 543 : Three of a kind - [('4', 'Spades'), ('8', 'Diamonds')]
# 544 : Three of a kind - [('4', 'Spades'), ('8', 'Clubs')]
# 545 : Three of a kind - [('4', 'Spades'), ('9', 'Spades')]
# 546 : Three of a kind - [('4', 'Spades'), ('9', 'Hearts')]
# 547 : Three of a kind - [('4', 'Spades'), ('9', 'Diamonds')]
# 548 : Three of a kind - [('4', 'Spades'), ('9', 'Clubs')]
# 549 : Three of a kind - [('4', 'Spades'), ('T', 'Spades')]
# 550 : Three of a kind - [('4', 'Spades'), ('T', 'Hearts')]
# 551 : Three of a kind - [('4', 'Spades'), ('T', 'Diamonds')]
# 552 : Three of a kind - [('4', 'Spades'), ('T', 'Clubs')]
# 553 : Three of a kind - [('4', 'Spades'), ('J', 'Spades')]
# 554 : Three of a kind - [('4', 'Spades'), ('J', 'Hearts')]
# 555 : Three of a kind - [('4', 'Spades'), ('J', 'Diamonds')]
# 556 : Three of a kind - [('4', 'Spades'), ('J', 'Clubs')]
# 557 : Three of a kind - [('4', 'Spades'), ('K', 'Spades')]
# 558 : Three of a kind - [('4', 'Spades'), ('K', 'Hearts')]
# 559 : Three of a kind - [('4', 'Spades'), ('K', 'Diamonds')]
# 560 : Three of a kind - [('4', 'Spades'), ('K', 'Clubs')]
# 561 : Three of a kind - [('4', 'Spades'), ('A', 'Spades')]
# 562 : Three of a kind - [('4', 'Spades'), ('A', 'Hearts')]
# 563 : Three of a kind - [('4', 'Spades'), ('A', 'Diamonds')]
# 564 : Three of a kind - [('4', 'Spades'), ('A', 'Clubs')]
# 565 : Three of a kind - [('4', 'Hearts'), ('7', 'Spades')]
# 566 : Three of a kind - [('4', 'Hearts'), ('7', 'Hearts')]
# 567 : Three of a kind - [('4', 'Hearts'), ('7', 'Diamonds')]
# 568 : Three of a kind - [('4', 'Hearts'), ('7', 'Clubs')]
# 569 : Three of a kind - [('4', 'Hearts'), ('8', 'Spades')]
# 570 : Three of a kind - [('4', 'Hearts'), ('8', 'Hearts')]
# 571 : Three of a kind - [('4', 'Hearts'), ('8', 'Diamonds')]
# 572 : Three of a kind - [('4', 'Hearts'), ('8', 'Clubs')]
# 573 : Three of a kind - [('4', 'Hearts'), ('9', 'Spades')]
# 574 : Three of a kind - [('4', 'Hearts'), ('9', 'Hearts')]
# 575 : Three of a kind - [('4', 'Hearts'), ('9', 'Diamonds')]
# 576 : Three of a kind - [('4', 'Hearts'), ('9', 'Clubs')]
# 577 : Three of a kind - [('4', 'Hearts'), ('T', 'Spades')]
# 578 : Three of a kind - [('4', 'Hearts'), ('T', 'Hearts')]
# 579 : Three of a kind - [('4', 'Hearts'), ('T', 'Diamonds')]
# 580 : Three of a kind - [('4', 'Hearts'), ('T', 'Clubs')]
# 581 : Three of a kind - [('4', 'Hearts'), ('J', 'Spades')]
# 582 : Three of a kind - [('4', 'Hearts'), ('J', 'Hearts')]
# 583 : Three of a kind - [('4', 'Hearts'), ('J', 'Diamonds')]
# 584 : Three of a kind - [('4', 'Hearts'), ('J', 'Clubs')]
# 585 : Three of a kind - [('4', 'Hearts'), ('K', 'Spades')]
# 586 : Three of a kind - [('4', 'Hearts'), ('K', 'Hearts')]
# 587 : Three of a kind - [('4', 'Hearts'), ('K', 'Diamonds')]
# 588 : Three of a kind - [('4', 'Hearts'), ('K', 'Clubs')]
# 589 : Three of a kind - [('4', 'Hearts'), ('A', 'Spades')]
# 590 : Three of a kind - [('4', 'Hearts'), ('A', 'Hearts')]
# 591 : Three of a kind - [('4', 'Hearts'), ('A', 'Diamonds')]
# 592 : Three of a kind - [('4', 'Hearts'), ('A', 'Clubs')]
# 593 : Three of a kind - [('4', 'Diamonds'), ('7', 'Spades')]
# 594 : Three of a kind - [('4', 'Diamonds'), ('7', 'Hearts')]
# 595 : Three of a kind - [('4', 'Diamonds'), ('7', 'Diamonds')]
# 596 : Three of a kind - [('4', 'Diamonds'), ('7', 'Clubs')]
# 597 : Three of a kind - [('4', 'Diamonds'), ('8', 'Spades')]
# 598 : Three of a kind - [('4', 'Diamonds'), ('8', 'Hearts')]
# 599 : Three of a kind - [('4', 'Diamonds'), ('8', 'Diamonds')]
# 600 : Three of a kind - [('4', 'Diamonds'), ('8', 'Clubs')]
# 601 : Three of a kind - [('4', 'Diamonds'), ('9', 'Spades')]
# 602 : Three of a kind - [('4', 'Diamonds'), ('9', 'Hearts')]
# 603 : Three of a kind - [('4', 'Diamonds'), ('9', 'Diamonds')]
# 604 : Three of a kind - [('4', 'Diamonds'), ('9', 'Clubs')]
# 605 : Three of a kind - [('4', 'Diamonds'), ('T', 'Spades')]
# 606 : Three of a kind - [('4', 'Diamonds'), ('T', 'Hearts')]
# 607 : Three of a kind - [('4', 'Diamonds'), ('T', 'Diamonds')]
# 608 : Three of a kind - [('4', 'Diamonds'), ('T', 'Clubs')]
# 609 : Three of a kind - [('4', 'Diamonds'), ('J', 'Spades')]
# 610 : Three of a kind - [('4', 'Diamonds'), ('J', 'Hearts')]
# 611 : Three of a kind - [('4', 'Diamonds'), ('J', 'Diamonds')]
# 612 : Three of a kind - [('4', 'Diamonds'), ('J', 'Clubs')]
# 613 : Three of a kind - [('4', 'Diamonds'), ('K', 'Spades')]
# 614 : Three of a kind - [('4', 'Diamonds'), ('K', 'Hearts')]
# 615 : Three of a kind - [('4', 'Diamonds'), ('K', 'Diamonds')]
# 616 : Three of a kind - [('4', 'Diamonds'), ('K', 'Clubs')]
# 617 : Three of a kind - [('4', 'Diamonds'), ('A', 'Spades')]
# 618 : Three of a kind - [('4', 'Diamonds'), ('A', 'Hearts')]
# 619 : Three of a kind - [('4', 'Diamonds'), ('A', 'Diamonds')]
# 620 : Three of a kind - [('4', 'Diamonds'), ('A', 'Clubs')]
# 621 : Three of a kind - [('4', 'Clubs'), ('7', 'Spades')]
# 622 : Three of a kind - [('4', 'Clubs'), ('7', 'Hearts')]
# 623 : Three of a kind - [('4', 'Clubs'), ('7', 'Diamonds')]
# 624 : Three of a kind - [('4', 'Clubs'), ('7', 'Clubs')]
# 625 : Three of a kind - [('4', 'Clubs'), ('8', 'Spades')]
# 626 : Three of a kind - [('4', 'Clubs'), ('8', 'Hearts')]
# 627 : Three of a kind - [('4', 'Clubs'), ('8', 'Diamonds')]
# 628 : Three of a kind - [('4', 'Clubs'), ('8', 'Clubs')]
# 629 : Three of a kind - [('4', 'Clubs'), ('9', 'Spades')]
# 630 : Three of a kind - [('4', 'Clubs'), ('9', 'Hearts')]
# 631 : Three of a kind - [('4', 'Clubs'), ('9', 'Diamonds')]
# 632 : Three of a kind - [('4', 'Clubs'), ('9', 'Clubs')]
# 633 : Three of a kind - [('4', 'Clubs'), ('T', 'Spades')]
# 634 : Three of a kind - [('4', 'Clubs'), ('T', 'Hearts')]
# 635 : Three of a kind - [('4', 'Clubs'), ('T', 'Diamonds')]
# 636 : Three of a kind - [('4', 'Clubs'), ('T', 'Clubs')]
# 637 : Three of a kind - [('4', 'Clubs'), ('J', 'Spades')]
# 638 : Three of a kind - [('4', 'Clubs'), ('J', 'Hearts')]
# 639 : Three of a kind - [('4', 'Clubs'), ('J', 'Diamonds')]
# 640 : Three of a kind - [('4', 'Clubs'), ('J', 'Clubs')]
# 641 : Three of a kind - [('4', 'Clubs'), ('K', 'Spades')]
# 642 : Three of a kind - [('4', 'Clubs'), ('K', 'Hearts')]
# 643 : Three of a kind - [('4', 'Clubs'), ('K', 'Diamonds')]
# 644 : Three of a kind - [('4', 'Clubs'), ('K', 'Clubs')]
# 645 : Three of a kind - [('4', 'Clubs'), ('A', 'Spades')]
# 646 : Three of a kind - [('4', 'Clubs'), ('A', 'Hearts')]
# 647 : Three of a kind - [('4', 'Clubs'), ('A', 'Diamonds')]
# 648 : Three of a kind - [('4', 'Clubs'), ('A', 'Clubs')]
# 649 : Three of a kind - [('5', 'Spades'), ('5', 'Hearts')]
# 650 : Three of a kind - [('5', 'Spades'), ('5', 'Clubs')]
# 651 : Three of a kind - [('5', 'Hearts'), ('5', 'Clubs')]
# 652 : Three of a kind - [('6', 'Spades'), ('6', 'Hearts')]
# 653 : Three of a kind - [('6', 'Spades'), ('6', 'Diamonds')]
# 654 : Three of a kind - [('6', 'Hearts'), ('6', 'Diamonds')]
# 655 : Three of a kind - [('7', 'Spades'), ('8', 'Spades')]
# 656 : Three of a kind - [('7', 'Spades'), ('8', 'Hearts')]
# 657 : Three of a kind - [('7', 'Spades'), ('8', 'Diamonds')]
# 658 : Three of a kind - [('7', 'Spades'), ('8', 'Clubs')]
# 659 : Three of a kind - [('7', 'Spades'), ('9', 'Spades')]
# 660 : Three of a kind - [('7', 'Spades'), ('9', 'Hearts')]
# 661 : Three of a kind - [('7', 'Spades'), ('9', 'Diamonds')]
# 662 : Three of a kind - [('7', 'Spades'), ('9', 'Clubs')]
# 663 : Three of a kind - [('7', 'Spades'), ('T', 'Spades')]
# 664 : Three of a kind - [('7', 'Spades'), ('T', 'Hearts')]
# 665 : Three of a kind - [('7', 'Spades'), ('T', 'Diamonds')]
# 666 : Three of a kind - [('7', 'Spades'), ('T', 'Clubs')]
# 667 : Three of a kind - [('7', 'Spades'), ('J', 'Spades')]
# 668 : Three of a kind - [('7', 'Spades'), ('J', 'Hearts')]
# 669 : Three of a kind - [('7', 'Spades'), ('J', 'Diamonds')]
# 670 : Three of a kind - [('7', 'Spades'), ('J', 'Clubs')]
# 671 : Three of a kind - [('7', 'Spades'), ('K', 'Spades')]
# 672 : Three of a kind - [('7', 'Spades'), ('K', 'Hearts')]
# 673 : Three of a kind - [('7', 'Spades'), ('K', 'Diamonds')]
# 674 : Three of a kind - [('7', 'Spades'), ('K', 'Clubs')]
# 675 : Three of a kind - [('7', 'Spades'), ('A', 'Spades')]
# 676 : Three of a kind - [('7', 'Spades'), ('A', 'Hearts')]
# 677 : Three of a kind - [('7', 'Spades'), ('A', 'Diamonds')]
# 678 : Three of a kind - [('7', 'Spades'), ('A', 'Clubs')]
# 679 : Three of a kind - [('7', 'Hearts'), ('8', 'Spades')]
# 680 : Three of a kind - [('7', 'Hearts'), ('8', 'Hearts')]
# 681 : Three of a kind - [('7', 'Hearts'), ('8', 'Diamonds')]
# 682 : Three of a kind - [('7', 'Hearts'), ('8', 'Clubs')]
# 683 : Three of a kind - [('7', 'Hearts'), ('9', 'Spades')]
# 684 : Three of a kind - [('7', 'Hearts'), ('9', 'Hearts')]
# 685 : Three of a kind - [('7', 'Hearts'), ('9', 'Diamonds')]
# 686 : Three of a kind - [('7', 'Hearts'), ('9', 'Clubs')]
# 687 : Three of a kind - [('7', 'Hearts'), ('T', 'Spades')]
# 688 : Three of a kind - [('7', 'Hearts'), ('T', 'Hearts')]
# 689 : Three of a kind - [('7', 'Hearts'), ('T', 'Diamonds')]
# 690 : Three of a kind - [('7', 'Hearts'), ('T', 'Clubs')]
# 691 : Three of a kind - [('7', 'Hearts'), ('J', 'Spades')]
# 692 : Three of a kind - [('7', 'Hearts'), ('J', 'Hearts')]
# 693 : Three of a kind - [('7', 'Hearts'), ('J', 'Diamonds')]
# 694 : Three of a kind - [('7', 'Hearts'), ('J', 'Clubs')]
# 695 : Three of a kind - [('7', 'Hearts'), ('K', 'Spades')]
# 696 : Three of a kind - [('7', 'Hearts'), ('K', 'Hearts')]
# 697 : Three of a kind - [('7', 'Hearts'), ('K', 'Diamonds')]
# 698 : Three of a kind - [('7', 'Hearts'), ('K', 'Clubs')]
# 699 : Three of a kind - [('7', 'Hearts'), ('A', 'Spades')]
# 700 : Three of a kind - [('7', 'Hearts'), ('A', 'Hearts')]
# 701 : Three of a kind - [('7', 'Hearts'), ('A', 'Diamonds')]
# 702 : Three of a kind - [('7', 'Hearts'), ('A', 'Clubs')]
# 703 : Three of a kind - [('7', 'Diamonds'), ('8', 'Spades')]
# 704 : Three of a kind - [('7', 'Diamonds'), ('8', 'Hearts')]
# 705 : Three of a kind - [('7', 'Diamonds'), ('8', 'Diamonds')]
# 706 : Three of a kind - [('7', 'Diamonds'), ('8', 'Clubs')]
# 707 : Three of a kind - [('7', 'Diamonds'), ('9', 'Spades')]
# 708 : Three of a kind - [('7', 'Diamonds'), ('9', 'Hearts')]
# 709 : Three of a kind - [('7', 'Diamonds'), ('9', 'Diamonds')]
# 710 : Three of a kind - [('7', 'Diamonds'), ('9', 'Clubs')]
# 711 : Three of a kind - [('7', 'Diamonds'), ('T', 'Spades')]
# 712 : Three of a kind - [('7', 'Diamonds'), ('T', 'Hearts')]
# 713 : Three of a kind - [('7', 'Diamonds'), ('T', 'Diamonds')]
# 714 : Three of a kind - [('7', 'Diamonds'), ('T', 'Clubs')]
# 715 : Three of a kind - [('7', 'Diamonds'), ('J', 'Spades')]
# 716 : Three of a kind - [('7', 'Diamonds'), ('J', 'Hearts')]
# 717 : Three of a kind - [('7', 'Diamonds'), ('J', 'Diamonds')]
# 718 : Three of a kind - [('7', 'Diamonds'), ('J', 'Clubs')]
# 719 : Three of a kind - [('7', 'Diamonds'), ('K', 'Spades')]
# 720 : Three of a kind - [('7', 'Diamonds'), ('K', 'Hearts')]
# 721 : Three of a kind - [('7', 'Diamonds'), ('K', 'Diamonds')]
# 722 : Three of a kind - [('7', 'Diamonds'), ('K', 'Clubs')]
# 723 : Three of a kind - [('7', 'Diamonds'), ('A', 'Spades')]
# 724 : Three of a kind - [('7', 'Diamonds'), ('A', 'Hearts')]
# 725 : Three of a kind - [('7', 'Diamonds'), ('A', 'Diamonds')]
# 726 : Three of a kind - [('7', 'Diamonds'), ('A', 'Clubs')]
# 727 : Three of a kind - [('7', 'Clubs'), ('8', 'Spades')]
# 728 : Three of a kind - [('7', 'Clubs'), ('8', 'Hearts')]
# 729 : Three of a kind - [('7', 'Clubs'), ('8', 'Diamonds')]
# 730 : Three of a kind - [('7', 'Clubs'), ('8', 'Clubs')]
# 731 : Three of a kind - [('7', 'Clubs'), ('9', 'Spades')]
# 732 : Three of a kind - [('7', 'Clubs'), ('9', 'Hearts')]
# 733 : Three of a kind - [('7', 'Clubs'), ('9', 'Diamonds')]
# 734 : Three of a kind - [('7', 'Clubs'), ('9', 'Clubs')]
# 735 : Three of a kind - [('7', 'Clubs'), ('T', 'Spades')]
# 736 : Three of a kind - [('7', 'Clubs'), ('T', 'Hearts')]
# 737 : Three of a kind - [('7', 'Clubs'), ('T', 'Diamonds')]
# 738 : Three of a kind - [('7', 'Clubs'), ('T', 'Clubs')]
# 739 : Three of a kind - [('7', 'Clubs'), ('J', 'Spades')]
# 740 : Three of a kind - [('7', 'Clubs'), ('J', 'Hearts')]
# 741 : Three of a kind - [('7', 'Clubs'), ('J', 'Diamonds')]
# 742 : Three of a kind - [('7', 'Clubs'), ('J', 'Clubs')]
# 743 : Three of a kind - [('7', 'Clubs'), ('K', 'Spades')]
# 744 : Three of a kind - [('7', 'Clubs'), ('K', 'Hearts')]
# 745 : Three of a kind - [('7', 'Clubs'), ('K', 'Diamonds')]
# 746 : Three of a kind - [('7', 'Clubs'), ('K', 'Clubs')]
# 747 : Three of a kind - [('7', 'Clubs'), ('A', 'Spades')]
# 748 : Three of a kind - [('7', 'Clubs'), ('A', 'Hearts')]
# 749 : Three of a kind - [('7', 'Clubs'), ('A', 'Diamonds')]
# 750 : Three of a kind - [('7', 'Clubs'), ('A', 'Clubs')]
# 751 : Three of a kind - [('8', 'Spades'), ('9', 'Spades')]
# 752 : Three of a kind - [('8', 'Spades'), ('9', 'Hearts')]
# 753 : Three of a kind - [('8', 'Spades'), ('9', 'Diamonds')]
# 754 : Three of a kind - [('8', 'Spades'), ('9', 'Clubs')]
# 755 : Three of a kind - [('8', 'Spades'), ('T', 'Spades')]
# 756 : Three of a kind - [('8', 'Spades'), ('T', 'Hearts')]
# 757 : Three of a kind - [('8', 'Spades'), ('T', 'Diamonds')]
# 758 : Three of a kind - [('8', 'Spades'), ('T', 'Clubs')]
# 759 : Three of a kind - [('8', 'Spades'), ('J', 'Spades')]
# 760 : Three of a kind - [('8', 'Spades'), ('J', 'Hearts')]
# 761 : Three of a kind - [('8', 'Spades'), ('J', 'Diamonds')]
# 762 : Three of a kind - [('8', 'Spades'), ('J', 'Clubs')]
# 763 : Three of a kind - [('8', 'Spades'), ('K', 'Spades')]
# 764 : Three of a kind - [('8', 'Spades'), ('K', 'Hearts')]
# 765 : Three of a kind - [('8', 'Spades'), ('K', 'Diamonds')]
# 766 : Three of a kind - [('8', 'Spades'), ('K', 'Clubs')]
# 767 : Three of a kind - [('8', 'Spades'), ('A', 'Spades')]
# 768 : Three of a kind - [('8', 'Spades'), ('A', 'Hearts')]
# 769 : Three of a kind - [('8', 'Spades'), ('A', 'Diamonds')]
# 770 : Three of a kind - [('8', 'Spades'), ('A', 'Clubs')]
# 771 : Three of a kind - [('8', 'Hearts'), ('9', 'Spades')]
# 772 : Three of a kind - [('8', 'Hearts'), ('9', 'Hearts')]
# 773 : Three of a kind - [('8', 'Hearts'), ('9', 'Diamonds')]
# 774 : Three of a kind - [('8', 'Hearts'), ('9', 'Clubs')]
# 775 : Three of a kind - [('8', 'Hearts'), ('T', 'Spades')]
# 776 : Three of a kind - [('8', 'Hearts'), ('T', 'Hearts')]
# 777 : Three of a kind - [('8', 'Hearts'), ('T', 'Diamonds')]
# 778 : Three of a kind - [('8', 'Hearts'), ('T', 'Clubs')]
# 779 : Three of a kind - [('8', 'Hearts'), ('J', 'Spades')]
# 780 : Three of a kind - [('8', 'Hearts'), ('J', 'Hearts')]
# 781 : Three of a kind - [('8', 'Hearts'), ('J', 'Diamonds')]
# 782 : Three of a kind - [('8', 'Hearts'), ('J', 'Clubs')]
# 783 : Three of a kind - [('8', 'Hearts'), ('K', 'Spades')]
# 784 : Three of a kind - [('8', 'Hearts'), ('K', 'Hearts')]
# 785 : Three of a kind - [('8', 'Hearts'), ('K', 'Diamonds')]
# 786 : Three of a kind - [('8', 'Hearts'), ('K', 'Clubs')]
# 787 : Three of a kind - [('8', 'Hearts'), ('A', 'Spades')]
# 788 : Three of a kind - [('8', 'Hearts'), ('A', 'Hearts')]
# 789 : Three of a kind - [('8', 'Hearts'), ('A', 'Diamonds')]
# 790 : Three of a kind - [('8', 'Hearts'), ('A', 'Clubs')]
# 791 : Three of a kind - [('8', 'Diamonds'), ('9', 'Spades')]
# 792 : Three of a kind - [('8', 'Diamonds'), ('9', 'Hearts')]
# 793 : Three of a kind - [('8', 'Diamonds'), ('9', 'Diamonds')]
# 794 : Three of a kind - [('8', 'Diamonds'), ('9', 'Clubs')]
# 795 : Three of a kind - [('8', 'Diamonds'), ('T', 'Spades')]
# 796 : Three of a kind - [('8', 'Diamonds'), ('T', 'Hearts')]
# 797 : Three of a kind - [('8', 'Diamonds'), ('T', 'Diamonds')]
# 798 : Three of a kind - [('8', 'Diamonds'), ('T', 'Clubs')]
# 799 : Three of a kind - [('8', 'Diamonds'), ('J', 'Spades')]
# 800 : Three of a kind - [('8', 'Diamonds'), ('J', 'Hearts')]
# 801 : Three of a kind - [('8', 'Diamonds'), ('J', 'Diamonds')]
# 802 : Three of a kind - [('8', 'Diamonds'), ('J', 'Clubs')]
# 803 : Three of a kind - [('8', 'Diamonds'), ('K', 'Spades')]
# 804 : Three of a kind - [('8', 'Diamonds'), ('K', 'Hearts')]
# 805 : Three of a kind - [('8', 'Diamonds'), ('K', 'Diamonds')]
# 806 : Three of a kind - [('8', 'Diamonds'), ('K', 'Clubs')]
# 807 : Three of a kind - [('8', 'Diamonds'), ('A', 'Spades')]
# 808 : Three of a kind - [('8', 'Diamonds'), ('A', 'Hearts')]
# 809 : Three of a kind - [('8', 'Diamonds'), ('A', 'Diamonds')]
# 810 : Three of a kind - [('8', 'Diamonds'), ('A', 'Clubs')]
# 811 : Three of a kind - [('8', 'Clubs'), ('9', 'Spades')]
# 812 : Three of a kind - [('8', 'Clubs'), ('9', 'Hearts')]
# 813 : Three of a kind - [('8', 'Clubs'), ('9', 'Diamonds')]
# 814 : Three of a kind - [('8', 'Clubs'), ('9', 'Clubs')]
# 815 : Three of a kind - [('8', 'Clubs'), ('T', 'Spades')]
# 816 : Three of a kind - [('8', 'Clubs'), ('T', 'Hearts')]
# 817 : Three of a kind - [('8', 'Clubs'), ('T', 'Diamonds')]
# 818 : Three of a kind - [('8', 'Clubs'), ('T', 'Clubs')]
# 819 : Three of a kind - [('8', 'Clubs'), ('J', 'Spades')]
# 820 : Three of a kind - [('8', 'Clubs'), ('J', 'Hearts')]
# 821 : Three of a kind - [('8', 'Clubs'), ('J', 'Diamonds')]
# 822 : Three of a kind - [('8', 'Clubs'), ('J', 'Clubs')]
# 823 : Three of a kind - [('8', 'Clubs'), ('K', 'Spades')]
# 824 : Three of a kind - [('8', 'Clubs'), ('K', 'Hearts')]
# 825 : Three of a kind - [('8', 'Clubs'), ('K', 'Diamonds')]
# 826 : Three of a kind - [('8', 'Clubs'), ('K', 'Clubs')]
# 827 : Three of a kind - [('8', 'Clubs'), ('A', 'Spades')]
# 828 : Three of a kind - [('8', 'Clubs'), ('A', 'Hearts')]
# 829 : Three of a kind - [('8', 'Clubs'), ('A', 'Diamonds')]
# 830 : Three of a kind - [('8', 'Clubs'), ('A', 'Clubs')]
# 831 : Three of a kind - [('9', 'Spades'), ('T', 'Spades')]
# 832 : Three of a kind - [('9', 'Spades'), ('T', 'Hearts')]
# 833 : Three of a kind - [('9', 'Spades'), ('T', 'Diamonds')]
# 834 : Three of a kind - [('9', 'Spades'), ('T', 'Clubs')]
# 835 : Three of a kind - [('9', 'Spades'), ('J', 'Spades')]
# 836 : Three of a kind - [('9', 'Spades'), ('J', 'Hearts')]
# 837 : Three of a kind - [('9', 'Spades'), ('J', 'Diamonds')]
# 838 : Three of a kind - [('9', 'Spades'), ('J', 'Clubs')]
# 839 : Three of a kind - [('9', 'Spades'), ('K', 'Spades')]
# 840 : Three of a kind - [('9', 'Spades'), ('K', 'Hearts')]
# 841 : Three of a kind - [('9', 'Spades'), ('K', 'Diamonds')]
# 842 : Three of a kind - [('9', 'Spades'), ('K', 'Clubs')]
# 843 : Three of a kind - [('9', 'Spades'), ('A', 'Spades')]
# 844 : Three of a kind - [('9', 'Spades'), ('A', 'Hearts')]
# 845 : Three of a kind - [('9', 'Spades'), ('A', 'Diamonds')]
# 846 : Three of a kind - [('9', 'Spades'), ('A', 'Clubs')]
# 847 : Three of a kind - [('9', 'Hearts'), ('T', 'Spades')]
# 848 : Three of a kind - [('9', 'Hearts'), ('T', 'Hearts')]
# 849 : Three of a kind - [('9', 'Hearts'), ('T', 'Diamonds')]
# 850 : Three of a kind - [('9', 'Hearts'), ('T', 'Clubs')]
# 851 : Three of a kind - [('9', 'Hearts'), ('J', 'Spades')]
# 852 : Three of a kind - [('9', 'Hearts'), ('J', 'Hearts')]
# 853 : Three of a kind - [('9', 'Hearts'), ('J', 'Diamonds')]
# 854 : Three of a kind - [('9', 'Hearts'), ('J', 'Clubs')]
# 855 : Three of a kind - [('9', 'Hearts'), ('K', 'Spades')]
# 856 : Three of a kind - [('9', 'Hearts'), ('K', 'Hearts')]
# 857 : Three of a kind - [('9', 'Hearts'), ('K', 'Diamonds')]
# 858 : Three of a kind - [('9', 'Hearts'), ('K', 'Clubs')]
# 859 : Three of a kind - [('9', 'Hearts'), ('A', 'Spades')]
# 860 : Three of a kind - [('9', 'Hearts'), ('A', 'Hearts')]
# 861 : Three of a kind - [('9', 'Hearts'), ('A', 'Diamonds')]
# 862 : Three of a kind - [('9', 'Hearts'), ('A', 'Clubs')]
# 863 : Three of a kind - [('9', 'Diamonds'), ('T', 'Spades')]
# 864 : Three of a kind - [('9', 'Diamonds'), ('T', 'Hearts')]
# 865 : Three of a kind - [('9', 'Diamonds'), ('T', 'Diamonds')]
# 866 : Three of a kind - [('9', 'Diamonds'), ('T', 'Clubs')]
# 867 : Three of a kind - [('9', 'Diamonds'), ('J', 'Spades')]
# 868 : Three of a kind - [('9', 'Diamonds'), ('J', 'Hearts')]
# 869 : Three of a kind - [('9', 'Diamonds'), ('J', 'Diamonds')]
# 870 : Three of a kind - [('9', 'Diamonds'), ('J', 'Clubs')]
# 871 : Three of a kind - [('9', 'Diamonds'), ('K', 'Spades')]
# 872 : Three of a kind - [('9', 'Diamonds'), ('K', 'Hearts')]
# 873 : Three of a kind - [('9', 'Diamonds'), ('K', 'Diamonds')]
# 874 : Three of a kind - [('9', 'Diamonds'), ('K', 'Clubs')]
# 875 : Three of a kind - [('9', 'Diamonds'), ('A', 'Spades')]
# 876 : Three of a kind - [('9', 'Diamonds'), ('A', 'Hearts')]
# 877 : Three of a kind - [('9', 'Diamonds'), ('A', 'Diamonds')]
# 878 : Three of a kind - [('9', 'Diamonds'), ('A', 'Clubs')]
# 879 : Three of a kind - [('9', 'Clubs'), ('T', 'Spades')]
# 880 : Three of a kind - [('9', 'Clubs'), ('T', 'Hearts')]
# 881 : Three of a kind - [('9', 'Clubs'), ('T', 'Diamonds')]
# 882 : Three of a kind - [('9', 'Clubs'), ('T', 'Clubs')]
# 883 : Three of a kind - [('9', 'Clubs'), ('J', 'Spades')]
# 884 : Three of a kind - [('9', 'Clubs'), ('J', 'Hearts')]
# 885 : Three of a kind - [('9', 'Clubs'), ('J', 'Diamonds')]
# 886 : Three of a kind - [('9', 'Clubs'), ('J', 'Clubs')]
# 887 : Three of a kind - [('9', 'Clubs'), ('K', 'Spades')]
# 888 : Three of a kind - [('9', 'Clubs'), ('K', 'Hearts')]
# 889 : Three of a kind - [('9', 'Clubs'), ('K', 'Diamonds')]
# 890 : Three of a kind - [('9', 'Clubs'), ('K', 'Clubs')]
# 891 : Three of a kind - [('9', 'Clubs'), ('A', 'Spades')]
# 892 : Three of a kind - [('9', 'Clubs'), ('A', 'Hearts')]
# 893 : Three of a kind - [('9', 'Clubs'), ('A', 'Diamonds')]
# 894 : Three of a kind - [('9', 'Clubs'), ('A', 'Clubs')]
# 895 : Three of a kind - [('T', 'Spades'), ('J', 'Spades')]
# 896 : Three of a kind - [('T', 'Spades'), ('J', 'Hearts')]
# 897 : Three of a kind - [('T', 'Spades'), ('J', 'Diamonds')]
# 898 : Three of a kind - [('T', 'Spades'), ('J', 'Clubs')]
# 899 : Three of a kind - [('T', 'Spades'), ('K', 'Spades')]
# 900 : Three of a kind - [('T', 'Spades'), ('K', 'Hearts')]
# 901 : Three of a kind - [('T', 'Spades'), ('K', 'Diamonds')]
# 902 : Three of a kind - [('T', 'Spades'), ('K', 'Clubs')]
# 903 : Three of a kind - [('T', 'Spades'), ('A', 'Spades')]
# 904 : Three of a kind - [('T', 'Spades'), ('A', 'Hearts')]
# 905 : Three of a kind - [('T', 'Spades'), ('A', 'Diamonds')]
# 906 : Three of a kind - [('T', 'Spades'), ('A', 'Clubs')]
# 907 : Three of a kind - [('T', 'Hearts'), ('J', 'Spades')]
# 908 : Three of a kind - [('T', 'Hearts'), ('J', 'Hearts')]
# 909 : Three of a kind - [('T', 'Hearts'), ('J', 'Diamonds')]
# 910 : Three of a kind - [('T', 'Hearts'), ('J', 'Clubs')]
# 911 : Three of a kind - [('T', 'Hearts'), ('K', 'Spades')]
# 912 : Three of a kind - [('T', 'Hearts'), ('K', 'Hearts')]
# 913 : Three of a kind - [('T', 'Hearts'), ('K', 'Diamonds')]
# 914 : Three of a kind - [('T', 'Hearts'), ('K', 'Clubs')]
# 915 : Three of a kind - [('T', 'Hearts'), ('A', 'Spades')]
# 916 : Three of a kind - [('T', 'Hearts'), ('A', 'Hearts')]
# 917 : Three of a kind - [('T', 'Hearts'), ('A', 'Diamonds')]
# 918 : Three of a kind - [('T', 'Hearts'), ('A', 'Clubs')]
# 919 : Three of a kind - [('T', 'Diamonds'), ('J', 'Spades')]
# 920 : Three of a kind - [('T', 'Diamonds'), ('J', 'Hearts')]
# 921 : Three of a kind - [('T', 'Diamonds'), ('J', 'Diamonds')]
# 922 : Three of a kind - [('T', 'Diamonds'), ('J', 'Clubs')]
# 923 : Three of a kind - [('T', 'Diamonds'), ('K', 'Spades')]
# 924 : Three of a kind - [('T', 'Diamonds'), ('K', 'Hearts')]
# 925 : Three of a kind - [('T', 'Diamonds'), ('K', 'Diamonds')]
# 926 : Three of a kind - [('T', 'Diamonds'), ('K', 'Clubs')]
# 927 : Three of a kind - [('T', 'Diamonds'), ('A', 'Spades')]
# 928 : Three of a kind - [('T', 'Diamonds'), ('A', 'Hearts')]
# 929 : Three of a kind - [('T', 'Diamonds'), ('A', 'Diamonds')]
# 930 : Three of a kind - [('T', 'Diamonds'), ('A', 'Clubs')]
# 931 : Three of a kind - [('T', 'Clubs'), ('J', 'Spades')]
# 932 : Three of a kind - [('T', 'Clubs'), ('J', 'Hearts')]
# 933 : Three of a kind - [('T', 'Clubs'), ('J', 'Diamonds')]
# 934 : Three of a kind - [('T', 'Clubs'), ('J', 'Clubs')]
# 935 : Three of a kind - [('T', 'Clubs'), ('K', 'Spades')]
# 936 : Three of a kind - [('T', 'Clubs'), ('K', 'Hearts')]
# 937 : Three of a kind - [('T', 'Clubs'), ('K', 'Diamonds')]
# 938 : Three of a kind - [('T', 'Clubs'), ('K', 'Clubs')]
# 939 : Three of a kind - [('T', 'Clubs'), ('A', 'Spades')]
# 940 : Three of a kind - [('T', 'Clubs'), ('A', 'Hearts')]
# 941 : Three of a kind - [('T', 'Clubs'), ('A', 'Diamonds')]
# 942 : Three of a kind - [('T', 'Clubs'), ('A', 'Clubs')]
# 943 : Three of a kind - [('J', 'Spades'), ('K', 'Spades')]
# 944 : Three of a kind - [('J', 'Spades'), ('K', 'Hearts')]
# 945 : Three of a kind - [('J', 'Spades'), ('K', 'Diamonds')]
# 946 : Three of a kind - [('J', 'Spades'), ('K', 'Clubs')]
# 947 : Three of a kind - [('J', 'Spades'), ('A', 'Spades')]
# 948 : Three of a kind - [('J', 'Spades'), ('A', 'Hearts')]
# 949 : Three of a kind - [('J', 'Spades'), ('A', 'Diamonds')]
# 950 : Three of a kind - [('J', 'Spades'), ('A', 'Clubs')]
# 951 : Three of a kind - [('J', 'Hearts'), ('K', 'Spades')]
# 952 : Three of a kind - [('J', 'Hearts'), ('K', 'Hearts')]
# 953 : Three of a kind - [('J', 'Hearts'), ('K', 'Diamonds')]
# 954 : Three of a kind - [('J', 'Hearts'), ('K', 'Clubs')]
# 955 : Three of a kind - [('J', 'Hearts'), ('A', 'Spades')]
# 956 : Three of a kind - [('J', 'Hearts'), ('A', 'Hearts')]
# 957 : Three of a kind - [('J', 'Hearts'), ('A', 'Diamonds')]
# 958 : Three of a kind - [('J', 'Hearts'), ('A', 'Clubs')]
# 959 : Three of a kind - [('J', 'Diamonds'), ('K', 'Spades')]
# 960 : Three of a kind - [('J', 'Diamonds'), ('K', 'Hearts')]
# 961 : Three of a kind - [('J', 'Diamonds'), ('K', 'Diamonds')]
# 962 : Three of a kind - [('J', 'Diamonds'), ('K', 'Clubs')]
# 963 : Three of a kind - [('J', 'Diamonds'), ('A', 'Spades')]
# 964 : Three of a kind - [('J', 'Diamonds'), ('A', 'Hearts')]
# 965 : Three of a kind - [('J', 'Diamonds'), ('A', 'Diamonds')]
# 966 : Three of a kind - [('J', 'Diamonds'), ('A', 'Clubs')]
# 967 : Three of a kind - [('J', 'Clubs'), ('K', 'Spades')]
# 968 : Three of a kind - [('J', 'Clubs'), ('K', 'Hearts')]
# 969 : Three of a kind - [('J', 'Clubs'), ('K', 'Diamonds')]
# 970 : Three of a kind - [('J', 'Clubs'), ('K', 'Clubs')]
# 971 : Three of a kind - [('J', 'Clubs'), ('A', 'Spades')]
# 972 : Three of a kind - [('J', 'Clubs'), ('A', 'Hearts')]
# 973 : Three of a kind - [('J', 'Clubs'), ('A', 'Diamonds')]
# 974 : Three of a kind - [('J', 'Clubs'), ('A', 'Clubs')]
# 975 : Three of a kind - [('K', 'Spades'), ('A', 'Spades')]
# 976 : Three of a kind - [('K', 'Spades'), ('A', 'Hearts')]
# 977 : Three of a kind - [('K', 'Spades'), ('A', 'Diamonds')]
# 978 : Three of a kind - [('K', 'Spades'), ('A', 'Clubs')]
# 979 : Three of a kind - [('K', 'Hearts'), ('A', 'Spades')]
# 980 : Three of a kind - [('K', 'Hearts'), ('A', 'Hearts')]
# 981 : Three of a kind - [('K', 'Hearts'), ('A', 'Diamonds')]
# 982 : Three of a kind - [('K', 'Hearts'), ('A', 'Clubs')]
# 983 : Three of a kind - [('K', 'Diamonds'), ('A', 'Spades')]
# 984 : Three of a kind - [('K', 'Diamonds'), ('A', 'Hearts')]
# 985 : Three of a kind - [('K', 'Diamonds'), ('A', 'Diamonds')]
# 986 : Three of a kind - [('K', 'Diamonds'), ('A', 'Clubs')]
# 987 : Three of a kind - [('K', 'Clubs'), ('A', 'Spades')]
# 988 : Three of a kind - [('K', 'Clubs'), ('A', 'Hearts')]
# 989 : Three of a kind - [('K', 'Clubs'), ('A', 'Diamonds')]
# 990 : Three of a kind - [('K', 'Clubs'), ('A', 'Clubs')]

# %%
import random
import itertools

def find_high_card(cards):
    sorted_cards = sorted(cards, key=lambda x: '23456789TJQKA'.index(x[0]))
    return sorted_cards[-1]

def generate_random_cards(num_cards):
    ranks = '23456789TJQKA'
    suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
    deck = [(rank, suit) for rank in ranks for suit in suits]
    return random.sample(deck, num_cards)

def print_combination(hand_type, winning_cards, winning_combination, high_card):
    if hand_type == "Pair":
        print("Combination: Pair of", winning_cards[0][0] + "s")
    elif hand_type == "Two pair":
        pair1_rank = winning_cards[0][0]
        pair2_rank = winning_cards[2][0]
        print("Combination: Two Pair - Pair of", pair1_rank + "s and Pair of", pair2_rank + "s")
    # Add more elif blocks for other combinations
    else:
        print("Combination:", winning_combination)

def predict_poker_hand(hand, table_cards):
    all_cards = hand + table_cards
    sorted_cards = sorted(all_cards, key=lambda x: '23456789TJQKA'.index(x[0]))

    suits = [card[1] for card in all_cards]
    ranks = [card[0] for card in all_cards]

    for suit in set(suits):
        if suits.count(suit) >= 5:
            flush_cards = [card for card in all_cards if card[1] == suit]
            flush_sorted = sorted(flush_cards, key=lambda x: '23456789TJQKA'.index(x[0]))
            if len(set([card[1] for card in flush_sorted[-5:]])) == 1:
                if flush_sorted[-1][0] == 'A':
                    return "Royal flush", None, "Royal Flush"
                else:
                    return "Straight flush", None, "Straight Flush"

    # Check for Straight
    unique_ranks = sorted(set(ranks), key=lambda x: '23456789TJQKA'.index(x))
    straight_ranks = 'A23456789TJQKA'  # 'A'  low Ace
    for i in range(len(unique_ranks) - 4):
        if ''.join(unique_ranks[i:i+5]) in straight_ranks:
            return "Straight", None, "Straight"

    counts = [ranks.count(rank) for rank in set(ranks)]

    if 4 in counts:  # Four of a kind
        return "Four of a kind", None, "Four of a Kind"

    if 3 in counts and 2 in counts:  # Full house
        return "Full house", None, "Full House"

    if 3 in counts:  # Three of a kind
        three_kind_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 3])
        three_kind_cards = [card for card in all_cards if card[0] in three_kind_rank]
        return "Three of a kind", three_kind_cards, "Three of a Kind", find_high_card(three_kind_cards)

    if counts.count(2) == 2:  # Two pair
        two_pair_ranks = [rank for rank in set(ranks) if ranks.count(rank) == 2]
        two_pair_cards = [card for card in all_cards if card[0] in two_pair_ranks]
        return "Two pair", two_pair_cards, "Two Pair", find_high_card(two_pair_cards)

    if counts.count(2) == 1:  # Pair
        pair_rank = set([rank for rank in set(ranks) if ranks.count(rank) == 2])
        pair_cards = [card for card in all_cards if card[0] in pair_rank]
        return "Pair", pair_cards, "Pair", find_high_card(pair_cards)

    high_card = find_high_card(all_cards)
    return "High card", [high_card], "High Card: " + high_card[0] + " of " + high_card[1]

def generate_remaining_cards(initial_hand, table_cards):
    ranks = '23456789TJQKA'
    suits = ['Spades', 'Hearts', 'Diamonds', 'Clubs']
    deck = [(rank, suit) for rank in ranks for suit in suits]
    
    remaining_cards = [card for card in deck if card not in initial_hand and card not in table_cards]
    
    return remaining_cards

def generate_hand_combinations(initial_hand, remaining_cards):
    return itertools.combinations(remaining_cards, 2)

def evaluate_hand_combinations(hand_combinations, table_cards):
    evaluated_hands = []
    for hand_combination in hand_combinations:
        hand = list(hand_combination)
        result = predict_poker_hand(hand, table_cards)
        hand_type = result[0]
        evaluated_hands.append((hand, hand_type))
    
    # Sort hands based on their ranks
    evaluated_hands.sort(key=lambda x: hand_ranking.index(x[1]))
    
    return evaluated_hands

def determine_betting_multiplier(hand_strength, hand_rankings):
    # Return the multiplier based on hand strength
    return hand_rankings.get(hand_strength, 0)

def determine_betting(player_hand, table_cards, stack_size=100000, bluff_chance=1):
    # Evaluate hand strength
    hand_strength = predict_poker_hand(player_hand, table_cards)[0]
    
    hand_rankings = {
        "Royal flush": 100,
        "Straight flush": 80,
        "Four of a kind": 60,
        "Full house": 40,
        "Flush": 30,
        "Straight": 30,
        "Three of a kind": 20,
        "Two pair": 15,
        "Pair": 10,
        "High card": 5
    }
    
    # Determine betting amount based on hand strength
    if bluff_chance >= random.random():  # Bluff
        bet_amount = stack_size  # All in
    else:
        bet_multiplier = determine_betting_multiplier(hand_strength, hand_rankings)
        bet_amount = min(int(stack_size * bet_multiplier), 100000)  # Cap 
    
    return "bet", bet_amount

hand_ranking = [
    "Royal flush",
    "Straight flush",
    "Four of a kind",
    "Full house",
    "Flush",
    "Straight",
    "Three of a kind",
    "Two pair",
    "Pair",
    "High card"
]

# Example usage:
player_hand = [('K', 'Spades'), ('2', 'Hearts')]
table_cards = [('4', 'Clubs'), ('3', 'Diamonds'), ('9', 'Diamonds'), ('8', 'Spades'), ('6', 'Clubs')]

result = predict_poker_hand(player_hand, table_cards)
hand_type, winning_cards, winning_combination, high_card = result[0], result[1], result[2] if len(result) > 2 else None, result[3] if len(result) > 3 else None

print_combination(hand_type, winning_cards, winning_combination, high_card)

remaining_cards = generate_remaining_cards(player_hand, table_cards)
hand_combinations = generate_hand_combinations(player_hand, remaining_cards)
evaluated_hands = evaluate_hand_combinations(hand_combinations, table_cards)

# print("Ranking of other hand combinations:")
# for i, (hand, hand_type) in enumerate(evaluated_hands, 1):
#     print(i, ":", hand_type, "-", hand)

action, bet_amount = determine_betting(player_hand, table_cards)
print("Player's betting action:", action)
print("Player's betting amount:", bet_amount)
# Out:
# Combination: High Card: K of Spades
# Player's betting action: bet
# Player's betting amount: 100000
